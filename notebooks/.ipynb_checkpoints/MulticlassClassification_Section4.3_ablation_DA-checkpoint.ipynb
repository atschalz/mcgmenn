# %%
import sys
# Append root path 
sys.path.append("../")
sys.path.append("../lmmnn")

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

os.environ["TF_FORCE_GPU_ALLOW_GROWTH"]="true"
os.environ["CUDA_VISIBLE_DEVICES"]="0"

if tf.test.gpu_device_name() != '/device:GPU:0':
    print('WARNING: GPU device not found.')
else:
    print('SUCCESS: Found GPU: {}'.format(tf.test.gpu_device_name()))

from model.mixed_effects import *
from utils.fe_models import get_model
from utils.evaluation import *
from utils.utils import *
from data.preprocessing import dataset_preprocessing

# from vis.utils.utils import apply_modifications
# helper function
def update_layer_activation(model, activation, index=-1):
    model.layers[index].activation = activation
    return model

from tensorflow.keras.optimizers import Adam
from keras.models import Sequential, Model
from keras.layers import Dense, Input, Reshape, Embedding, Concatenate
from tensorflow.keras.activations import sigmoid

from sklearn.metrics import accuracy_score as acc
from sklearn.metrics import roc_auc_score as auroc
from sklearn.metrics import f1_score as f1
from sklearn.model_selection import train_test_split
from category_encoders import TargetEncoder
from tensorflow_addons.metrics import F1Score

from scipy import stats
import pickle
import yaml
import time
import gc

RS = 555
# Out:
# SUCCESS: Found GPU: /device:GPU:0

# %%
class MCMCSamplingCallback(tf.keras.callbacks.Callback):
    def __init__(self,
                 num_mcmc_samples=1,
                 step_size=0.01,
                 perc_burnin=0.1,
                 num_burnin_steps=0,
                 warm_restart=None):
        super().__init__()

        self.num_mcmc_samples = tf.constant(num_mcmc_samples)
        self.perc_burnin = perc_burnin
        self.num_burnin_steps = num_burnin_steps
        self.warm_restart = warm_restart
        self.step_size = tf.Variable(step_size,trainable=False)
        self.step_sizes = []


    def on_train_begin(self, logs=None):
#         self.mcmc_kernel = tfp.mcmc.HamiltonianMonteCarlo(
#             target_log_prob_fn=self.model.target_log_prob_fn,
#             step_size=self.step_size, #0.15
#             num_leapfrog_steps=3
#         )

        self.mcmc_kernel = tfp.mcmc.DualAveragingStepSizeAdaptation(
            inner_kernel=tfp.mcmc.NoUTurnSampler(
                target_log_prob_fn=self.model.target_log_prob_fn,
                step_size=self.step_size),
            num_adaptation_steps=500,
            target_accept_prob=0.651)

#         self.mcmc_kernel = tfp.mcmc.DualAveragingStepSizeAdaptation(
#             inner_kernel=tfp.mcmc.NoUTurnSampler(
#                 target_log_prob_fn=self.model.target_log_prob_fn,
#                 step_size=self.step_size),
#             num_adaptation_steps=500,
#             target_accept_prob=0.651)

    def on_epoch_begin(self, epoch, logs=None):
        if epoch==0:
            self.model.all_samples.extend(([[state[num] for state in self.model.current_state] for num in range(1)]))

            self.model.mean_samples = [tf.reduce_mean([sample[q] for sample in self.model.all_samples[round(epoch*(self.perc_burnin)):]], axis=0) for q in
                                       range(len(self.model.qs))]
        if self.model.fe_pretraining:
            if self.model.fe_converged:
                self.run_sampling(epoch)
            else:
                self.model.acceptance_rates.append(-1)
        else:
            self.run_sampling(epoch)

    def run_sampling(self,epoch):
        self.model.fX.assign(self.model.fe_model(self.model.X, training=False))

        if self.model.embed_x:
            self.model.X_embedded.assign(self.model.X_embed_model(self.model.X, training=False))

        if self.model.embed_z:
            for q_num in range(len(self.model.qs)):
                self.model.Z_embedded[q_num].assign(self.model.Z_embed_models[q_num](self.model.Z[:,q_num], training=False))

                ## Find initial step size
        # if self.model.previous_kernel_results.log_accept_ratio == -np.inf:
        # if len(self.model.acceptance_rates)>0 and self.model.acceptance_rates[-1]<0.5:
#         if len(self.model.acceptance_rates)>0 and self.model.acceptance_rates[-1]<0.0001:
            # self.mcmc_kernel.parameters["step_size"] = self.mcmc_kernel.parameters["step_size"]/2
            # self.model.previous_kernel_results["new_step_size"] = self.model.previous_kernel_results.step_size/2
            # setattr(self.model.previous_kernel_results, "new_step_size", self.model.previous_kernel_results.step_size/2)
#             self.step_size.assign(self.step_size/2)
#             print(f"Adapt step size to {float(self.step_size)}")

    
        if self.warm_restart!=None and epoch>0:
            ## Warm restart
            # if self.model.previous_kernel_results.log_accept_ratio == -np.inf:
                # restart = True
            # else:
                # restart = False
            # else:
            restart = ((epoch + 1) % self.warm_restart) == 0 and epoch != 0

            if restart:
                print("\n Warm restart to unstuck the chain")
                if self.model.embed_z and self.model.embed_x:
                    self.model.current_state = self.model.data_model(self.model.fX, self.model.X_embedded, self.model.Z_embedded).sample(1, seed=self.model.RS)[:-1]
                elif self.model.embed_z and not self.model.embed_x:
                    self.model.current_state = self.model.data_model(self.model.fX, self.model.X, self.model.Z_embedded).sample(1, seed=self.model.RS)[:-1]
                elif not self.model.embed_z and self.model.embed_x:
                    self.model.current_state = self.model.data_model(self.model.fX, self.model.X_embedded, self.model.Z).sample(1, seed=self.model.RS)[:-1]
                else:
                    self.model.current_state = self.model.data_model(self.model.fX, self.model.X, self.model.Z).sample(1, seed=self.model.RS)[:-1]

        print("\n Start sampling for epoch {} of training".format(epoch + 1))
        start = time.time()
        if epoch==0:
            self.previous_kernel_results = None
#             new_state, self.previous_kernel_results = self.get_mcmc_samples(self.model.current_state,
#                                                                                   tf.constant(self.num_mcmc_samples),
#                                                                                   None
#                                                                                                    )
        else:
#             self.step_size.assign(self.model.previous_kernel_results.inner_results.step_size)
            print(f"Adapt step size to {float(self.previous_kernel_results.inner_results.step_size)}")
        new_state, self.previous_kernel_results = self.get_mcmc_samples(self.model.current_state,
                                                                              tf.constant(self.num_mcmc_samples),
                                                                              self.previous_kernel_results
                                                                                               )
        # self.model.divide_constants.assign(
        #     list(1/np.mean(self.model.data_model._stddev_z,axis=1))+[1.])
        # self.model.divide_constants.assign(
        #     list((lambda x: 1+(x-x.mean()))(np.array(1+tf.math.softmax(1/len(self.model.qs)+0.5*tf.math.softmax(np.abs([np.mean(i) for i in self.model.previous_kernel_results.grads_target_log_prob]))))))+[1.])
        # print(np.round(self.model.divide_constants,2))
        try:
            log_accept_ratio = self.previous_kernel_results.log_accept_ratio
        except:
            log_accept_ratio = self.previous_kernel_results.inner_results.log_accept_ratio
        acceptance_rate = tf.math.exp(tf.minimum(log_accept_ratio, 0.))

        self.step_sizes.append(float(self.step_size))

        end = time.time()


        self.model.current_state = [tf.identity(i) for i in new_state]
        # Todo: Append all current states
        self.model.acceptance_rates.append(acceptance_rate)
        # self.model.all_samples.append(
        #     [tf.math.reduce_mean(self.model.current_state[q_num], axis=0) for q_num in range(len(self.model.qs))])
        self.model.all_samples.extend(([[state[num] for state in self.model.current_state] for num in range(self.num_mcmc_samples)]))

        self.model.mean_samples = [tf.reduce_mean([sample[q] for sample in self.model.all_samples[round(epoch*(self.perc_burnin)):]], axis=0) for q in
                                   range(len(self.model.qs))]

        self.model.e_step_times.append(round(end - start, 2))

    # def on_epoch_end(self, epoch, logs=None):
        for q_num in range(len(self.model.qs)):
                self.model.data_model.trainable_variables[q_num].assign(
                    tf.math.reduce_std(self.model.current_state[q_num][-1],axis=0))

        self.model.stds.append([tf.identity(i) for i in self.model.data_model._stddev_z])

    @tf.function(reduce_retracing=True)  # autograph=False, jit_compile=True, reduce_retracing=True)
    def get_mcmc_samples(self, current_state, num_mcmc_samples=tf.constant(1), previous_kernel_results=None):
        samples, _, previous_kernel_results = tfp.mcmc.sample_chain(
            kernel=self.mcmc_kernel, num_results=num_mcmc_samples,
            current_state=[state[-1] for state in current_state],
            num_burnin_steps=self.num_burnin_steps,
            trace_fn=None, previous_kernel_results=previous_kernel_results,
            return_final_kernel_results=True, seed=self.model.RS)
        #     current_state=[sample[-1] for sample in samples]

        return samples, previous_kernel_results

# %% [markdown]
# #### Download and save data from Pargent et al. by running "data/download_pargent2022_datasets.py before running this notebook

# %%
mode="cv"
hct=10
test_ratio=None
val_ratio=None
folds=5
results = {}
dataset_names = ["eucalyptus", "Midwest_survey", "hpc-job-scheduling", "video-game-sales", "okcupid-stem", "Diabetes130US"]


loss_use = lambda: tf.keras.losses.CategoricalCrossentropy
target= "categorical"
batch_size=512
epochs = 500
early_stopping = 20
model_name = "AutoGluon"
embed_dims_method = "AutoGluon"

results = {}

#######################################

for dataset_name in dataset_names:
    print(f"Start training procedure for {dataset_name}")
    data_path = f"{mode}_RS{RS}_hct{hct}"
    if mode == "cv":
        data_path += f"_{folds}folds"
    elif mode == "train_test":
        data_path += f"_split{1-test_ratio*100}-{test_ratio*100}"
    elif mode == "train_val_test":
        data_path += f"_split{round(100-(test_ratio+val_ratio)*100)}-{round(test_ratio*100)}-{round(val_ratio*100)}"

    # If no data_dict exists, run preprocessing, else load data_dict
    if not os.path.exists(f"../data/prepared/{dataset_name}/"+data_path+"/data_dict.pickle"):
        dataset_preprocessing.process_dataset(dataset_name, target, mode, RS, hct, test_ratio, val_ratio, folds)
    with open(f"../data/prepared/{dataset_name}/{data_path}/data_dict.pickle", 'rb') as handle:
            data_dict = pickle.load(handle)

    z_cols = data_dict["z_cols"]
    
    results[dataset_name] = {}
    for fold_num in range(folds):
        results[dataset_name][fold_num] = {}

        print(f"Fold no. {fold_num}")
        save_path = f"../results/{dataset_name}/{data_path}/fold_{fold_num}/dual_averaging"
        if not os.path.exists(save_path):
            os.makedirs(save_path)
        
        z_ohe_encoded_train = data_dict[f"z_ohe_encoded_train_{fold_num}"] 
        z_ohe_encoded_val = data_dict[f"z_ohe_encoded_val_{fold_num}"] 
        z_ohe_encoded_test = data_dict[f"z_ohe_encoded_test_{fold_num}"] 

        z_target_encoded_train = data_dict[f"z_target_encoded_train_{fold_num}"] 
        z_target_encoded_val = data_dict[f"z_target_encoded_val_{fold_num}"] 
        z_target_encoded_test = data_dict[f"z_target_encoded_test_{fold_num}"] 
        
        target_encoding_time = data_dict[f"target_encoding_time_{fold_num}"]
        ohe_encoding_time = data_dict[f"ohe_encoding_time_{fold_num}"]
        
        x_cols = data_dict[f"X_train_{fold_num}"].columns
        X_train = data_dict[f"X_train_{fold_num}"]
        Z_train = data_dict[f"Z_train_{fold_num}"]
        y_train = data_dict[f"y_train_{fold_num}"]

        X_val = data_dict[f"X_val_{fold_num}"]
        Z_val = data_dict[f"Z_val_{fold_num}"]
        y_val = data_dict[f"y_val_{fold_num}"]

        X_test = data_dict[f"X_test_{fold_num}"]
        Z_test = data_dict[f"Z_test_{fold_num}"]
        y_test = data_dict[f"y_test_{fold_num}"]
    
        if not os.path.exists(f"{save_path}/results_RS{RS}_{dataset_name}_iter{fold_num}.pickle"):

            tf.random.set_seed(RS+fold_num)
            np.random.seed(RS+fold_num)

            qs = np.max([tf.reduce_max(Z_train, axis=0),tf.reduce_max(Z_val, axis=0),tf.reduce_max(Z_test, axis=0)],axis=0)+1
            
            X_train = tf.convert_to_tensor(X_train)
            Z_train = tf.convert_to_tensor(Z_train,dtype=tf.int32)
            y_train = tf.convert_to_tensor(y_train)

            X_val = tf.convert_to_tensor(X_val)
            Z_val = tf.convert_to_tensor(Z_val,dtype=tf.int32)
            y_val = tf.convert_to_tensor(y_val)

            X_test = tf.convert_to_tensor(X_test)
            Z_test = tf.convert_to_tensor(Z_test,dtype=tf.int32)
            y_test = tf.convert_to_tensor(y_test)

            if target == "categorical":
                n_classes = np.unique(y_train).shape[0]
            elif target=="binary":
                n_classes = 1
            
            y_train = tf.one_hot(tf.cast(y_train,tf.int32),n_classes)
            y_val = tf.one_hot(tf.cast(y_val,tf.int32),n_classes)
            y_test = tf.one_hot(tf.cast(y_test,tf.int32),n_classes)
            
            ##### GMENN #####
            d = X_train.shape[1] # columns
            n = X_train.shape[0] # rows
            num_outputs = n_classes
            perc_numeric = d/(d+Z_train.shape[1])

#             qs = np.max([tf.reduce_max(Z_train, axis=0),tf.reduce_max(Z_val, axis=0),tf.reduce_max(Z_test, axis=0)],axis=0)+1

            set_seed(RS)

            fe_model, optimizer = get_model(model_name=model_name, input_size=X_train.shape[1], 
                                              output_size=num_outputs, 
                                              target=target, 
                                              perc_numeric=perc_numeric, RS=RS)
            
            if dataset_name=="eucalyptus":
                optimizer.learning_rate.assign(optimizer.learning_rate*10)
        
        
            initial_stds = np.ones([len(qs),num_outputs]).astype(float).tolist()

            me_model = MixedEffectsNetwork(X_train, Z_train, y_train, fe_model, 
                                           target=target, qs=qs,
                                           initial_stds=initial_stds,
                                          fe_loss_weight=1.,
                                           mode="intercepts",
                                           early_stopping_fe=early_stopping,
                                          )    

            me_model.compile(
                loss_class_me = loss_use()(),
                loss_class_fe = loss_use()(),
            #     metric_class_me = tf.keras.metrics.AUC(multi_label=True, name="auc_me"),
            #     metric_class_fe = tf.keras.metrics.AUC(multi_label=True, name="auc_fe"),
                optimizer=optimizer
            )

            mcmc = MCMCSamplingCallback(num_mcmc_samples=1,
                                        perc_burnin=0.7,
                                        warm_restart=None,
                                        num_burnin_steps=1,
                                        step_size = 0.1#initial_step_size,
                                   )

            print_metric = PrintMetrics(X_train, Z_train, y_train, X_val, Z_val, y_val)

            start = time.time()
            history = me_model.fit([X_train,Z_train], y_train,
                         callbacks=[mcmc,
                                    print_metric,
                                    tf.keras.callbacks.EarlyStopping(monitor="me_auc_val", patience=early_stopping, mode="max")],
                         epochs=epochs,
                         validation_data=[[X_val,Z_val],y_val],
                        batch_size=batch_size)

            end = time.time()
            fit_time_gmenn = round(end-start,2)

            y_train_pred_gmenn, y_train_pred_gmenn_fe = me_model([X_train,Z_train])
            y_val_pred_gmenn, y_val_pred_gmenn_fe = me_model([X_val,Z_val])
            y_test_pred_gmenn, y_test_pred_gmenn_fe = me_model([X_test,Z_test])    

            
            ###### Prepare NN Training ######
#             metrics_use = []
#             if target =="binary":
#                 metrics_use.append(tf.keras.metrics.AUC(name="auc"))
#                 metrics_use.append(tf.keras.metrics.Accuracy(name="accuracy"))
#                 metrics_use.append(F1Score(num_classes=2, average="micro", name="f1"))
#                 stop_mode = "max"
#                 activation_layer = tf.keras.activations.sigmoid
#             elif target =="categorical":
#                 metrics_use.append(tf.keras.metrics.AUC(multi_label=True, name="auc"))
#                 metrics_use.append(tf.keras.metrics.CategoricalAccuracy(name="accuracy"))
#                 metrics_use.append(F1Score(num_classes=num_outputs, average="weighted", name="f1"))
#                 stop_mode = "max"
#                 activation_layer = tf.keras.activations.softmax
#             elif target == "continuous":
#                 metrics_use.append(RSquare(name="r2"))
#                 metrics_use.append(tf.keras.metrics.MeanSquaredError(name="mse"))
#                 stop_mode = "min"            
            
#             ##### Ignore #####
#             model_nn, optimizer = get_model(model_name=model_name, 
#                                             input_size=X_train.shape[1], 
#                                             output_size=num_outputs, 
#                                             target=target, 
#                                             perc_numeric=perc_numeric, RS=RS)
#             if dataset_name=="eucalyptus":
#                 optimizer.learning_rate.assign(optimizer.learning_rate*10)

#             model_nn.build((n,d))
#             update_layer_activation(model=model_nn, activation=activation_layer)

#             model_nn.compile(loss=loss_use()(), optimizer=optimizer, metrics = metrics_use)

#             callback = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=early_stopping, mode=stop_mode)

#             start = time.time()
#             history_nn = model_nn.fit(X_train, y_train,
#                          validation_data= [X_val, y_val],
#                          epochs=epochs, batch_size=batch_size, callbacks=[callback])
#             end = time.time()
#             fit_time_nn = round(end-start,2)

#             y_train_pred_nn = model_nn.predict(X_train ,batch_size=batch_size)
#             y_val_pred_nn = model_nn.predict(X_val ,batch_size=batch_size)
#             y_test_pred_nn = model_nn.predict(X_test ,batch_size=batch_size)

#             if target == "binary":
#                 eval_res_train_nn = get_metrics(y_train[:,0], y_train_pred_nn, target=target)
#                 eval_res_val_nn = get_metrics(y_val[:,0], y_val_pred_nn, target=target)
#                 eval_res_test_nn = get_metrics(y_test[:,0], y_test_pred_nn, target=target)
#             elif target == "categorical":
#                 eval_res_train_nn = get_metrics(y_train, y_train_pred_nn, target=target)
#                 eval_res_val_nn = get_metrics(y_val, y_val_pred_nn, target=target)
#                 eval_res_test_nn = get_metrics(y_test, y_test_pred_nn, target=target)

#             ##### Target Encoding #####
#             print("\n Train Target Encoding Network")
#             model_nn_te, optimizer = get_model(model_name=model_name, 
#                                             input_size=np.append(X_train ,z_target_encoded_train, axis=1).shape[1], 
#                                             output_size=num_outputs, 
#                                             target=target, 
#                                             perc_numeric=perc_numeric, RS=RS)
#             if dataset_name=="eucalyptus":
#                 optimizer.learning_rate.assign(optimizer.learning_rate*10)
#             model_nn_te.build((n,np.append(X_train ,z_target_encoded_train, axis=1).shape[1]))
#             update_layer_activation(model=model_nn_te, activation=activation_layer)
#             model_nn_te.compile(loss=loss_use()(), optimizer=optimizer, metrics = metrics_use)
#             callback = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=early_stopping, mode=stop_mode)

#             start = time.time()
#             history_nn_te = model_nn_te.fit(np.append(X_train ,z_target_encoded_train, axis=1), y_train,
#                          validation_data= [np.append(X_val ,z_target_encoded_val, axis=1), y_val],
#                          epochs=epochs, batch_size=batch_size, callbacks=[callback])
#             end = time.time()
#             fit_time_te = round(end-start,2)+target_encoding_time

#             y_train_pred_nn_te = model_nn_te.predict(np.append(X_train ,z_target_encoded_train, axis=1) ,batch_size=batch_size)
#             y_val_pred_nn_te = model_nn_te.predict(np.append(X_val ,z_target_encoded_val, axis=1) ,batch_size=batch_size)
#             y_test_pred_nn_te = model_nn_te.predict(np.append(X_test ,z_target_encoded_test, axis=1) ,batch_size=batch_size)

#             if target == "binary":
#                 eval_res_train_nn_te = get_metrics(y_train[:,0], y_train_pred_nn_te, target=target)
#                 eval_res_val_nn_te = get_metrics(y_val[:,0], y_val_pred_nn_te, target=target)
#                 eval_res_test_nn_te = get_metrics(y_test[:,0], y_test_pred_nn_te, target=target)
#             elif target == "categorical":
#                 eval_res_train_nn_te = get_metrics(y_train, y_train_pred_nn_te, target=target)
#                 eval_res_val_nn_te = get_metrics(y_val, y_val_pred_nn_te, target=target)
#                 eval_res_test_nn_te = get_metrics(y_test, y_test_pred_nn_te, target=target)

#             ##### OHE #####
#             print("\n Train OHE Network")
#             model_nn_ohe, optimizer = get_model(model_name=model_name, 
#                                             input_size=np.append(X_train ,z_ohe_encoded_train, axis=1).shape[1], 
#                                             output_size=num_outputs, 
#                                             target=target, 
#                                             perc_numeric=perc_numeric, RS=RS)
#             if dataset_name=="eucalyptus":
#                 optimizer.learning_rate.assign(optimizer.learning_rate*10)
#             model_nn_ohe.build((n,np.append(X_train ,z_ohe_encoded_train, axis=1).shape[1]))
#             update_layer_activation(model=model_nn_ohe, activation=activation_layer)
#             model_nn_ohe.compile(loss=loss_use()(), optimizer=optimizer, metrics = metrics_use)
#             callback = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=early_stopping, mode=stop_mode)

#             start = time.time()
#             history_nn_ohe = model_nn_ohe.fit(np.append(X_train ,z_ohe_encoded_train, axis=1), y_train,
#                          validation_data= [np.append(X_val ,z_ohe_encoded_val, axis=1), y_val],
#                          epochs=epochs, batch_size=batch_size, callbacks=[callback])
#             end = time.time()
#             fit_time_ohe = round(end-start,2)+ohe_encoding_time

#             y_train_pred_nn_ohe = model_nn_ohe.predict(np.append(X_train ,z_ohe_encoded_train, axis=1), batch_size=batch_size)
#             y_val_pred_nn_ohe = model_nn_ohe.predict(np.append(X_val ,z_ohe_encoded_val, axis=1), batch_size=batch_size)
#             y_test_pred_nn_ohe = model_nn_ohe.predict(np.append(X_test ,z_ohe_encoded_test, axis=1), batch_size=batch_size)
            
#             if target == "binary":
#                 eval_res_train_nn_ohe = get_metrics(y_train[:,0], y_train_pred_nn_ohe, target=target)
#                 eval_res_val_nn_ohe = get_metrics(y_val[:,0], y_val_pred_nn_ohe, target=target)
#                 eval_res_test_nn_ohe = get_metrics(y_test[:,0], y_test_pred_nn_ohe, target=target)            
#             elif target == "categorical":
#                 eval_res_train_nn_ohe = get_metrics(y_train, y_train_pred_nn_ohe, target=target)
#                 eval_res_val_nn_ohe = get_metrics(y_val, y_val_pred_nn_ohe, target=target)
#                 eval_res_test_nn_ohe = get_metrics(y_test, y_test_pred_nn_ohe, target=target)
                
#             ##### Embedding #####
#             print("\n Embedding Estimate Network")

#             if embed_dims_method=="sqrt":
#                 embed_dims = [int(np.sqrt(q)) for q in qs]
#             elif embed_dims_method=="AutoGluon":
#                 embed_dims = [int(np.max([100, np.round(1.6*q**0.56)])) for q in qs]
#             else:
#                 embed_dims = [10 for q in qs]

#             input_layer = Input(shape=(d,))

#             # Define embedding layers
#             embed_inputs = []
#             embedding_layers = []
#             for q_num in range(len(qs)):
#                 Z_input_layer = Input(shape=(1,))
#                 embedding_layer = Embedding(qs[q_num], embed_dims[q_num], input_length=1)(Z_input_layer)
#                 embedding_layer = Reshape(target_shape=(embed_dims[q_num],))(embedding_layer)

#                 embed_inputs.append(Z_input_layer)
#                 embedding_layers.append(embedding_layer)

#             ### Get model layer dimensions
#             min_numeric_embed_dim = 32
#             max_numeric_embed_dim = 2056
#             max_layer_width = 2056
#             # Main dense model
#             if target == "continuous":
#                 default_layer_sizes = [256,
#                                        128]  # overall network will have 4 layers. Input layer, 256-unit hidden layer, 128-unit hidden layer, output layer.
#             else:
#                 default_sizes = [256, 128]  # will be scaled adaptively
#                 # base_size = max(1, min(num_net_outputs, 20)/2.0) # scale layer width based on number of classes
#                 base_size = max(1, min(num_outputs,
#                                        100) / 50)  # TODO: Updated because it improved model quality and made training far faster
#                 default_layer_sizes = [defaultsize * base_size for defaultsize in default_sizes]
#             layer_expansion_factor = 1  # TODO: consider scaling based on num_rows, eg: layer_expansion_factor = 2-np.exp(-max(0,train_dataset.num_examples-10000))
#             first_layer_width = int(min(max_layer_width, layer_expansion_factor * default_layer_sizes[0]))

#             # numeric embed dim
#             vector_dim = 0  # total dimensionality of vector features (I think those should be transformed string features, which we don't have)
#             prop_vector_features = perc_numeric  # Fraction of features that are numeric
#             numeric_embedding_size = int(min(max_numeric_embed_dim,
#                                              max(min_numeric_embed_dim,
#                                                  first_layer_width * prop_vector_features * np.log10(vector_dim + 10))))


#             numeric_embedding = Dense(numeric_embedding_size, activation="relu")(input_layer)

#             concat = Concatenate()([numeric_embedding] + embedding_layers)

#             base_model, optimizer = get_model(model_name=model_name, 
#                                               input_size=numeric_embedding_size + sum(embed_dims), 
#                                               output_size=num_outputs, target=target,
#                                               perc_numeric=perc_numeric, RS=RS)

#             if dataset_name=="eucalyptus":
#                 optimizer.learning_rate.assign(optimizer.learning_rate*10)
#             base_model.build((n, numeric_embedding_size + sum(embed_dims)))
#             update_layer_activation(model=base_model, activation=activation_layer)

#             layers = base_model(concat)

#             model_embed = Model(inputs=[input_layer] + embed_inputs, outputs=layers)


#             model_embed.compile(loss=loss_use()(), optimizer=optimizer, metrics = metrics_use)
#             callback = tf.keras.callbacks.EarlyStopping(monitor="val_auc", patience=early_stopping, mode=stop_mode)

#             start = time.time()
#             history_nn_embed = model_embed.fit([X_train] + [Z_train[: ,q_num] for q_num in range(len(qs))], y_train,
#                             validation_data=[[X_val] + [Z_val[: ,q_num] for q_num in range(len(qs))], y_val],
#                             epochs=epochs, batch_size=batch_size, callbacks=[callback])
#             end = time.time()
#             fit_time_embed = round(end-start,2)

#             y_train_pred_embed = model_embed.predict([X_train] + [Z_train[: ,q_num] for q_num in range(len(qs))]
#                                                      ,batch_size=batch_size)
#             y_val_pred_embed = model_embed.predict([X_val] + [Z_val[: ,q_num] for q_num in range(len(qs))]
#                                                     ,batch_size=batch_size)
#             y_test_pred_embed = model_embed.predict([X_test] + [Z_test[: ,q_num] for q_num in range(len(qs))]
#                                                     ,batch_size=batch_size)

#             if target == "binary":
#                 eval_res_train_embed = get_metrics(y_train[:,0], y_train_pred_embed, target=target)
#                 eval_res_val_embed = get_metrics(y_val[:,0], y_val_pred_embed, target=target)
#                 eval_res_test_embed = get_metrics(y_test[:,0], y_test_pred_embed, target=target)
#             elif target == "categorical":
#                 eval_res_train_embed = get_metrics(y_train, y_train_pred_embed, target=target)
#                 eval_res_val_embed = get_metrics(y_val, y_val_pred_embed, target=target)
#                 eval_res_test_embed = get_metrics(y_test, y_test_pred_embed, target=target)

#             eval_res_train_embed, eval_res_test_embed        



            ##### Document Results #####
            
            results[dataset_name][fold_num]["histories"] = {"GMENN": history.history,
#                                                        "Ignore": history_nn.history,
#                                                        "TE": history_nn_te.history,
#                                                        "OHE": history_nn_ohe.history,
#                                                        "Embedding": history_nn_embed.history,
                                                      }
            
            results[dataset_name][fold_num]["predictions"] = {"GMENN": [y_train_pred_gmenn, y_val_pred_gmenn, y_test_pred_gmenn],
                                                        "GMENN (FE)": [y_train_pred_gmenn_fe, y_val_pred_gmenn_fe, y_test_pred_gmenn_fe],
#                                                         "Ignore": [y_train_pred_nn, y_val_pred_nn, y_test_pred_nn],
#                                                         "TE": [y_train_pred_nn_te, y_val_pred_nn_te, y_test_pred_nn_te],
#                                                         "OHE": [y_train_pred_nn_ohe, y_val_pred_nn_ohe, y_test_pred_nn_ohe],
#                                                         "Embedding": [y_train_pred_embed, y_val_pred_embed, y_test_pred_embed],
                                                     }
            
            results[dataset_name][fold_num]["times"] = {"GMENN": fit_time_gmenn,
#                                                    "Ignore": fit_time_nn,
#                                                    "TE": fit_time_te,
#                                                    "OHE": fit_time_ohe,
#                                                    "Embedding": fit_time_embed,
                                                      }
            
            results[dataset_name][fold_num]["other_info"] = {
                "GMENN": {
#                     "_stddev_z": np.array([i.numpy() for i in me_model.data_model._stddev_z]),
#                     "acceptance_rates": np.array(me_model.acceptance_rates),
#                     "random_effects": me_model.mean_samples,
#                     "all_samples": me_model.all_samples,
#                     "stds": me_model.stds
                },
            }
            
            
            with open(f"{save_path}//results_RS{RS}_{dataset_name}_iter{fold_num}.pickle", 'wb') as handle:
                pickle.dump(results[dataset_name][fold_num], handle, protocol=pickle.HIGHEST_PROTOCOL)
            
            
            del X_train, X_val, X_test, y_train, y_val, y_test
#             del z_target_encoded_train, z_target_encoded_val, z_target_encoded_test
#             del z_ohe_encoded_train, z_ohe_encoded_val, z_ohe_encoded_test
            
            gc.collect()
        else:
            print(f"Load results for dataset {dataset_name}, iteration={fold_num}")
            with open(f"{save_path}/results_RS{RS}_{dataset_name}_iter{fold_num}.pickle", 'rb') as handle:
                results[dataset_name][fold_num] = pickle.load(handle)
# Out:
# Start training procedure for eucalyptus
# Fold no. 0
# Random seed set as 555
# 2024-01-18 16:26:35.360477: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
#  Start sampling for epoch 1 of training
# Epoch 1/500
# 1/1 [==============================] - ETA: 0sWARNING:tensorflow:5 out of the last 5 calls to <function pfor.<locals>.f at 0x7f66d8269b20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function pfor.<locals>.f at 0x7f66d82699e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 6s 6s/step - me_loss: 1.4721 - me_loss_val: 1.6373 - fe_loss: 1.4676 - fe_loss_val: 1.4793 - me_auc: 0.7271 - me_auc_val: 0.6758 - fe_auc: 0.7469 - fe_auc_val: 0.7200 - stds: 0.9291 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 2 of training
# Adapt step size to 1.8861645460128784
# Epoch 2/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 1.1466 - me_loss_val: 1.3029 - fe_loss: 1.3474 - fe_loss_val: 1.3843 - me_auc: 0.8188 - me_auc_val: 0.7597 - fe_auc: 0.8250 - fe_auc_val: 0.7936 - stds: 0.8823 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 3 of training
# Adapt step size to 0.07890954613685608
# Epoch 3/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.9898 - me_loss_val: 1.1801 - fe_loss: 1.2644 - fe_loss_val: 1.3183 - me_auc: 0.8652 - me_auc_val: 0.7963 - fe_auc: 0.8584 - fe_auc_val: 0.8287 - stds: 0.9107 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 4 of training
# Adapt step size to 0.46754327416419983
# Epoch 4/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.8772 - me_loss_val: 1.1039 - fe_loss: 1.2081 - fe_loss_val: 1.2731 - me_auc: 0.8998 - me_auc_val: 0.8211 - fe_auc: 0.8814 - fe_auc_val: 0.8450 - stds: 0.8036 - acceptance_rate: 0.6817
#
#  Start sampling for epoch 5 of training
# Adapt step size to 0.17662160098552704
# Epoch 5/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.8230 - me_loss_val: 1.0786 - fe_loss: 1.1706 - fe_loss_val: 1.2434 - me_auc: 0.9157 - me_auc_val: 0.8336 - fe_auc: 0.8954 - fe_auc_val: 0.8506 - stds: 0.7963 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 6 of training
# Adapt step size to 0.5712532997131348
# Epoch 6/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.8167 - me_loss_val: 1.1060 - fe_loss: 1.1426 - fe_loss_val: 1.2228 - me_auc: 0.9188 - me_auc_val: 0.8232 - fe_auc: 0.9042 - fe_auc_val: 0.8499 - stds: 0.6929 - acceptance_rate: 0.2638
#
#  Start sampling for epoch 7 of training
# Adapt step size to 0.22003073990345
# Epoch 7/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7922 - me_loss_val: 1.0731 - fe_loss: 1.1180 - fe_loss_val: 1.2059 - me_auc: 0.9239 - me_auc_val: 0.8300 - fe_auc: 0.9106 - fe_auc_val: 0.8506 - stds: 0.6514 - acceptance_rate: 0.4878
#
#  Start sampling for epoch 8 of training
# Adapt step size to 0.19742809236049652
# Epoch 8/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7715 - me_loss_val: 1.0366 - fe_loss: 1.0957 - fe_loss_val: 1.1917 - me_auc: 0.9308 - me_auc_val: 0.8427 - fe_auc: 0.9171 - fe_auc_val: 0.8496 - stds: 0.6485 - acceptance_rate: 2.9397e-30
#
#  Start sampling for epoch 9 of training
# Adapt step size to 0.3579099476337433
# Epoch 9/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7607 - me_loss_val: 1.0306 - fe_loss: 1.0745 - fe_loss_val: 1.1783 - me_auc: 0.9330 - me_auc_val: 0.8433 - fe_auc: 0.9214 - fe_auc_val: 0.8509 - stds: 0.6102 - acceptance_rate: 0.8302
#
#  Start sampling for epoch 10 of training
# Adapt step size to 0.14440128207206726
# Epoch 10/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7500 - me_loss_val: 1.0203 - fe_loss: 1.0546 - fe_loss_val: 1.1651 - me_auc: 0.9380 - me_auc_val: 0.8489 - fe_auc: 0.9250 - fe_auc_val: 0.8519 - stds: 0.6030 - acceptance_rate: 0.9987
#
#  Start sampling for epoch 11 of training
# Adapt step size to 0.04182971641421318
# Epoch 11/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.7518 - me_loss_val: 1.0137 - fe_loss: 1.0362 - fe_loss_val: 1.1534 - me_auc: 0.9379 - me_auc_val: 0.8522 - fe_auc: 0.9289 - fe_auc_val: 0.8519 - stds: 0.6055 - acceptance_rate: 2.8440e-16
#
#  Start sampling for epoch 12 of training
# Adapt step size to 0.3457425832748413
# Epoch 12/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7480 - me_loss_val: 1.0061 - fe_loss: 1.0195 - fe_loss_val: 1.1411 - me_auc: 0.9403 - me_auc_val: 0.8542 - fe_auc: 0.9315 - fe_auc_val: 0.8537 - stds: 0.6008 - acceptance_rate: 0.9847
#
#  Start sampling for epoch 13 of training
# Adapt step size to 0.1463279277086258
# Epoch 13/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.7353 - me_loss_val: 0.9952 - fe_loss: 1.0044 - fe_loss_val: 1.1282 - me_auc: 0.9440 - me_auc_val: 0.8566 - fe_auc: 0.9339 - fe_auc_val: 0.8583 - stds: 0.5677 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 14 of training
# Adapt step size to 0.06105780601501465
# Epoch 14/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7280 - me_loss_val: 0.9852 - fe_loss: 0.9901 - fe_loss_val: 1.1151 - me_auc: 0.9459 - me_auc_val: 0.8597 - fe_auc: 0.9361 - fe_auc_val: 0.8613 - stds: 0.5033 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 15 of training
# Adapt step size to 0.4547238051891327
# Epoch 15/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.7241 - me_loss_val: 0.9834 - fe_loss: 0.9761 - fe_loss_val: 1.1020 - me_auc: 0.9476 - me_auc_val: 0.8606 - fe_auc: 0.9371 - fe_auc_val: 0.8642 - stds: 0.5120 - acceptance_rate: 0.0260
#
#  Start sampling for epoch 16 of training
# Adapt step size to 0.20011600852012634
# Epoch 16/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7185 - me_loss_val: 0.9776 - fe_loss: 0.9630 - fe_loss_val: 1.0904 - me_auc: 0.9488 - me_auc_val: 0.8609 - fe_auc: 0.9386 - fe_auc_val: 0.8665 - stds: 0.4834 - acceptance_rate: 0.9925
#
#  Start sampling for epoch 17 of training
# Adapt step size to 0.0971132293343544
# Epoch 17/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.7145 - me_loss_val: 0.9709 - fe_loss: 0.9506 - fe_loss_val: 1.0805 - me_auc: 0.9499 - me_auc_val: 0.8628 - fe_auc: 0.9399 - fe_auc_val: 0.8670 - stds: 0.4520 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 18 of training
# Adapt step size to 0.044108908623456955
# Epoch 18/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7123 - me_loss_val: 0.9699 - fe_loss: 0.9382 - fe_loss_val: 1.0713 - me_auc: 0.9520 - me_auc_val: 0.8642 - fe_auc: 0.9414 - fe_auc_val: 0.8695 - stds: 0.4304 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 19 of training
# Adapt step size to 0.020952586084604263
# Epoch 19/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7119 - me_loss_val: 0.9743 - fe_loss: 0.9270 - fe_loss_val: 1.0636 - me_auc: 0.9519 - me_auc_val: 0.8612 - fe_auc: 0.9428 - fe_auc_val: 0.8705 - stds: 0.4084 - acceptance_rate: 3.5764e-18
#
#  Start sampling for epoch 20 of training
# Adapt step size to 0.13552914559841156
# Epoch 20/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7071 - me_loss_val: 0.9643 - fe_loss: 0.9163 - fe_loss_val: 1.0556 - me_auc: 0.9518 - me_auc_val: 0.8633 - fe_auc: 0.9437 - fe_auc_val: 0.8721 - stds: 0.3952 - acceptance_rate: 0.3966
#
#  Start sampling for epoch 21 of training
# Adapt step size to 0.06470509618520737
# Epoch 21/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7059 - me_loss_val: 0.9535 - fe_loss: 0.9050 - fe_loss_val: 1.0467 - me_auc: 0.9524 - me_auc_val: 0.8682 - fe_auc: 0.9443 - fe_auc_val: 0.8742 - stds: 0.3880 - acceptance_rate: 1.3169e-08
#
#  Start sampling for epoch 22 of training
# Adapt step size to 0.08545905351638794
# Epoch 22/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7058 - me_loss_val: 0.9495 - fe_loss: 0.8932 - fe_loss_val: 1.0381 - me_auc: 0.9519 - me_auc_val: 0.8677 - fe_auc: 0.9457 - fe_auc_val: 0.8754 - stds: 0.3616 - acceptance_rate: 0.9511
#
#  Start sampling for epoch 23 of training
# Adapt step size to 0.04195152223110199
# Epoch 23/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.7003 - me_loss_val: 0.9416 - fe_loss: 0.8824 - fe_loss_val: 1.0299 - me_auc: 0.9529 - me_auc_val: 0.8696 - fe_auc: 0.9466 - fe_auc_val: 0.8770 - stds: 0.3734 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 24 of training
# Adapt step size to 0.018647121265530586
# Epoch 24/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6997 - me_loss_val: 0.9368 - fe_loss: 0.8720 - fe_loss_val: 1.0215 - me_auc: 0.9537 - me_auc_val: 0.8712 - fe_auc: 0.9474 - fe_auc_val: 0.8795 - stds: 0.3691 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 25 of training
# Adapt step size to 0.10563501715660095
# Epoch 25/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6965 - me_loss_val: 0.9313 - fe_loss: 0.8614 - fe_loss_val: 1.0114 - me_auc: 0.9548 - me_auc_val: 0.8732 - fe_auc: 0.9483 - fe_auc_val: 0.8819 - stds: 0.3469 - acceptance_rate: 3.1570e-27
#
#  Start sampling for epoch 26 of training
# Adapt step size to 0.053189050406217575
# Epoch 26/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6932 - me_loss_val: 0.9273 - fe_loss: 0.8512 - fe_loss_val: 1.0018 - me_auc: 0.9555 - me_auc_val: 0.8737 - fe_auc: 0.9493 - fe_auc_val: 0.8844 - stds: 0.3297 - acceptance_rate: 0.4880
#
#  Start sampling for epoch 27 of training
# Adapt step size to 0.027264736592769623
# Epoch 27/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6884 - me_loss_val: 0.9231 - fe_loss: 0.8417 - fe_loss_val: 0.9931 - me_auc: 0.9561 - me_auc_val: 0.8767 - fe_auc: 0.9506 - fe_auc_val: 0.8860 - stds: 0.3294 - acceptance_rate: 1.1711e-13
#
#  Start sampling for epoch 28 of training
# Adapt step size to 0.043910346925258636
# Epoch 28/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6860 - me_loss_val: 0.9110 - fe_loss: 0.8325 - fe_loss_val: 0.9855 - me_auc: 0.9560 - me_auc_val: 0.8783 - fe_auc: 0.9522 - fe_auc_val: 0.8874 - stds: 0.3162 - acceptance_rate: 0.2966
#
#  Start sampling for epoch 29 of training
# Adapt step size to 0.02293252758681774
# Epoch 29/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6836 - me_loss_val: 0.9055 - fe_loss: 0.8233 - fe_loss_val: 0.9807 - me_auc: 0.9564 - me_auc_val: 0.8817 - fe_auc: 0.9536 - fe_auc_val: 0.8871 - stds: 0.2898 - acceptance_rate: 0.7485
#
#  Start sampling for epoch 30 of training
# Adapt step size to 0.023738566786050797
# Epoch 30/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6775 - me_loss_val: 0.9029 - fe_loss: 0.8151 - fe_loss_val: 0.9765 - me_auc: 0.9581 - me_auc_val: 0.8820 - fe_auc: 0.9552 - fe_auc_val: 0.8874 - stds: 0.2719 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 31 of training
# Adapt step size to 0.06711024045944214
# Epoch 31/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6762 - me_loss_val: 0.9053 - fe_loss: 0.8074 - fe_loss_val: 0.9722 - me_auc: 0.9597 - me_auc_val: 0.8820 - fe_auc: 0.9564 - fe_auc_val: 0.8880 - stds: 0.2493 - acceptance_rate: 0.1043
#
#  Start sampling for epoch 32 of training
# Adapt step size to 0.03565486520528793
# Epoch 32/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6762 - me_loss_val: 0.9108 - fe_loss: 0.8004 - fe_loss_val: 0.9670 - me_auc: 0.9600 - me_auc_val: 0.8823 - fe_auc: 0.9569 - fe_auc_val: 0.8881 - stds: 0.2032 - acceptance_rate: 0.2461
#
#  Start sampling for epoch 33 of training
# Adapt step size to 0.02411017194390297
# Epoch 33/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6724 - me_loss_val: 0.9013 - fe_loss: 0.7938 - fe_loss_val: 0.9608 - me_auc: 0.9612 - me_auc_val: 0.8860 - fe_auc: 0.9571 - fe_auc_val: 0.8890 - stds: 0.1729 - acceptance_rate: 0.5093
#
#  Start sampling for epoch 34 of training
# Adapt step size to 0.022304048761725426
# Epoch 34/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6700 - me_loss_val: 0.8958 - fe_loss: 0.7868 - fe_loss_val: 0.9542 - me_auc: 0.9630 - me_auc_val: 0.8893 - fe_auc: 0.9576 - fe_auc_val: 0.8895 - stds: 0.1680 - acceptance_rate: 1.6281e-25
#
#  Start sampling for epoch 35 of training
# Adapt step size to 0.03615143150091171
# Epoch 35/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6684 - me_loss_val: 0.8945 - fe_loss: 0.7794 - fe_loss_val: 0.9481 - me_auc: 0.9644 - me_auc_val: 0.8902 - fe_auc: 0.9580 - fe_auc_val: 0.8902 - stds: 0.1546 - acceptance_rate: 0.5763
#
#  Start sampling for epoch 36 of training
# Adapt step size to 0.019860563799738884
# Epoch 36/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6642 - me_loss_val: 0.8918 - fe_loss: 0.7716 - fe_loss_val: 0.9424 - me_auc: 0.9649 - me_auc_val: 0.8912 - fe_auc: 0.9587 - fe_auc_val: 0.8908 - stds: 0.1576 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 37 of training
# Adapt step size to 0.03664349764585495
# Epoch 37/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6631 - me_loss_val: 0.8866 - fe_loss: 0.7641 - fe_loss_val: 0.9367 - me_auc: 0.9653 - me_auc_val: 0.8937 - fe_auc: 0.9592 - fe_auc_val: 0.8915 - stds: 0.1520 - acceptance_rate: 4.3911e-14
#
#  Start sampling for epoch 38 of training
# Adapt step size to 0.0203691553324461
# Epoch 38/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6610 - me_loss_val: 0.8811 - fe_loss: 0.7565 - fe_loss_val: 0.9313 - me_auc: 0.9657 - me_auc_val: 0.8947 - fe_auc: 0.9597 - fe_auc_val: 0.8920 - stds: 0.1452 - acceptance_rate: 0.8719
#
#  Start sampling for epoch 39 of training
# Adapt step size to 0.011456072330474854
# Epoch 39/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6581 - me_loss_val: 0.8741 - fe_loss: 0.7500 - fe_loss_val: 0.9259 - me_auc: 0.9665 - me_auc_val: 0.8955 - fe_auc: 0.9601 - fe_auc_val: 0.8920 - stds: 0.1439 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 40 of training
# Adapt step size to 0.005144839640706778
# Epoch 40/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6560 - me_loss_val: 0.8681 - fe_loss: 0.7437 - fe_loss_val: 0.9205 - me_auc: 0.9668 - me_auc_val: 0.8967 - fe_auc: 0.9598 - fe_auc_val: 0.8911 - stds: 0.1290 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 41 of training
# Adapt step size to 0.021847635507583618
# Epoch 41/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6551 - me_loss_val: 0.8660 - fe_loss: 0.7377 - fe_loss_val: 0.9157 - me_auc: 0.9672 - me_auc_val: 0.8956 - fe_auc: 0.9599 - fe_auc_val: 0.8913 - stds: 0.1304 - acceptance_rate: 0.2997
#
#  Start sampling for epoch 42 of training
# Adapt step size to 0.012474979273974895
# Epoch 42/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6538 - me_loss_val: 0.8681 - fe_loss: 0.7315 - fe_loss_val: 0.9111 - me_auc: 0.9675 - me_auc_val: 0.8953 - fe_auc: 0.9598 - fe_auc_val: 0.8919 - stds: 0.1343 - acceptance_rate: 7.6178e-13
#
#  Start sampling for epoch 43 of training
# Adapt step size to 0.012946386821568012
# Epoch 43/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6503 - me_loss_val: 0.8666 - fe_loss: 0.7249 - fe_loss_val: 0.9068 - me_auc: 0.9678 - me_auc_val: 0.8945 - fe_auc: 0.9597 - fe_auc_val: 0.8914 - stds: 0.1330 - acceptance_rate: 0.6163
#
#  Start sampling for epoch 44 of training
# Adapt step size to 0.007502206135541201
# Epoch 44/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.6496 - me_loss_val: 0.8686 - fe_loss: 0.7180 - fe_loss_val: 0.9025 - me_auc: 0.9683 - me_auc_val: 0.8937 - fe_auc: 0.9603 - fe_auc_val: 0.8919 - stds: 0.1390 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 45 of training
# Adapt step size to 0.01417483575642109
# Epoch 45/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6475 - me_loss_val: 0.8662 - fe_loss: 0.7112 - fe_loss_val: 0.8981 - me_auc: 0.9685 - me_auc_val: 0.8945 - fe_auc: 0.9609 - fe_auc_val: 0.8915 - stds: 0.1364 - acceptance_rate: 0.0403
#
#  Start sampling for epoch 46 of training
# Adapt step size to 0.008283151313662529
# Epoch 46/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.6417 - me_loss_val: 0.8601 - fe_loss: 0.7050 - fe_loss_val: 0.8938 - me_auc: 0.9689 - me_auc_val: 0.8957 - fe_auc: 0.9615 - fe_auc_val: 0.8916 - stds: 0.1422 - acceptance_rate: 0.2392
#
#  Start sampling for epoch 47 of training
# Adapt step size to 0.00527170579880476
# Epoch 47/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6396 - me_loss_val: 0.8559 - fe_loss: 0.6994 - fe_loss_val: 0.8889 - me_auc: 0.9692 - me_auc_val: 0.8949 - fe_auc: 0.9617 - fe_auc_val: 0.8924 - stds: 0.1350 - acceptance_rate: 0.9441
#
#  Start sampling for epoch 48 of training
# Adapt step size to 0.004905475303530693
# Epoch 48/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6374 - me_loss_val: 0.8478 - fe_loss: 0.6943 - fe_loss_val: 0.8842 - me_auc: 0.9697 - me_auc_val: 0.8976 - fe_auc: 0.9619 - fe_auc_val: 0.8923 - stds: 0.1225 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 49 of training
# Adapt step size to 0.002641610335558653
# Epoch 49/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6355 - me_loss_val: 0.8446 - fe_loss: 0.6898 - fe_loss_val: 0.8793 - me_auc: 0.9694 - me_auc_val: 0.8974 - fe_auc: 0.9617 - fe_auc_val: 0.8926 - stds: 0.1110 - acceptance_rate: 0.4349
#
#  Start sampling for epoch 50 of training
# Adapt step size to 0.0036938036791980267
# Epoch 50/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6324 - me_loss_val: 0.8422 - fe_loss: 0.6854 - fe_loss_val: 0.8752 - me_auc: 0.9693 - me_auc_val: 0.8978 - fe_auc: 0.9616 - fe_auc_val: 0.8926 - stds: 0.1051 - acceptance_rate: 0.0925
#
#  Start sampling for epoch 51 of training
# Adapt step size to 0.004931230563670397
# Epoch 51/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6294 - me_loss_val: 0.8399 - fe_loss: 0.6806 - fe_loss_val: 0.8715 - me_auc: 0.9694 - me_auc_val: 0.8981 - fe_auc: 0.9618 - fe_auc_val: 0.8933 - stds: 0.1034 - acceptance_rate: 0.4079
#
#  Start sampling for epoch 52 of training
# Adapt step size to 0.0035237816628068686
# Epoch 52/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6266 - me_loss_val: 0.8371 - fe_loss: 0.6755 - fe_loss_val: 0.8679 - me_auc: 0.9695 - me_auc_val: 0.8982 - fe_auc: 0.9622 - fe_auc_val: 0.8937 - stds: 0.1038 - acceptance_rate: 0.1016
#
#  Start sampling for epoch 53 of training
# Adapt step size to 0.00445981603115797
# Epoch 53/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6224 - me_loss_val: 0.8348 - fe_loss: 0.6704 - fe_loss_val: 0.8653 - me_auc: 0.9694 - me_auc_val: 0.8982 - fe_auc: 0.9628 - fe_auc_val: 0.8935 - stds: 0.1101 - acceptance_rate: 0.2866
#
#  Start sampling for epoch 54 of training
# Adapt step size to 0.003256453201174736
# Epoch 54/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6187 - me_loss_val: 0.8311 - fe_loss: 0.6651 - fe_loss_val: 0.8629 - me_auc: 0.9696 - me_auc_val: 0.8993 - fe_auc: 0.9634 - fe_auc_val: 0.8940 - stds: 0.1054 - acceptance_rate: 0.7165
#
#  Start sampling for epoch 55 of training
# Adapt step size to 0.0033133532851934433
# Epoch 55/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6150 - me_loss_val: 0.8289 - fe_loss: 0.6597 - fe_loss_val: 0.8608 - me_auc: 0.9697 - me_auc_val: 0.8987 - fe_auc: 0.9638 - fe_auc_val: 0.8946 - stds: 0.1049 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 56 of training
# Adapt step size to 0.0069961040280759335
# Epoch 56/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6112 - me_loss_val: 0.8268 - fe_loss: 0.6548 - fe_loss_val: 0.8584 - me_auc: 0.9698 - me_auc_val: 0.8989 - fe_auc: 0.9639 - fe_auc_val: 0.8944 - stds: 0.1072 - acceptance_rate: 0.0076
#
#  Start sampling for epoch 57 of training
# Adapt step size to 0.004292607307434082
# Epoch 57/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6085 - me_loss_val: 0.8267 - fe_loss: 0.6503 - fe_loss_val: 0.8552 - me_auc: 0.9702 - me_auc_val: 0.8990 - fe_auc: 0.9642 - fe_auc_val: 0.8946 - stds: 0.1057 - acceptance_rate: 0.3775
#
#  Start sampling for epoch 58 of training
# Adapt step size to 0.002687345491722226
# Epoch 58/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6061 - me_loss_val: 0.8239 - fe_loss: 0.6461 - fe_loss_val: 0.8516 - me_auc: 0.9704 - me_auc_val: 0.8996 - fe_auc: 0.9647 - fe_auc_val: 0.8950 - stds: 0.1020 - acceptance_rate: 0.2329
#
#  Start sampling for epoch 59 of training
# Adapt step size to 0.0031946999952197075
# Epoch 59/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.6016 - me_loss_val: 0.8217 - fe_loss: 0.6421 - fe_loss_val: 0.8488 - me_auc: 0.9707 - me_auc_val: 0.8991 - fe_auc: 0.9650 - fe_auc_val: 0.8946 - stds: 0.1038 - acceptance_rate: 0.5310
#
#  Start sampling for epoch 60 of training
# Adapt step size to 0.0029606069438159466
# Epoch 60/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5975 - me_loss_val: 0.8193 - fe_loss: 0.6383 - fe_loss_val: 0.8478 - me_auc: 0.9708 - me_auc_val: 0.8992 - fe_auc: 0.9649 - fe_auc_val: 0.8946 - stds: 0.1074 - acceptance_rate: 7.4662e-29
#
#  Start sampling for epoch 61 of training
# Adapt step size to 0.004545783158391714
# Epoch 61/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.5943 - me_loss_val: 0.8177 - fe_loss: 0.6347 - fe_loss_val: 0.8476 - me_auc: 0.9707 - me_auc_val: 0.8999 - fe_auc: 0.9649 - fe_auc_val: 0.8943 - stds: 0.0958 - acceptance_rate: 0.1028
#
#  Start sampling for epoch 62 of training
# Adapt step size to 0.0028431774117052555
# Epoch 62/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5916 - me_loss_val: 0.8177 - fe_loss: 0.6312 - fe_loss_val: 0.8472 - me_auc: 0.9704 - me_auc_val: 0.8991 - fe_auc: 0.9648 - fe_auc_val: 0.8945 - stds: 0.0927 - acceptance_rate: 0.2689
#
#  Start sampling for epoch 63 of training
# Adapt step size to 0.0021239484194666147
# Epoch 63/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.5885 - me_loss_val: 0.8158 - fe_loss: 0.6277 - fe_loss_val: 0.8454 - me_auc: 0.9704 - me_auc_val: 0.8998 - fe_auc: 0.9647 - fe_auc_val: 0.8944 - stds: 0.0950 - acceptance_rate: 0.1151
#
#  Start sampling for epoch 64 of training
# Adapt step size to 0.0020971004851162434
# Epoch 64/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5852 - me_loss_val: 0.8133 - fe_loss: 0.6239 - fe_loss_val: 0.8428 - me_auc: 0.9706 - me_auc_val: 0.9000 - fe_auc: 0.9652 - fe_auc_val: 0.8945 - stds: 0.1047 - acceptance_rate: 0.6844
#
#  Start sampling for epoch 65 of training
# Adapt step size to 0.0016075378516688943
# Epoch 65/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5822 - me_loss_val: 0.8097 - fe_loss: 0.6201 - fe_loss_val: 0.8403 - me_auc: 0.9710 - me_auc_val: 0.9005 - fe_auc: 0.9657 - fe_auc_val: 0.8946 - stds: 0.0875 - acceptance_rate: 1.2936e-22
#
#  Start sampling for epoch 66 of training
# Adapt step size to 0.003134609665721655
# Epoch 66/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5796 - me_loss_val: 0.8058 - fe_loss: 0.6165 - fe_loss_val: 0.8376 - me_auc: 0.9719 - me_auc_val: 0.9009 - fe_auc: 0.9664 - fe_auc_val: 0.8947 - stds: 0.0866 - acceptance_rate: 0.9942
#
#  Start sampling for epoch 67 of training
# Adapt step size to 0.0019939199555665255
# Epoch 67/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.5767 - me_loss_val: 0.8042 - fe_loss: 0.6129 - fe_loss_val: 0.8356 - me_auc: 0.9724 - me_auc_val: 0.9009 - fe_auc: 0.9669 - fe_auc_val: 0.8951 - stds: 0.0925 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 68 of training
# Adapt step size to 0.001263595768250525
# Epoch 68/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.5740 - me_loss_val: 0.8050 - fe_loss: 0.6092 - fe_loss_val: 0.8355 - me_auc: 0.9725 - me_auc_val: 0.9007 - fe_auc: 0.9670 - fe_auc_val: 0.8939 - stds: 0.0945 - acceptance_rate: 0.3727
#
#  Start sampling for epoch 69 of training
# Adapt step size to 0.0016696566017344594
# Epoch 69/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5709 - me_loss_val: 0.8051 - fe_loss: 0.6055 - fe_loss_val: 0.8359 - me_auc: 0.9724 - me_auc_val: 0.9001 - fe_auc: 0.9670 - fe_auc_val: 0.8938 - stds: 0.0940 - acceptance_rate: 5.9057e-10
#
#  Start sampling for epoch 70 of training
# Adapt step size to 0.0017747055971994996
# Epoch 70/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5682 - me_loss_val: 0.8048 - fe_loss: 0.6025 - fe_loss_val: 0.8355 - me_auc: 0.9723 - me_auc_val: 0.8997 - fe_auc: 0.9671 - fe_auc_val: 0.8936 - stds: 0.0816 - acceptance_rate: 0.7721
#
#  Start sampling for epoch 71 of training
# Adapt step size to 0.0011448622681200504
# Epoch 71/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5653 - me_loss_val: 0.8030 - fe_loss: 0.5992 - fe_loss_val: 0.8337 - me_auc: 0.9722 - me_auc_val: 0.9003 - fe_auc: 0.9672 - fe_auc_val: 0.8937 - stds: 0.0786 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 72 of training
# Adapt step size to 0.0025003373157233
# Epoch 72/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5621 - me_loss_val: 0.8006 - fe_loss: 0.5955 - fe_loss_val: 0.8307 - me_auc: 0.9725 - me_auc_val: 0.9000 - fe_auc: 0.9675 - fe_auc_val: 0.8939 - stds: 0.0766 - acceptance_rate: 0.0296
#
#  Start sampling for epoch 73 of training
# Adapt step size to 0.0016174936899915338
# Epoch 73/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5589 - me_loss_val: 0.7972 - fe_loss: 0.5917 - fe_loss_val: 0.8274 - me_auc: 0.9729 - me_auc_val: 0.9006 - fe_auc: 0.9679 - fe_auc_val: 0.8941 - stds: 0.0731 - acceptance_rate: 0.4358
#
#  Start sampling for epoch 74 of training
# Adapt step size to 0.0011011356255039573
# Epoch 74/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5558 - me_loss_val: 0.7941 - fe_loss: 0.5884 - fe_loss_val: 0.8245 - me_auc: 0.9734 - me_auc_val: 0.9007 - fe_auc: 0.9684 - fe_auc_val: 0.8945 - stds: 0.0612 - acceptance_rate: 0.1002
#
#  Start sampling for epoch 75 of training
# Adapt step size to 0.0014099797699600458
# Epoch 75/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.5527 - me_loss_val: 0.7914 - fe_loss: 0.5848 - fe_loss_val: 0.8228 - me_auc: 0.9738 - me_auc_val: 0.9011 - fe_auc: 0.9691 - fe_auc_val: 0.8942 - stds: 0.0620 - acceptance_rate: 0.8045
#
#  Start sampling for epoch 76 of training
# Adapt step size to 0.0010750530054792762
# Epoch 76/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5495 - me_loss_val: 0.7897 - fe_loss: 0.5812 - fe_loss_val: 0.8210 - me_auc: 0.9742 - me_auc_val: 0.9010 - fe_auc: 0.9694 - fe_auc_val: 0.8941 - stds: 0.0678 - acceptance_rate: 0.2171
#
#  Start sampling for epoch 77 of training
# Adapt step size to 0.0012840755516663194
# Epoch 77/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5466 - me_loss_val: 0.7885 - fe_loss: 0.5778 - fe_loss_val: 0.8201 - me_auc: 0.9744 - me_auc_val: 0.9014 - fe_auc: 0.9697 - fe_auc_val: 0.8936 - stds: 0.0671 - acceptance_rate: 0.0828
#
#  Start sampling for epoch 78 of training
# Adapt step size to 0.0011729109100997448
# Epoch 78/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5438 - me_loss_val: 0.7859 - fe_loss: 0.5747 - fe_loss_val: 0.8179 - me_auc: 0.9749 - me_auc_val: 0.9016 - fe_auc: 0.9700 - fe_auc_val: 0.8938 - stds: 0.0632 - acceptance_rate: 0.8788
#
#  Start sampling for epoch 79 of training
# Adapt step size to 0.0008755294256843626
# Epoch 79/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5417 - me_loss_val: 0.7842 - fe_loss: 0.5715 - fe_loss_val: 0.8158 - me_auc: 0.9750 - me_auc_val: 0.9020 - fe_auc: 0.9703 - fe_auc_val: 0.8947 - stds: 0.0636 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 80 of training
# Adapt step size to 0.0020620652940124273
# Epoch 80/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5392 - me_loss_val: 0.7826 - fe_loss: 0.5686 - fe_loss_val: 0.8136 - me_auc: 0.9751 - me_auc_val: 0.9021 - fe_auc: 0.9704 - fe_auc_val: 0.8951 - stds: 0.0674 - acceptance_rate: 2.2204e-09
#
#  Start sampling for epoch 81 of training
# Adapt step size to 0.0010515725007280707
# Epoch 81/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5374 - me_loss_val: 0.7812 - fe_loss: 0.5658 - fe_loss_val: 0.8116 - me_auc: 0.9749 - me_auc_val: 0.9024 - fe_auc: 0.9705 - fe_auc_val: 0.8951 - stds: 0.0722 - acceptance_rate: 0.2835
#
#  Start sampling for epoch 82 of training
# Adapt step size to 0.0006975494907237589
# Epoch 82/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.5354 - me_loss_val: 0.7807 - fe_loss: 0.5630 - fe_loss_val: 0.8100 - me_auc: 0.9750 - me_auc_val: 0.9024 - fe_auc: 0.9707 - fe_auc_val: 0.8956 - stds: 0.0704 - acceptance_rate: 0.8743
#
#  Start sampling for epoch 83 of training
# Adapt step size to 0.0007061072392389178
# Epoch 83/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5327 - me_loss_val: 0.7793 - fe_loss: 0.5599 - fe_loss_val: 0.8079 - me_auc: 0.9752 - me_auc_val: 0.9022 - fe_auc: 0.9710 - fe_auc_val: 0.8956 - stds: 0.0730 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 84 of training
# Adapt step size to 0.00039187289075925946
# Epoch 84/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.5304 - me_loss_val: 0.7781 - fe_loss: 0.5569 - fe_loss_val: 0.8063 - me_auc: 0.9755 - me_auc_val: 0.9022 - fe_auc: 0.9714 - fe_auc_val: 0.8960 - stds: 0.0718 - acceptance_rate: 0.4415
#
#  Start sampling for epoch 85 of training
# Adapt step size to 0.0006043299217708409
# Epoch 85/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.5279 - me_loss_val: 0.7774 - fe_loss: 0.5542 - fe_loss_val: 0.8043 - me_auc: 0.9759 - me_auc_val: 0.9022 - fe_auc: 0.9720 - fe_auc_val: 0.8968 - stds: 0.0724 - acceptance_rate: 0.1928
#
#  Start sampling for epoch 86 of training
# Adapt step size to 0.0007695010281167924
# Epoch 86/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5255 - me_loss_val: 0.7761 - fe_loss: 0.5515 - fe_loss_val: 0.8027 - me_auc: 0.9762 - me_auc_val: 0.9019 - fe_auc: 0.9723 - fe_auc_val: 0.8965 - stds: 0.0721 - acceptance_rate: 0.3150
#
#  Start sampling for epoch 87 of training
# Adapt step size to 0.0006821933784522116
# Epoch 87/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5222 - me_loss_val: 0.7756 - fe_loss: 0.5482 - fe_loss_val: 0.8023 - me_auc: 0.9766 - me_auc_val: 0.9013 - fe_auc: 0.9727 - fe_auc_val: 0.8959 - stds: 0.0705 - acceptance_rate: 0.5248
#
#  Start sampling for epoch 88 of training
# Adapt step size to 0.0007217550300993025
# Epoch 88/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5198 - me_loss_val: 0.7761 - fe_loss: 0.5454 - fe_loss_val: 0.8025 - me_auc: 0.9768 - me_auc_val: 0.9008 - fe_auc: 0.9728 - fe_auc_val: 0.8962 - stds: 0.0692 - acceptance_rate: 5.9194e-32
#
#  Start sampling for epoch 89 of training
# Adapt step size to 0.0010300129652023315
# Epoch 89/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.5173 - me_loss_val: 0.7763 - fe_loss: 0.5426 - fe_loss_val: 0.8027 - me_auc: 0.9768 - me_auc_val: 0.9015 - fe_auc: 0.9730 - fe_auc_val: 0.8960 - stds: 0.0690 - acceptance_rate: 2.5921e-16
#
#  Start sampling for epoch 90 of training
# Adapt step size to 0.0006939512095414102
# Epoch 90/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.5148 - me_loss_val: 0.7764 - fe_loss: 0.5397 - fe_loss_val: 0.8024 - me_auc: 0.9770 - me_auc_val: 0.9010 - fe_auc: 0.9731 - fe_auc_val: 0.8962 - stds: 0.0662 - acceptance_rate: 0.5222
#
#  Start sampling for epoch 91 of training
# Adapt step size to 0.0004693073278758675
# Epoch 91/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5127 - me_loss_val: 0.7746 - fe_loss: 0.5368 - fe_loss_val: 0.8007 - me_auc: 0.9771 - me_auc_val: 0.9013 - fe_auc: 0.9734 - fe_auc_val: 0.8964 - stds: 0.0658 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 92 of training
# Adapt step size to 0.00016251642955467105
# Epoch 92/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5108 - me_loss_val: 0.7731 - fe_loss: 0.5341 - fe_loss_val: 0.7990 - me_auc: 0.9773 - me_auc_val: 0.9013 - fe_auc: 0.9736 - fe_auc_val: 0.8967 - stds: 0.0626 - acceptance_rate: 0.0764
#
#  Start sampling for epoch 93 of training
# Adapt step size to 0.00045128626516088843
# Epoch 93/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5082 - me_loss_val: 0.7725 - fe_loss: 0.5310 - fe_loss_val: 0.7980 - me_auc: 0.9776 - me_auc_val: 0.9009 - fe_auc: 0.9740 - fe_auc_val: 0.8965 - stds: 0.0563 - acceptance_rate: 0.9411
#
#  Start sampling for epoch 94 of training
# Adapt step size to 0.0003420035354793072
# Epoch 94/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5062 - me_loss_val: 0.7723 - fe_loss: 0.5283 - fe_loss_val: 0.7983 - me_auc: 0.9779 - me_auc_val: 0.9011 - fe_auc: 0.9743 - fe_auc_val: 0.8963 - stds: 0.0520 - acceptance_rate: 0.8779
#
#  Start sampling for epoch 95 of training
# Adapt step size to 0.00036240729968994856
# Epoch 95/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5042 - me_loss_val: 0.7721 - fe_loss: 0.5257 - fe_loss_val: 0.7976 - me_auc: 0.9781 - me_auc_val: 0.9012 - fe_auc: 0.9746 - fe_auc_val: 0.8962 - stds: 0.0497 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 96 of training
# Adapt step size to 0.00020947837037965655
# Epoch 96/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.5023 - me_loss_val: 0.7721 - fe_loss: 0.5235 - fe_loss_val: 0.7971 - me_auc: 0.9781 - me_auc_val: 0.9011 - fe_auc: 0.9749 - fe_auc_val: 0.8964 - stds: 0.0452 - acceptance_rate: 0.7623
#
#  Start sampling for epoch 97 of training
# Adapt step size to 0.0003412789083085954
# Epoch 97/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.5005 - me_loss_val: 0.7739 - fe_loss: 0.5210 - fe_loss_val: 0.7976 - me_auc: 0.9783 - me_auc_val: 0.9009 - fe_auc: 0.9749 - fe_auc_val: 0.8963 - stds: 0.0478 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 98 of training
# Adapt step size to 0.0006651732255704701
# Epoch 98/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.4980 - me_loss_val: 0.7743 - fe_loss: 0.5182 - fe_loss_val: 0.7977 - me_auc: 0.9785 - me_auc_val: 0.9008 - fe_auc: 0.9753 - fe_auc_val: 0.8963 - stds: 0.0508 - acceptance_rate: 0.0895
#
#  Start sampling for epoch 99 of training
# Adapt step size to 0.00045602404861710966
# Epoch 99/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.4961 - me_loss_val: 0.7757 - fe_loss: 0.5155 - fe_loss_val: 0.7980 - me_auc: 0.9786 - me_auc_val: 0.9007 - fe_auc: 0.9755 - fe_auc_val: 0.8965 - stds: 0.0457 - acceptance_rate: 0.3825
#
#  Start sampling for epoch 100 of training
# Adapt step size to 0.00035414635203778744
# Epoch 100/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.4940 - me_loss_val: 0.7755 - fe_loss: 0.5131 - fe_loss_val: 0.7974 - me_auc: 0.9789 - me_auc_val: 0.9006 - fe_auc: 0.9757 - fe_auc_val: 0.8962 - stds: 0.0455 - acceptance_rate: 2.7961e-05
#
#  Start sampling for epoch 101 of training
# Adapt step size to 0.00038326563662849367
# Epoch 101/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.4918 - me_loss_val: 0.7745 - fe_loss: 0.5100 - fe_loss_val: 0.7954 - me_auc: 0.9791 - me_auc_val: 0.9007 - fe_auc: 0.9762 - fe_auc_val: 0.8961 - stds: 0.0437 - acceptance_rate: 0.1838
# Fold no. 1
# Random seed set as 555
#
#  Start sampling for epoch 1 of training
# Epoch 1/500
# 1/1 [==============================] - 6s 6s/step - me_loss: 2.1073 - me_loss_val: 5.5364 - fe_loss: 1.4370 - fe_loss_val: 5.1833 - me_auc: 0.6185 - me_auc_val: 0.6694 - fe_auc: 0.7530 - fe_auc_val: 0.6668 - stds: 0.9532 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 2 of training
# Adapt step size to 1.8861645460128784
# Epoch 2/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 1.3935 - me_loss_val: 4.9288 - fe_loss: 1.3121 - fe_loss_val: 4.9768 - me_auc: 0.7353 - me_auc_val: 0.7452 - fe_auc: 0.8229 - fe_auc_val: 0.7191 - stds: 0.9107 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 3 of training
# Adapt step size to 0.07890954613685608
# Epoch 3/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 1.1051 - me_loss_val: 4.2781 - fe_loss: 1.2339 - fe_loss_val: 4.4481 - me_auc: 0.8227 - me_auc_val: 0.7952 - fe_auc: 0.8523 - fe_auc_val: 0.7486 - stds: 0.9819 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 4 of training
# Adapt step size to 0.46754327416419983
# Epoch 4/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.9544 - me_loss_val: 4.1129 - fe_loss: 1.1828 - fe_loss_val: 4.2833 - me_auc: 0.8752 - me_auc_val: 0.8084 - fe_auc: 0.8672 - fe_auc_val: 0.7637 - stds: 0.8369 - acceptance_rate: 0.8533
#
#  Start sampling for epoch 5 of training
# Adapt step size to 0.17662160098552704
# Epoch 5/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.8851 - me_loss_val: 3.9552 - fe_loss: 1.1499 - fe_loss_val: 4.1569 - me_auc: 0.8973 - me_auc_val: 0.8208 - fe_auc: 0.8794 - fe_auc_val: 0.7743 - stds: 0.7766 - acceptance_rate: 0.9999
#
#  Start sampling for epoch 6 of training
# Adapt step size to 0.07852160930633545
# Epoch 6/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.8774 - me_loss_val: 3.8065 - fe_loss: 1.1277 - fe_loss_val: 4.0376 - me_auc: 0.9031 - me_auc_val: 0.8315 - fe_auc: 0.8883 - fe_auc_val: 0.7823 - stds: 0.7705 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 7 of training
# Adapt step size to 0.7114397287368774
# Epoch 7/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.8429 - me_loss_val: 3.5649 - fe_loss: 1.1102 - fe_loss_val: 3.8119 - me_auc: 0.9152 - me_auc_val: 0.8435 - fe_auc: 0.8965 - fe_auc_val: 0.7897 - stds: 0.6993 - acceptance_rate: 2.9161e-06
#
#  Start sampling for epoch 8 of training
# Adapt step size to 0.27670902013778687
# Epoch 8/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.8304 - me_loss_val: 3.1571 - fe_loss: 1.0963 - fe_loss_val: 3.4080 - me_auc: 0.9199 - me_auc_val: 0.8477 - fe_auc: 0.9030 - fe_auc_val: 0.7935 - stds: 0.6484 - acceptance_rate: 0.9802
#
#  Start sampling for epoch 9 of training
# Adapt step size to 0.11020845174789429
# Epoch 9/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.8030 - me_loss_val: 2.6713 - fe_loss: 1.0817 - fe_loss_val: 2.9164 - me_auc: 0.9269 - me_auc_val: 0.8474 - fe_auc: 0.9083 - fe_auc_val: 0.7974 - stds: 0.6244 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 10 of training
# Adapt step size to 0.04257037863135338
# Epoch 10/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7907 - me_loss_val: 2.1214 - fe_loss: 1.0667 - fe_loss_val: 2.3591 - me_auc: 0.9309 - me_auc_val: 0.8466 - fe_auc: 0.9134 - fe_auc_val: 0.8014 - stds: 0.5758 - acceptance_rate: 1.1816e-35
#
#  Start sampling for epoch 11 of training
# Adapt step size to 0.3646974265575409
# Epoch 11/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7882 - me_loss_val: 1.5665 - fe_loss: 1.0497 - fe_loss_val: 1.7799 - me_auc: 0.9290 - me_auc_val: 0.8427 - fe_auc: 0.9181 - fe_auc_val: 0.8050 - stds: 0.5403 - acceptance_rate: 0.9769
#
#  Start sampling for epoch 12 of training
# Adapt step size to 0.15184499323368073
# Epoch 12/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.7826 - me_loss_val: 1.0561 - fe_loss: 1.0331 - fe_loss_val: 1.2639 - me_auc: 0.9313 - me_auc_val: 0.8449 - fe_auc: 0.9208 - fe_auc_val: 0.8076 - stds: 0.5030 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 13 of training
# Adapt step size to 0.06092480942606926
# Epoch 13/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7760 - me_loss_val: 0.9820 - fe_loss: 1.0184 - fe_loss_val: 1.1871 - me_auc: 0.9331 - me_auc_val: 0.8620 - fe_auc: 0.9224 - fe_auc_val: 0.8235 - stds: 0.5023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 14 of training
# Adapt step size to 0.4694226384162903
# Epoch 14/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7765 - me_loss_val: 0.9767 - fe_loss: 1.0053 - fe_loss_val: 1.1777 - me_auc: 0.9335 - me_auc_val: 0.8614 - fe_auc: 0.9235 - fe_auc_val: 0.8250 - stds: 0.4744 - acceptance_rate: 0.7374
#
#  Start sampling for epoch 15 of training
# Adapt step size to 0.20358441770076752
# Epoch 15/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.7711 - me_loss_val: 0.9690 - fe_loss: 0.9929 - fe_loss_val: 1.1690 - me_auc: 0.9354 - me_auc_val: 0.8665 - fe_auc: 0.9244 - fe_auc_val: 0.8249 - stds: 0.4484 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 16 of training
# Adapt step size to 0.04397637024521828
# Epoch 16/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7629 - me_loss_val: 0.9562 - fe_loss: 0.9816 - fe_loss_val: 1.1609 - me_auc: 0.9376 - me_auc_val: 0.8698 - fe_auc: 0.9256 - fe_auc_val: 0.8261 - stds: 0.4142 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 17 of training
# Adapt step size to 0.30828943848609924
# Epoch 17/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7596 - me_loss_val: 0.9472 - fe_loss: 0.9714 - fe_loss_val: 1.1534 - me_auc: 0.9398 - me_auc_val: 0.8712 - fe_auc: 0.9271 - fe_auc_val: 0.8288 - stds: 0.3835 - acceptance_rate: 0.6325
#
#  Start sampling for epoch 18 of training
# Adapt step size to 0.1402227133512497
# Epoch 18/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7579 - me_loss_val: 0.9364 - fe_loss: 0.9609 - fe_loss_val: 1.1452 - me_auc: 0.9432 - me_auc_val: 0.8755 - fe_auc: 0.9283 - fe_auc_val: 0.8303 - stds: 0.3616 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 19 of training
# Adapt step size to 0.3449696898460388
# Epoch 19/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7562 - me_loss_val: 0.9414 - fe_loss: 0.9496 - fe_loss_val: 1.1367 - me_auc: 0.9437 - me_auc_val: 0.8715 - fe_auc: 0.9295 - fe_auc_val: 0.8314 - stds: 0.3480 - acceptance_rate: 0.0434
#
#  Start sampling for epoch 20 of training
# Adapt step size to 0.16050678491592407
# Epoch 20/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7495 - me_loss_val: 0.9396 - fe_loss: 0.9381 - fe_loss_val: 1.1278 - me_auc: 0.9437 - me_auc_val: 0.8726 - fe_auc: 0.9302 - fe_auc_val: 0.8344 - stds: 0.3351 - acceptance_rate: 0.7295
#
#  Start sampling for epoch 21 of training
# Adapt step size to 0.08537160605192184
# Epoch 21/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7460 - me_loss_val: 0.9405 - fe_loss: 0.9278 - fe_loss_val: 1.1203 - me_auc: 0.9460 - me_auc_val: 0.8723 - fe_auc: 0.9309 - fe_auc_val: 0.8347 - stds: 0.3237 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 22 of training
# Adapt step size to 0.2590813934803009
# Epoch 22/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7386 - me_loss_val: 0.9363 - fe_loss: 0.9181 - fe_loss_val: 1.1156 - me_auc: 0.9485 - me_auc_val: 0.8751 - fe_auc: 0.9321 - fe_auc_val: 0.8361 - stds: 0.3377 - acceptance_rate: 2.1405e-09
#
#  Start sampling for epoch 23 of training
# Adapt step size to 0.12514673173427582
# Epoch 23/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7307 - me_loss_val: 0.9302 - fe_loss: 0.9082 - fe_loss_val: 1.1123 - me_auc: 0.9501 - me_auc_val: 0.8762 - fe_auc: 0.9330 - fe_auc_val: 0.8357 - stds: 0.3322 - acceptance_rate: 0.6319
#
#  Start sampling for epoch 24 of training
# Adapt step size to 0.061702996492385864
# Epoch 24/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7262 - me_loss_val: 0.9279 - fe_loss: 0.8990 - fe_loss_val: 1.1097 - me_auc: 0.9510 - me_auc_val: 0.8760 - fe_auc: 0.9336 - fe_auc_val: 0.8360 - stds: 0.3285 - acceptance_rate: 3.3643e-21
#
#  Start sampling for epoch 25 of training
# Adapt step size to 0.14183638989925385
# Epoch 25/500
# 1/1 [==============================] - 2s 2s/step - me_loss: 0.7204 - me_loss_val: 0.9304 - fe_loss: 0.8902 - fe_loss_val: 1.1069 - me_auc: 0.9520 - me_auc_val: 0.8734 - fe_auc: 0.9340 - fe_auc_val: 0.8357 - stds: 0.3164 - acceptance_rate: 0.2419
#
#  Start sampling for epoch 26 of training
# Adapt step size to 0.07113233953714371
# Epoch 26/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7169 - me_loss_val: 0.9318 - fe_loss: 0.8812 - fe_loss_val: 1.1030 - me_auc: 0.9525 - me_auc_val: 0.8720 - fe_auc: 0.9346 - fe_auc_val: 0.8366 - stds: 0.2978 - acceptance_rate: 0.8605
#
#  Start sampling for epoch 27 of training
# Adapt step size to 0.06399407237768173
# Epoch 27/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7097 - me_loss_val: 0.9278 - fe_loss: 0.8716 - fe_loss_val: 1.0986 - me_auc: 0.9534 - me_auc_val: 0.8731 - fe_auc: 0.9352 - fe_auc_val: 0.8361 - stds: 0.2754 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 28 of training
# Adapt step size to 0.023903822526335716
# Epoch 28/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.7045 - me_loss_val: 0.9268 - fe_loss: 0.8623 - fe_loss_val: 1.0929 - me_auc: 0.9542 - me_auc_val: 0.8723 - fe_auc: 0.9361 - fe_auc_val: 0.8367 - stds: 0.2541 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 29 of training
# Adapt step size to 0.12322913855314255
# Epoch 29/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.7011 - me_loss_val: 0.9212 - fe_loss: 0.8541 - fe_loss_val: 1.0880 - me_auc: 0.9544 - me_auc_val: 0.8737 - fe_auc: 0.9369 - fe_auc_val: 0.8378 - stds: 0.2613 - acceptance_rate: 0.5860
#
#  Start sampling for epoch 30 of training
# Adapt step size to 0.06402868777513504
# Epoch 30/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6960 - me_loss_val: 0.9260 - fe_loss: 0.8467 - fe_loss_val: 1.0848 - me_auc: 0.9551 - me_auc_val: 0.8709 - fe_auc: 0.9372 - fe_auc_val: 0.8387 - stds: 0.2516 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 31 of training
# Adapt step size to 0.12457892298698425
# Epoch 31/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6931 - me_loss_val: 0.9247 - fe_loss: 0.8403 - fe_loss_val: 1.0829 - me_auc: 0.9556 - me_auc_val: 0.8697 - fe_auc: 0.9373 - fe_auc_val: 0.8375 - stds: 0.2446 - acceptance_rate: 0.2257
#
#  Start sampling for epoch 32 of training
# Adapt step size to 0.06570450216531754
# Epoch 32/500
# 1/1 [==============================] - 4s 4s/step - me_loss: 0.6892 - me_loss_val: 0.9241 - fe_loss: 0.8338 - fe_loss_val: 1.0821 - me_auc: 0.9557 - me_auc_val: 0.8697 - fe_auc: 0.9376 - fe_auc_val: 0.8360 - stds: 0.2417 - acceptance_rate: 0.6128
#
#  Start sampling for epoch 33 of training
# Adapt step size to 0.05743592977523804
# Epoch 33/500
# 1/1 [==============================] - 3s 3s/step - me_loss: 0.6843 - me_loss_val: 0.9286 - fe_loss: 0.8275 - fe_loss_val: 1.0811 - me_auc: 0.9561 - me_auc_val: 0.8695 - fe_auc: 0.9382 - fe_auc_val: 0.8356 - stds: 0.2329 - acceptance_rate: 0.2250
#
#  Start sampling for epoch 34 of training
# Adapt step size to 0.05164440721273422
# Epoch 34/500
# 1/1 [==============================] - 5s 5s/step - me_loss: 0.6818 - me_loss_val: 0.9325 - fe_loss: 0.8221 - fe_loss_val: 1.0795 - me_auc: 0.9560 - me_auc_val: 0.8664 - fe_auc: 0.9386 - fe_auc_val: 0.8359 - stds: 0.2499 - acceptance_rate: 0.0515
#
#  Start sampling for epoch 35 of training
# Adapt step size to 0.045316439121961594
# Epoch 35/500
# ...
# Adapt step size to 2.8617552771947885e-08
# Epoch 13/500
# 120/120 [==============================] - 12s 101ms/step - me_loss: 0.9075 - me_loss_val: 1.0120 - fe_loss: 0.8874 - fe_loss_val: 0.9501 - me_auc: 0.6940 - me_auc_val: 0.6326 - fe_auc: 0.6775 - fe_auc_val: 0.6266 - stds: 0.8232 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 14 of training
# Adapt step size to 2.791007602809259e-07
# Epoch 14/500
# 120/120 [==============================] - 11s 95ms/step - me_loss: 0.9111 - me_loss_val: 1.0214 - fe_loss: 0.8912 - fe_loss_val: 0.9596 - me_auc: 0.6989 - me_auc_val: 0.6378 - fe_auc: 0.6810 - fe_auc_val: 0.6300 - stds: 0.8232 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 15 of training
# Adapt step size to 2.559943368396489e-06
# Epoch 15/500
# 120/120 [==============================] - 12s 99ms/step - me_loss: 0.9101 - me_loss_val: 1.0290 - fe_loss: 0.8911 - fe_loss_val: 0.9681 - me_auc: 0.6997 - me_auc_val: 0.6344 - fe_auc: 0.6831 - fe_auc_val: 0.6257 - stds: 0.8232 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 16 of training
# Adapt step size to 1.3797497331324848e-06
# Epoch 16/500
# 120/120 [==============================] - 12s 103ms/step - me_loss: 0.9180 - me_loss_val: 1.0465 - fe_loss: 0.9024 - fe_loss_val: 0.9891 - me_auc: 0.7022 - me_auc_val: 0.6343 - fe_auc: 0.6822 - fe_auc_val: 0.6225 - stds: 0.8232 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 17 of training
# Adapt step size to 5.022192439696482e-08
# Epoch 17/500
# 120/120 [==============================] - 13s 106ms/step - me_loss: 0.9024 - me_loss_val: 1.0375 - fe_loss: 0.8841 - fe_loss_val: 0.9777 - me_auc: 0.7007 - me_auc_val: 0.6241 - fe_auc: 0.6858 - fe_auc_val: 0.6128 - stds: 0.8232 - acceptance_rate: 0.0000e+00
#  Start sampling for epoch 18 of training
# Adapt step size to 2.0350161555882096e-09
# Epoch 18/500
# 120/120 [==============================] - 11s 88ms/step - me_loss: 0.9067 - me_loss_val: 1.0485 - fe_loss: 0.8882 - fe_loss_val: 0.9894 - me_auc: 0.7078 - me_auc_val: 0.6337 - fe_auc: 0.6917 - fe_auc_val: 0.6224 - stds: 0.8232 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 19 of training
# Adapt step size to 1.264809701417846e-09
# Epoch 19/500
# 120/120 [==============================] - 12s 98ms/step - me_loss: 0.8982 - me_loss_val: 1.0540 - fe_loss: 0.8820 - fe_loss_val: 0.9981 - me_auc: 0.7133 - me_auc_val: 0.6330 - fe_auc: 0.6973 - fe_auc_val: 0.6204 - stds: 0.8232 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 20 of training
# Adapt step size to 7.964299220120097e-10
# Epoch 20/500
# 120/120 [==============================] - 13s 107ms/step - me_loss: 0.8901 - me_loss_val: 1.0490 - fe_loss: 0.8721 - fe_loss_val: 0.9907 - me_auc: 0.7162 - me_auc_val: 0.6324 - fe_auc: 0.7031 - fe_auc_val: 0.6215 - stds: 0.8232 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 21 of training
# Adapt step size to 5.075023179479388e-10
# Epoch 21/500
# 120/120 [==============================] - 12s 99ms/step - me_loss: 0.8784 - me_loss_val: 1.0489 - fe_loss: 0.8593 - fe_loss_val: 0.9901 - me_auc: 0.7209 - me_auc_val: 0.6312 - fe_auc: 0.7089 - fe_auc_val: 0.6181 - stds: 0.8232 - acceptance_rate: 0.9905
#
#  Start sampling for epoch 22 of training
# Adapt step size to 4.027215450008725e-09
# Epoch 22/500
# 120/120 [==============================] - 12s 98ms/step - me_loss: 0.8778 - me_loss_val: 1.0585 - fe_loss: 0.8589 - fe_loss_val: 1.0007 - me_auc: 0.7245 - me_auc_val: 0.6319 - fe_auc: 0.7131 - fe_auc_val: 0.6187 - stds: 0.8232 - acceptance_rate: 0.9971
#
#  Start sampling for epoch 23 of training
# Adapt step size to 2.931386156035387e-08
# Epoch 23/500
# 120/120 [==============================] - 13s 107ms/step - me_loss: 0.8721 - me_loss_val: 1.0639 - fe_loss: 0.8542 - fe_loss_val: 1.0065 - me_auc: 0.7266 - me_auc_val: 0.6297 - fe_auc: 0.7149 - fe_auc_val: 0.6166 - stds: 0.8232 - acceptance_rate: 0.9936
#
#  Start sampling for epoch 24 of training
# Adapt step size to 2.0438756109797396e-07
# Epoch 24/500
# 120/120 [==============================] - 13s 104ms/step - me_loss: 0.8635 - me_loss_val: 1.0603 - fe_loss: 0.8432 - fe_loss_val: 1.0014 - me_auc: 0.7320 - me_auc_val: 0.6284 - fe_auc: 0.7231 - fe_auc_val: 0.6145 - stds: 0.8232 - acceptance_rate: 0.9978
#
#  Start sampling for epoch 25 of training
# Adapt step size to 1.3360180446397862e-06
# Epoch 25/500
# 120/120 [==============================] - ETA: 0s
#  Early stopping of FE by fe_auc_val at 25 epochs
# 120/120 [==============================] - 11s 89ms/step - me_loss: 0.8573 - me_loss_val: 1.0677 - fe_loss: 0.8371 - fe_loss_val: 1.0099 - me_auc: 0.7359 - me_auc_val: 0.6299 - fe_auc: 0.7273 - fe_auc_val: 0.6170 - stds: 0.8233 - acceptance_rate: 1.0000
# Fold no. 4
# Random seed set as 555
#
#  Start sampling for epoch 1 of training
# Epoch 1/500
# 120/120 [==============================] - 13s 98ms/step - me_loss: 2.1925 - me_loss_val: 2.2007 - fe_loss: 1.0248 - fe_loss_val: 1.0203 - me_auc: 0.5259 - me_auc_val: 0.5201 - fe_auc: 0.6050 - fe_auc_val: 0.5984 - stds: 0.9986 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 2 of training
# Adapt step size to 0.30616337060928345
# Epoch 2/500
# 120/120 [==============================] - 11s 94ms/step - me_loss: 1.5703 - me_loss_val: 1.5867 - fe_loss: 0.9993 - fe_loss_val: 0.9981 - me_auc: 0.5548 - me_auc_val: 0.5490 - fe_auc: 0.6237 - fe_auc_val: 0.6138 - stds: 0.9437 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 3 of training
# Adapt step size to 0.0054937382228672504
# Epoch 3/500
# 120/120 [==============================] - 12s 99ms/step - me_loss: 1.3856 - me_loss_val: 1.4087 - fe_loss: 1.0112 - fe_loss_val: 1.0139 - me_auc: 0.5816 - me_auc_val: 0.5747 - fe_auc: 0.6381 - fe_auc_val: 0.6258 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 4 of training
# Adapt step size to 0.023714061826467514
# Epoch 4/500
# 120/120 [==============================] - 11s 94ms/step - me_loss: 1.3129 - me_loss_val: 1.3439 - fe_loss: 0.9990 - fe_loss_val: 1.0102 - me_auc: 0.6042 - me_auc_val: 0.5949 - fe_auc: 0.6444 - fe_auc_val: 0.6275 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 5 of training
# Adapt step size to 0.00034948758548125625
# Epoch 5/500
# 120/120 [==============================] - 13s 107ms/step - me_loss: 1.2856 - me_loss_val: 1.3175 - fe_loss: 0.9839 - fe_loss_val: 1.0008 - me_auc: 0.6120 - me_auc_val: 0.6005 - fe_auc: 0.6476 - fe_auc_val: 0.6276 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 6 of training
# Adapt step size to 5.09976325702155e-06
# Epoch 6/500
# 120/120 [==============================] - 12s 99ms/step - me_loss: 1.2811 - me_loss_val: 1.3189 - fe_loss: 1.0177 - fe_loss_val: 1.0384 - me_auc: 0.6171 - me_auc_val: 0.6038 - fe_auc: 0.6520 - fe_auc_val: 0.6298 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 7 of training
# Adapt step size to 8.320169087028262e-08
# Epoch 7/500
# 120/120 [==============================] - 13s 109ms/step - me_loss: 1.2910 - me_loss_val: 1.3338 - fe_loss: 1.0218 - fe_loss_val: 1.0473 - me_auc: 0.6203 - me_auc_val: 0.6060 - fe_auc: 0.6553 - fe_auc_val: 0.6311 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 8 of training
# Adapt step size to 1.5841800093951974e-09
# Epoch 8/500
# 120/120 [==============================] - 12s 97ms/step - me_loss: 1.2798 - me_loss_val: 1.3312 - fe_loss: 1.0093 - fe_loss_val: 1.0440 - me_auc: 0.6228 - me_auc_val: 0.6057 - fe_auc: 0.6596 - fe_auc_val: 0.6298 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 9 of training
# Adapt step size to 3.558946887194381e-11
# Epoch 9/500
# 120/120 [==============================] - 11s 93ms/step - me_loss: 1.2935 - me_loss_val: 1.3460 - fe_loss: 1.0284 - fe_loss_val: 1.0640 - me_auc: 0.6242 - me_auc_val: 0.6057 - fe_auc: 0.6577 - fe_auc_val: 0.6279 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 10 of training
# Adapt step size to 9.408435402286086e-13
# Epoch 10/500
# 120/120 [==============================] - 10s 84ms/step - me_loss: 1.2877 - me_loss_val: 1.3482 - fe_loss: 1.0082 - fe_loss_val: 1.0508 - me_auc: 0.6226 - me_auc_val: 0.6024 - fe_auc: 0.6599 - fe_auc_val: 0.6239 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 11 of training
# Adapt step size to 2.902452583830595e-14
# Epoch 11/500
# 120/120 [==============================] - 12s 99ms/step - me_loss: 1.2708 - me_loss_val: 1.3419 - fe_loss: 0.9881 - fe_loss_val: 1.0416 - me_auc: 0.6271 - me_auc_val: 0.6034 - fe_auc: 0.6644 - fe_auc_val: 0.6237 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 12 of training
# Adapt step size to 1.034028705250488e-15
# Epoch 12/500
# 120/120 [==============================] - 13s 107ms/step - me_loss: 1.2633 - me_loss_val: 1.3397 - fe_loss: 1.0067 - fe_loss_val: 1.0652 - me_auc: 0.6343 - me_auc_val: 0.6086 - fe_auc: 0.6724 - fe_auc_val: 0.6307 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 13 of training
# Adapt step size to 7.698802100998135e-16
# Epoch 13/500
# 120/120 [==============================] - 13s 105ms/step - me_loss: 1.2625 - me_loss_val: 1.3488 - fe_loss: 0.9906 - fe_loss_val: 1.0582 - me_auc: 0.6347 - me_auc_val: 0.6050 - fe_auc: 0.6740 - fe_auc_val: 0.6256 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 14 of training
# Adapt step size to 1.0221461670774021e-14
# Epoch 14/500
# 120/120 [==============================] - 12s 104ms/step - me_loss: 1.2559 - me_loss_val: 1.3508 - fe_loss: 0.9959 - fe_loss_val: 1.0721 - me_auc: 0.6349 - me_auc_val: 0.6029 - fe_auc: 0.6735 - fe_auc_val: 0.6190 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 15 of training
# Adapt step size to 1.2531463497097994e-13
# Epoch 15/500
# 120/120 [==============================] - 12s 97ms/step - me_loss: 1.2572 - me_loss_val: 1.3604 - fe_loss: 0.9805 - fe_loss_val: 1.0638 - me_auc: 0.6386 - me_auc_val: 0.6033 - fe_auc: 0.6781 - fe_auc_val: 0.6217 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 16 of training
# Adapt step size to 1.417574282784606e-12
# Epoch 16/500
# 120/120 [==============================] - 13s 108ms/step - me_loss: 1.2637 - me_loss_val: 1.3789 - fe_loss: 1.0051 - fe_loss_val: 1.1008 - me_auc: 0.6437 - me_auc_val: 0.6055 - fe_auc: 0.6815 - fe_auc_val: 0.6225 - stds: 0.9023 - acceptance_rate: 2.4287e-35
#
#  Start sampling for epoch 17 of training
# Adapt step size to 9.798053210788304e-13
# Epoch 17/500
# 120/120 [==============================] - 12s 101ms/step - me_loss: 1.2559 - me_loss_val: 1.3811 - fe_loss: 1.0424 - fe_loss_val: 1.1446 - me_auc: 0.6463 - me_auc_val: 0.6051 - fe_auc: 0.6869 - fe_auc_val: 0.6226 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 18 of training
# Adapt step size to 4.7345394477756736e-14
# Epoch 18/500
# 120/120 [==============================] - 13s 106ms/step - me_loss: 1.2476 - me_loss_val: 1.3811 - fe_loss: 0.9749 - fe_loss_val: 1.0872 - me_auc: 0.6482 - me_auc_val: 0.6047 - fe_auc: 0.6887 - fe_auc_val: 0.6192 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 19 of training
# Adapt step size to 3.4871306282000317e-14
# Epoch 19/500
# 120/120 [==============================] - 14s 118ms/step - me_loss: 1.2326 - me_loss_val: 1.3797 - fe_loss: 0.9870 - fe_loss_val: 1.1120 - me_auc: 0.6484 - me_auc_val: 0.6010 - fe_auc: 0.6929 - fe_auc_val: 0.6157 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 20 of training
# Adapt step size to 3.4415070619686627e-13
# Epoch 20/500
# 120/120 [==============================] - 11s 92ms/step - me_loss: 1.2232 - me_loss_val: 1.3759 - fe_loss: 0.9334 - fe_loss_val: 1.0622 - me_auc: 0.6509 - me_auc_val: 0.6013 - fe_auc: 0.6971 - fe_auc_val: 0.6159 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 21 of training
# Adapt step size to 3.1571787285217257e-12
# Epoch 21/500
# 120/120 [==============================] - 11s 93ms/step - me_loss: 1.2011 - me_loss_val: 1.3675 - fe_loss: 0.9580 - fe_loss_val: 1.1025 - me_auc: 0.6590 - me_auc_val: 0.6037 - fe_auc: 0.7057 - fe_auc_val: 0.6175 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 22 of training
# Adapt step size to 2.702159156153794e-11
# Epoch 22/500
# 120/120 [==============================] - 12s 98ms/step - me_loss: 1.2262 - me_loss_val: 1.4042 - fe_loss: 0.9828 - fe_loss_val: 1.1353 - me_auc: 0.6602 - me_auc_val: 0.6029 - fe_auc: 0.7025 - fe_auc_val: 0.6168 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 23 of training
# Adapt step size to 2.16544435160948e-10
# Epoch 23/500
# 120/120 [==============================] - 11s 96ms/step - me_loss: 1.1906 - me_loss_val: 1.3810 - fe_loss: 0.9098 - fe_loss_val: 1.0742 - me_auc: 0.6598 - me_auc_val: 0.5982 - fe_auc: 0.7126 - fe_auc_val: 0.6120 - stds: 0.9023 - acceptance_rate: 0.0000e+00
#
#  Start sampling for epoch 24 of training
# Adapt step size to 1.422079259905118e-10
# Epoch 24/500
# 120/120 [==============================] - 11s 91ms/step - me_loss: 1.1918 - me_loss_val: 1.4068 - fe_loss: 0.9487 - fe_loss_val: 1.1367 - me_auc: 0.6692 - me_auc_val: 0.6019 - fe_auc: 0.7160 - fe_auc_val: 0.6135 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 25 of training
# Adapt step size to 9.420800944903718e-11
# Epoch 25/500
# 120/120 [==============================] - 13s 107ms/step - me_loss: 1.1809 - me_loss_val: 1.3989 - fe_loss: 0.9195 - fe_loss_val: 1.1099 - me_auc: 0.6715 - me_auc_val: 0.6025 - fe_auc: 0.7207 - fe_auc_val: 0.6143 - stds: 0.9023 - acceptance_rate: 9.1110e-31
#
#  Start sampling for epoch 26 of training
# Adapt step size to 6.292014131936696e-11
# Epoch 26/500
# 120/120 [==============================] - 10s 84ms/step - me_loss: 1.1751 - me_loss_val: 1.4032 - fe_loss: 0.9155 - fe_loss_val: 1.1150 - me_auc: 0.6730 - me_auc_val: 0.6008 - fe_auc: 0.7239 - fe_auc_val: 0.6132 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 27 of training
# Adapt step size to 4.2345599249316024e-11
# Epoch 27/500
# 116/120 [============================>.] - ETA: 0s
#  Early stopping of FE by fe_auc_val at 27 epochs
# 120/120 [==============================] - 11s 94ms/step - me_loss: 1.1615 - me_loss_val: 1.4080 - fe_loss: 0.9136 - fe_loss_val: 1.1291 - me_auc: 0.6791 - me_auc_val: 0.6012 - fe_auc: 0.7297 - fe_auc_val: 0.6117 - stds: 0.9023 - acceptance_rate: 0.9957
#
#  Start sampling for epoch 28 of training
# Adapt step size to 2.895126915980484e-10
# Epoch 28/500
# 120/120 [==============================] - 4s 32ms/step - me_loss: 1.1615 - me_loss_val: 1.4080 - fe_loss: 0.9136 - fe_loss_val: 1.1291 - me_auc: 0.6791 - me_auc_val: 0.6012 - fe_auc: 0.7297 - fe_auc_val: 0.6117 - stds: 0.9023 - acceptance_rate: 0.9997
#
#  Start sampling for epoch 29 of training
# Adapt step size to 1.8613408592216274e-09
# Epoch 29/500
# 120/120 [==============================] - 4s 36ms/step - me_loss: 1.1615 - me_loss_val: 1.4080 - fe_loss: 0.9136 - fe_loss_val: 1.1291 - me_auc: 0.6791 - me_auc_val: 0.6012 - fe_auc: 0.7297 - fe_auc_val: 0.6117 - stds: 0.9023 - acceptance_rate: 1.0000
#
#  Start sampling for epoch 30 of training
# Adapt step size to 1.1497792051784472e-08
# Epoch 30/500
# 120/120 [==============================] - 4s 31ms/step - me_loss: 1.1615 - me_loss_val: 1.4080 - fe_loss: 0.9136 - fe_loss_val: 1.1291 - me_auc: 0.6791 - me_auc_val: 0.6012 - fe_auc: 0.7297 - fe_auc_val: 0.6117 - stds: 0.9023 - acceptance_rate: 0.9653
#
#  Start sampling for epoch 31 of training
# Adapt step size to 6.37013926052532e-08
# Epoch 31/500
# 120/120 [==============================] - 5s 41ms/step - me_loss: 1.1615 - me_loss_val: 1.4080 - fe_loss: 0.9136 - fe_loss_val: 1.1291 - me_auc: 0.6791 - me_auc_val: 0.6012 - fe_auc: 0.7297 - fe_auc_val: 0.6117 - stds: 0.9023 - acceptance_rate: 0.9875
#
#  Start sampling for epoch 32 of training
# Adapt step size to 3.105009511727985e-07
# Epoch 32/500
# 120/120 [==============================] - 4s 38ms/step - me_loss: 1.1614 - me_loss_val: 1.4080 - fe_loss: 0.9136 - fe_loss_val: 1.1291 - me_auc: 0.6791 - me_auc_val: 0.6012 - fe_auc: 0.7297 - fe_auc_val: 0.6117 - stds: 0.9023 - acceptance_rate: 0.9865

# %% [markdown]
# ## Evaluation
#
# ### Performance

# %%
models = ["GMENN", "TE", "OHE", "Embedding","Ignore"]

results_perf = {dataset_name: {num: {model: {}  for model in models} for num in range(folds)} for dataset_name in dataset_names}
for dataset_name in dataset_names:
    try:
        with open(f"../data/prepared/{dataset_name}/{data_path}/data_dict.pickle", 'rb') as handle:
            data_dict = pickle.load(handle)        
    except:
        print(f"dataset {dataset_name} not found") 
    for num in range(folds):
        y_test = data_dict[f"y_test_{num}"]
        n_classes = np.unique(y_test).shape[0]
        y_test = tf.one_hot(data_dict[f"y_test_{num}"],n_classes)
        for model in models:
            try:
                y_pred = results[dataset_name][num]["predictions"][model][2]

                results_perf[dataset_name][num][model] = get_metrics(y_test,y_pred,target)
                results_perf[dataset_name][num][model]["Time"] = results[dataset_name][num]["times"][model]
            except:
                print(f"Set nan for {dataset_name}, {num}")
                results_perf[dataset_name][num][model] = {"Accuracy": np.nan,
                                                          "AUROC": np.nan,
                                                          "F1": np.nan,
                                                          "Time": np.nan}
#                 print(f"Didnt work for {dataset_name}, {num}")
# Out:
# Set nan for eucalyptus, 0
# Set nan for eucalyptus, 0
# Set nan for eucalyptus, 0
# Set nan for eucalyptus, 0
# Set nan for eucalyptus, 1
# Set nan for eucalyptus, 1
# Set nan for eucalyptus, 1
# Set nan for eucalyptus, 1
# Set nan for eucalyptus, 2
# Set nan for eucalyptus, 2
# Set nan for eucalyptus, 2
# Set nan for eucalyptus, 2
# Set nan for eucalyptus, 3
# Set nan for eucalyptus, 3
# Set nan for eucalyptus, 3
# Set nan for eucalyptus, 3
# Set nan for eucalyptus, 4
# Set nan for eucalyptus, 4
# Set nan for eucalyptus, 4
# Set nan for eucalyptus, 4
# Set nan for Midwest_survey, 0
# Set nan for Midwest_survey, 0
# Set nan for Midwest_survey, 0
# Set nan for Midwest_survey, 0
# Set nan for Midwest_survey, 1
# Set nan for Midwest_survey, 1
# Set nan for Midwest_survey, 1
# Set nan for Midwest_survey, 1
# Set nan for Midwest_survey, 2
# Set nan for Midwest_survey, 2
# Set nan for Midwest_survey, 2
# Set nan for Midwest_survey, 2
# Set nan for Midwest_survey, 3
# Set nan for Midwest_survey, 3
# Set nan for Midwest_survey, 3
# Set nan for Midwest_survey, 3
# Set nan for Midwest_survey, 4
# Set nan for Midwest_survey, 4
# Set nan for Midwest_survey, 4
# Set nan for Midwest_survey, 4
# Set nan for hpc-job-scheduling, 0
# Set nan for hpc-job-scheduling, 0
# Set nan for hpc-job-scheduling, 0
# Set nan for hpc-job-scheduling, 0
# Set nan for hpc-job-scheduling, 1
# Set nan for hpc-job-scheduling, 1
# Set nan for hpc-job-scheduling, 1
# Set nan for hpc-job-scheduling, 1
# Set nan for hpc-job-scheduling, 2
# Set nan for hpc-job-scheduling, 2
# Set nan for hpc-job-scheduling, 2
# Set nan for hpc-job-scheduling, 2
# Set nan for hpc-job-scheduling, 3
# Set nan for hpc-job-scheduling, 3
# Set nan for hpc-job-scheduling, 3
# Set nan for hpc-job-scheduling, 3
# Set nan for hpc-job-scheduling, 4
# Set nan for hpc-job-scheduling, 4
# Set nan for hpc-job-scheduling, 4
# Set nan for hpc-job-scheduling, 4
# Set nan for video-game-sales, 0
# Set nan for video-game-sales, 0
# Set nan for video-game-sales, 0
# Set nan for video-game-sales, 0
# Set nan for video-game-sales, 1
# Set nan for video-game-sales, 1
# Set nan for video-game-sales, 1
# Set nan for video-game-sales, 1
# Set nan for video-game-sales, 2
# Set nan for video-game-sales, 2
# Set nan for video-game-sales, 2
# Set nan for video-game-sales, 2
# Set nan for video-game-sales, 3
# Set nan for video-game-sales, 3
# Set nan for video-game-sales, 3
# Set nan for video-game-sales, 3
# Set nan for video-game-sales, 4
# Set nan for video-game-sales, 4
# Set nan for video-game-sales, 4
# Set nan for video-game-sales, 4
# Set nan for okcupid-stem, 0
# Set nan for okcupid-stem, 0
# Set nan for okcupid-stem, 0
# Set nan for okcupid-stem, 0
# Set nan for okcupid-stem, 1
# Set nan for okcupid-stem, 1
# Set nan for okcupid-stem, 1
# Set nan for okcupid-stem, 1
# Set nan for okcupid-stem, 2
# Set nan for okcupid-stem, 2
# Set nan for okcupid-stem, 2
# Set nan for okcupid-stem, 2
# Set nan for okcupid-stem, 3
# Set nan for okcupid-stem, 3
# Set nan for okcupid-stem, 3
# Set nan for okcupid-stem, 3
# Set nan for okcupid-stem, 4
# Set nan for okcupid-stem, 4
# Set nan for okcupid-stem, 4
# Set nan for okcupid-stem, 4
# Set nan for Diabetes130US, 0
# Set nan for Diabetes130US, 0
# Set nan for Diabetes130US, 0
# Set nan for Diabetes130US, 0
# Set nan for Diabetes130US, 1
# Set nan for Diabetes130US, 1
# Set nan for Diabetes130US, 1
# Set nan for Diabetes130US, 1
# Set nan for Diabetes130US, 2
# Set nan for Diabetes130US, 2
# Set nan for Diabetes130US, 2
# Set nan for Diabetes130US, 2
# Set nan for Diabetes130US, 3
# Set nan for Diabetes130US, 3
# Set nan for Diabetes130US, 3
# Set nan for Diabetes130US, 3
# Set nan for Diabetes130US, 4
# Set nan for Diabetes130US, 4
# Set nan for Diabetes130US, 4
# Set nan for Diabetes130US, 4

# %%
models = ["GMENN", "TE", "OHE", "Embedding", "Ignore"]

metric = "AUROC"

#####
dataset_res_dict = {}
best_models = {}
t_test_results = {}

round_mean_at = 2
round_std_at = 3

for dataset_name in dataset_names:
    dataset_models = list(results_perf[dataset_name][0].keys())
    use_df = pd.DataFrame([pd.DataFrame(results_perf[dataset_name][fold_num]).loc[metric,models] for fold_num in results_perf[dataset_name].keys()],index=results_perf[dataset_name].keys())
    
    df_mean = pd.DataFrame(use_df.mean(axis=0).round(round_mean_at).astype(str) + " (" + use_df.std(axis=0).round(round_std_at).astype(str) + ")").transpose()
    model_dict = {i: df_mean[i].values[0] for i in df_mean.columns}
    dataset_res_dict[dataset_name] = model_dict
    
    best_models[dataset_name] = use_df.columns[use_df.mean(axis=0).argmax()]

    t_test_res = np.array([stats.ttest_rel(use_df[best_models[dataset_name]].values, use_df[model].values)[1] if model in dataset_models else 0 for model in models]).round(3)
    t_test_res[np.isnan(t_test_res)] = 1.
    t_test_results[dataset_name] = t_test_res
    
res_df = pd.DataFrame(dataset_res_dict).transpose()
    
def negative_bold(val):
    i = np.where(val.name==np.array(models))[0][0]
    return ["font-weight: bold"  if t_test_results[dataset_name][i]>=0.05 else "" for dataset_name in val.keys()]
    # Case without transpose:
#     return ["font-weight: bold"  if t_test_results[val.name][i]>=0.05 else "" for i in range(len(val))]

# res_df.style.apply(negative_bold)
res_df
# Out:
#                            GMENN         TE        OHE  Embedding     Ignore
# eucalyptus           0.89 (0.03)  nan (nan)  nan (nan)  nan (nan)  nan (nan)
# Midwest_survey      0.88 (0.008)  nan (nan)  nan (nan)  nan (nan)  nan (nan)
# hpc-job-scheduling  0.91 (0.007)  nan (nan)  nan (nan)  nan (nan)  nan (nan)
# video-game-sales    0.78 (0.008)  nan (nan)  nan (nan)  nan (nan)  nan (nan)
# okcupid-stem        0.75 (0.037)  nan (nan)  nan (nan)  nan (nan)  nan (nan)
# Diabetes130US       0.62 (0.015)  nan (nan)  nan (nan)  nan (nan)  nan (nan)

# %%
res_df["GMENN"].apply(lambda x: float(x.split(" ")[0])).values
# Out:
# array([0.89, 0.88, 0.91, 0.78, 0.75, 0.62])

# %% [markdown]
# ### Time

# %%
models = ["GMENN", "TE", "OHE", "Embedding", "Ignore"]
metric = "Time"

#####
dataset_res_dict = {}
best_models = {}
t_test_results = {}

round_mean_at = 2
round_std_at = 3

for dataset_name in dataset_names:
    dataset_models = list(results_perf[dataset_name][0].keys())
    use_df = pd.DataFrame([pd.DataFrame(results_perf[dataset_name][fold_num]).loc[metric,models] for fold_num in results_perf[dataset_name].keys()],index=results_perf[dataset_name].keys())/60
    
    df_mean = pd.DataFrame(use_df.mean(axis=0).round(round_mean_at).astype(str) + " (" + use_df.std(axis=0).round(round_std_at).astype(str) + ")").transpose()
    model_dict = {i: df_mean[i].values[0] for i in df_mean.columns}
    dataset_res_dict[dataset_name] = model_dict
    
    best_models[dataset_name] = use_df.columns[use_df.mean(axis=0).argmin()]

    t_test_res = np.array([stats.ttest_rel(use_df[best_models[dataset_name]].values, use_df[model].values)[1] if model in dataset_models else 0 for model in models]).round(3)
    t_test_res[np.isnan(t_test_res)] = 1.
    t_test_results[dataset_name] = t_test_res
    
res_df = pd.DataFrame(dataset_res_dict).transpose()
    
def negative_bold(val):
    i = np.where(val.name==np.array(models))[0][0]
    return ["font-weight: bold"  if t_test_results[dataset_name][i]>=0.05 else "" for dataset_name in val.keys()]
    # Case without transpose:
#     return ["font-weight: bold"  if t_test_results[val.name][i]>=0.05 else "" for i in range(len(val))]

# res_df.style.apply(negative_bold)
res_df
# Out:
#                               GMENN         TE        OHE  Embedding  \
# eucalyptus           43.27 (49.678)  nan (nan)  nan (nan)  nan (nan)
# Midwest_survey        12.15 (1.466)  nan (nan)  nan (nan)  nan (nan)
# hpc-job-scheduling  116.06 (40.381)  nan (nan)  nan (nan)  nan (nan)
# video-game-sales      35.91 (8.086)  nan (nan)  nan (nan)  nan (nan)
# okcupid-stem         69.75 (22.213)  nan (nan)  nan (nan)  nan (nan)
# Diabetes130US         50.53 (4.358)  nan (nan)  nan (nan)  nan (nan)
#
#                        Ignore
# eucalyptus          nan (nan)
# Midwest_survey      nan (nan)
# hpc-job-scheduling  nan (nan)
# video-game-sales    nan (nan)
# okcupid-stem        nan (nan)
# Diabetes130US       nan (nan)

# %%
res_df["GMENN"].apply(lambda x: float(x.split(" ")[0])).values
# Out:
# array([ 43.27,  12.15, 116.06,  35.91,  69.75,  50.53])
