# %% [markdown]
# Compare multilevel perceptrons (MLPs) on the spiral classification problem, where data is generated from several clusters with varying spiral radii.

# %%
# Run to select GPU #1 and limit memory usage to 30%
# from armed.tfutils import set_gpu
# set_gpu(1, 0.3)

# %%
import os
import sys
sys.path.append("../")
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import matplotlib.pyplot as plt
import tensorflow as tf
from scipy import stats
from sklearn.model_selection import StratifiedKFold

from spirals import make_spiral_random_radius, make_spiral_random_radius_confounder, plot_clusters, make_spiral_true_boundary
from armed.models.mlp_classifiers import BaseMLP, ClusterCovariateMLP, DomainAdversarialMLP, MixedEffectsMLPNonlinearSlope
from armed.models.metalearning import mldg
from armed.misc import expand_results_path, make_random_onehot

sys.path.append("../../../menn")
from model.random_intercept_network import RandomInterceptNetwork
from utils.fe_models import get_model
from data.preprocessing import dataset_preprocessing
# Out:
# C:\Users\AndrejTschalzev\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %% [markdown]
# Define output directory path.

# %%
strOutputDir = expand_results_path('./spirals/random_radii/')
strOutputDir = './spirals/random_radii/'

# %%
strOutputDir
# Out:
# './spirals/random_radii/'

# %% [markdown]
# Spiral generation parameters.
# * clusters: Number of clusters
# * false_negatives: True draws the random radii from a distribution centered at zero, such that half the clusters have flipped spirals. This increases problem difficulty by obscuring the predictiveness of the features. False centers the distribution at 1.
# * confound_sd: If simulating confounded_vars, sets the strength of the confounding factor.
# * radius_sd: Inter-cluster variance of random radii
# * degrees: Spiral arclength in degrees
# * confounded_vars: Number of confounded variables to add
# * noise: s.d. of added Gaussian noise
# * random_seed

# %%
dictSpiralParams = {'clusters': 10, 
                    'false_negatives': False, 
                    'confound_sd': 0.,
                    'radius_sd': 0.3,
                    'degrees': 360,
                    'confounded_vars': 0,
                    'noise': 0.1,
                    'random_seed': 48}

# %% [markdown]
# Create and visualize dataset

# %%
# Create dataset
np.random.seed(dictSpiralParams['random_seed'])
if dictSpiralParams['confound_sd'] > 0:
    arrX, arrZ, arrY, arrRadii, arrRatio = make_spiral_random_radius_confounder(dictSpiralParams['clusters'],
                                                                                mean_radius=0 if dictSpiralParams['false_negatives'] else 1,
                                                                                ratio_sd=dictSpiralParams['confound_sd'],
                                                                                radius_sd=dictSpiralParams['radius_sd'],
                                                                                degrees=dictSpiralParams['degrees'],
                                                                                confounders=dictSpiralParams['confounded_vars'],
                                                                                noise=dictSpiralParams['noise'])
else:    
    arrX, arrZ, arrY, arrRadii = make_spiral_random_radius(dictSpiralParams['clusters'], 
                                                        mean_radius=0 if dictSpiralParams['false_negatives'] else 1, 
                                                        inter_cluster_sd=dictSpiralParams['radius_sd'], 
                                                        degrees=dictSpiralParams['degrees'],
                                                        noise=dictSpiralParams['noise'])

figData, axData = plot_clusters(arrX, arrZ, arrY, arrRadii)
figData.savefig(os.path.join(strOutputDir, 'spirals_data.png'))
figData.savefig(os.path.join(strOutputDir, 'spirals_data.svg'))
figData.show()

# One-hot to binary labels
arrY = arrY[:, 1]

# Ensure float32
arrX = arrX.astype(np.float32)
arrY = arrY.astype(np.float32)
arrZ = arrZ.astype(np.float32)

# Use the class label and cluster membership in stratified k-fold partitioning later
arrStrata = [f'{y}_{z}' for y, z in zip(arrY, arrZ.argmax(axis=1))]
arrStrata = np.array(arrStrata)
# Out:
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\1300008413.py:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figData.show()

# %%
# create informative names for the confounded probe features
lsFeatureNames = ['1', '2'] 
if dictSpiralParams['confounded_vars'] > 0:
    lsFeatureNames += [f'Probe {i+1}' for i in range(dictSpiralParams['confounded_vars'])]

# %%
def compute_grads(model, inputs):
    """Compute feature gradients/partial derivatives.

    Args:
        model: trained model
        inputs (array or tuple): model inputs

    Returns:
        pd.DataFrame: feature gradients
    """    

    if isinstance(inputs, tuple):
        x, z = inputs
        x = x.mean(axis=0).reshape((1, -1))
        # Use all zero design matrix, since for the ME-MLP we 
        # only want to measure the feature sensitivity of the 
        # fixed effects submodel.
        z = np.zeros((1, z.shape[1]), dtype=np.float32)
        
        with tf.GradientTape() as gt:
            tx = tf.constant(x)
            tz = tf.zeros_like(z)
            gt.watch(tx)
            gt.watch(tz)
            ty = model((tx, tz))
            
        dydx = gt.gradient(ty, tx)

    else:
        x = inputs
        x = x.mean(axis=0).reshape((1, -1))
        with tf.GradientTape() as gt:
            tx = tf.constant(x)
            gt.watch(tx)
            ty = model(tx)
            
        dydx = gt.gradient(ty, tx)

    dfGrads = pd.DataFrame(np.abs(dydx.numpy()), columns=lsFeatureNames)
    return pd.melt(dfGrads, var_name='Feature', value_name='Gradient')
    
def compute_random_slope_sd(model):
    """Compute the inter-cluster variances of the ME-MLP's learned random slopes.

    Args:
        model: trained model

    Returns:
        pd.DataFrame: s.d. for each feature
    """    
    arrRandomSlopePosterior = model.randomeffects.re_slope.weights[0].numpy()
    nClusters = dictSpiralParams['clusters']
    nFeatures = 2 + dictSpiralParams['confounded_vars']
    nWeights = nClusters * nFeatures
    arrRandomSlope = arrRandomSlopePosterior[:nWeights]
    arrRandomSlope = arrRandomSlope.reshape((nClusters, nFeatures))

    return pd.DataFrame({'Feature': lsFeatureNames, 'S.D.': arrRandomSlope.std(axis=0)})
    
def get_random_intercepts(model):
    """Get the learned random intercepts from the trained ME-MLP.

    Args:
        model: trained model

    Returns:
        pd.DataFrame: Cluster-specific random intercepts
    """    
    arrRandomIntPosterior = model.randomeffects.re_int.weights[0].numpy()
    nClusters = dictSpiralParams['clusters']
    arrRandomInt = arrRandomIntPosterior[:nClusters]
    
    return pd.DataFrame({'Cluster': range(nClusters), 'Random intercept': arrRandomInt})


def plot_percluster_decision_boundary(model, X, Y, Z, cluster_input=False, vmax=1.5, degrees=360, radii=None):
    """Plot decision boundaries learned per cluster. Currently only works with 2-class problems.

    Args:
        model (tf.keras.Model): trained model
        X (np.array): input
        Y (np.array): target
        Z (np.array): cluster membership matrix
        cluster_input (bool, optional): Whether model takes a cluster membership input. Defaults to False.
        vmax (float, optional): Extent of feature space to plot. Defaults to 1.5.
        degrees (int, optional): Spiral length (to plot true decision boundary). Defaults to 360.
        radii (array, optional): Cluster-specific radii (to plot true decision boundary). Defaults to None.

    Returns:
        figure, axes
    """    
    
    nClusters = Z.shape[1]
    nAxRows = int(np.ceil(nClusters / 5))
    fig, axes = plt.subplots(nAxRows, 5, figsize=(16, 3 * nAxRows), gridspec_kw={'hspace': 0.5})
    
    for iCluster in range(nClusters):
        ax = axes.flatten()[iCluster]
        
        arrXCluster = X[Z[:, iCluster]==1,]
        arrYCluster = Y[Z[:, iCluster]==1,]
        arrZCluster = Z[Z[:, iCluster]==1,]
        
        # Create grid of points in feature space
        arrGridX1, arrGridX2 = np.mgrid[-vmax:vmax+0.1:0.01, -vmax:vmax+0.1:0.01]
        # Fill in extra confounded features with 0.5
        if X.shape[1] > 2:
            arrGridX3 = np.ones_like(arrGridX1) * 0.5
            arrGridXConf = np.stack([arrGridX3.flatten()] * (X.shape[1] - 2), axis=-1)
            arrGridX = np.concatenate([arrGridX1.reshape(-1, 1), arrGridX2.reshape(-1, 1), arrGridXConf], axis=1)
        else:    
            arrGridX = np.stack([arrGridX1.flatten(), arrGridX2.flatten()], axis=0).T
            
        if cluster_input:
            arrGridZ = np.zeros((arrGridX.shape[0], Z.shape[1]))
            arrGridZ[:, iCluster] = 1
            try:# model == RandomInterceptNetwork:
                arrGridYFlat = model.predict((arrGridX, arrGridZ), verbose=0)
            except:
                print("Manually added exception for GMENN occured")
                arrGridYFlat = model.predict(arrGridX, arrGridZ.astype(float)).numpy()
        else:
            try:
                arrGridYFlat = model.predict(arrGridX, verbose=0) 
            except:
                print("Manually added exception for GMENN occured")
                arrGridZ = np.zeros((arrGridX.shape[0], Z.shape[1]))
                arrGridZ[:, iCluster] = 1
                try:# model == RandomInterceptNetwork:
                    arrGridYFlat = model.predict((arrGridX, arrGridZ), verbose=0)
                except:
                    arrGridYFlat = model.predict(tf.cast(tf.convert_to_tensor(arrGridX),tf.float32), arrGridZ.astype(int)).numpy()
            
        
        if isinstance(arrGridYFlat, tuple):
            arrGridYFlat = arrGridYFlat[0]
        arrGridY = (arrGridYFlat >= 0.5).reshape(arrGridX1.shape).astype(int)
        
        # Use contour function to visualize decision boundary
        ax.contour(arrGridX1, arrGridX2, arrGridY, levels=1, colors='k')  
        ax.contourf(arrGridX1, arrGridX2, arrGridY, levels=1, colors=['C0', 'C1'], alpha=0.5)    
        
        # Plot data points
        ax.scatter(arrXCluster[arrYCluster == 0, 0], arrXCluster[arrYCluster == 0, 1], 
                   c='C0', s=5, alpha=0.9)
        ax.scatter(arrXCluster[arrYCluster == 1, 0], arrXCluster[arrYCluster == 1, 1], 
                   c='C1', s=10, alpha=0.9, marker='P')
        
        if radii is not None:
            # Plot true decision boundary (midpoint between classes)
            arrTrueBoundary = make_spiral_true_boundary(degrees=degrees-180, 
                                                        radius=radii[iCluster])
            ax.plot(arrTrueBoundary[:1000, 0], 
                                        arrTrueBoundary[:1000, 1], 
                                        c='g', ls='--', lw=3)   
            ax.plot(arrTrueBoundary[1000:, 0], 
                                        arrTrueBoundary[1000:, 1], 
                                        c='g', ls='--', lw=3)
                
        # Include accuracy in subplot title    
        try:
            if cluster_input:
                acc = model.evaluate((arrXCluster, arrZCluster), arrYCluster, verbose=0, return_dict=True)['acc']
            else:
                acc = model.evaluate(arrXCluster, arrYCluster, verbose=0, return_dict=True)['acc']
        except:
            print("Manually added exception for GMENN occured")
            acc = model.evaluate(["accuracy"], arrXCluster, arrYCluster, arrZCluster.astype(int))["accuracy"]

        ax.set_title(f'Accuracy: {acc:.03f}')
        
        ax.set_xlim(-vmax, vmax)
        ax.set_ylim(-vmax, vmax)
        ax.set_aspect('equal')    
    return fig, axes
    

def cross_validate(model_class, use_z=False, build_args={}, compile_args={}, use_mldg=False, randomize_z=False,epochs=10):
    """Perform 10-fold cross-validation and return per-fold performance, feature importance, and decision boundary plot.

    Args:
        model_class: model class
        use_z (bool, optional): Whether model takes Z input. Defaults to False.
        build_args (dict, optional): Model build arguments. Defaults to {}.
        compile_args (dict, optional): Model compile arguments. Defaults to {}.
        use_mldg (bool, optional): Whether to use meta-learning domain generalization to train. Defaults to False.
        randomize_z (bool, optional): Randomize the Z input when evaluating on test data 
            (ablating the RE information). Defaults to False.

    Returns:
        if model_class == MixedEffectsMLPNonlinearSlope:
            performance, feature importance, random slope variance, random intercepts, decision boundary fig
        else: 
        performance, feature importance, decision boundary fig
    """    
    kfolds = StratifiedKFold(10)
    lsResults = []
    lsGrads = []
    if model_class == MixedEffectsMLPNonlinearSlope:
        lsRandomSlopeSD = [] 
        lsRandomInt = []  
    
    for fold_num, (arrTrainIdx, arrTestIdx) in enumerate(kfolds.split(arrX, arrStrata)):
        if fold_num!=9:
            continue
        print(f"Training fold {fold_num}")
        arrXTrain = arrX[arrTrainIdx,]
        arrYTrain = arrY[arrTrainIdx,]
        arrZTrain = arrZ[arrTrainIdx,]
        arrXTest = arrX[arrTestIdx,]
        arrYTest = arrY[arrTestIdx,]
        arrZTest = arrZ[arrTestIdx,]
        
        tf.random.set_seed(283)
        
        if model_class==RandomInterceptNetwork:
            build_args_split = build_args.copy()
            build_args_split["fe_model"] = build_args_split["fe_model"]()
            model = model_class(**build_args_split)
        else:
            model = model_class(**build_args)

        if randomize_z:
            arrZTest = make_random_onehot(arrXTest.shape[0], arrZTrain.shape[1])
        
        if use_z:
            dataTrain = (arrXTrain, arrZTrain)
            dataTest = (arrXTest, arrZTest)
            # dataHeldout = (xHeldout, zHeldout)
        else:
            dataTrain = arrXTrain
            dataTest = arrXTest     
            # dataHeldout = xHeldout
            
        if model_class==RandomInterceptNetwork:
            
            arrZTrain_menn = np.argmax(arrZTrain,axis=1).reshape(-1,1)
            arrZTest_menn = np.argmax(arrZTest,axis=1).reshape(-1,1)
            
            config = compile_args
            e_mode = config["menn_parameters"]["e_mode"]
            m_mode = config["menn_parameters"]["m_mode"]
            type_mcem = config["menn_parameters"]["type_mcem"]
            type_kernel = config["menn_parameters"]["type_kernel"]
            epsilon = config["menn_parameters"]["epsilon"]
            set_variance_to_sample_std = config["menn_parameters"]["set_variance_to_sample_std"]
            num_iters = epochs
            num_pretrain_fe_iters = config["menn_parameters"]["num_pretrain_fe_iters"]
            num_warmup_iters = config["menn_parameters"]["num_warmup_iters"]
            min_samples = config["menn_parameters"]["min_samples"]
            max_samples = config["menn_parameters"]["max_samples"]
            print_training = config["menn_parameters"]["print_training"]
            print_warmup = config["menn_parameters"]["print_warmup"]
            print_pretraining = config["menn_parameters"]["print_pretraining"]
            early_stopping_fe = config["menn_parameters"]["early_stopping_fe"]
            early_stopping_metric_fe = config["menn_parameters"]["early_stopping_metric_fe"]
            early_stopping_re = config["menn_parameters"]["early_stopping_re"]
            early_stopping_metric_re = config["menn_parameters"]["early_stopping_metric_re"]
            track_best_model= config["menn_parameters"]["track_best_model"]
            track_best_model_metric = config["menn_parameters"]["track_best_model_metric"]
            optimizer = config["menn_parameters"]["optimizer"]
            batch_size=32
            metrics = ["accuracy"]
            mcmc_kernel_init_func = model.get_mcmc_kernel_init_func(type_kernel= type_kernel, epsilon=epsilon, min_samples = min_samples, max_samples = max_samples, type_mcem=type_mcem)
            
        else:
            model.compile(**compile_args)
        
        if use_mldg:
            # Call model once to instantiate weights
            _ = model.predict(arrXTrain, steps=1)
            model = mldg(arrXTrain, arrYTrain, arrZTrain, model, epochs=10, loss_fn=tf.keras.losses.binary_crossentropy)
        
        elif model_class==RandomInterceptNetwork:
            log = model.fit(arrXTrain, arrYTrain, arrZTrain_menn.astype(int),
                           val_data=[arrXTest, arrYTest, arrZTest_menn.astype(int)],
                           e_mode=e_mode,
                           m_mode = m_mode,
                           set_variance_to_sample_std=set_variance_to_sample_std,
                           mcmc_kernel_init_func = mcmc_kernel_init_func, num_mcmc_samples=1,
                           optimizer_fe=optimizer,
                           batch_size=batch_size,
                           num_pretrain_fe_iters = num_pretrain_fe_iters,
                           num_warmup_iters=num_warmup_iters,
                           num_iters=num_iters,
                           print_warmup=print_warmup, print_pretraining=print_pretraining, print_training=print_training,
                           early_stopping_fe=early_stopping_fe, early_stopping_metric_fe=early_stopping_metric_fe,
                           early_stopping_re=early_stopping_re, early_stopping_metric_re=early_stopping_metric_re,
                           metrics = metrics,
                           track_best_model=track_best_model, track_best_model_metric = track_best_model_metric
                           )
            
        
        else:
            log = model.fit(dataTrain, arrYTrain,
                            validation_data=(dataTest, arrYTest),
                            epochs=epochs,
                            verbose=1)
        if model_class==RandomInterceptNetwork:
            print(model._stddev_z)
            dictMetrics = {}
            dictMetrics["Accuracy"] = model.evaluate(metrics, arrXTrain, arrYTrain, arrZTrain_menn.astype(int))["accuracy"]
            dictMetrics["Test Accuracy"] = model.evaluate(metrics, arrXTest, arrYTest, arrZTest_menn.astype(int))["accuracy"]
        else:
            
            dictMetrics = {'Accuracy': model.evaluate(dataTrain, arrYTrain, verbose=0, return_dict=True)['acc'],
                           'Test Accuracy': model.evaluate(dataTest, arrYTest, verbose=0, return_dict=True)['acc']}
            
        lsResults += [dictMetrics]
        
        if model_class==RandomInterceptNetwork:
            lsGrads += [compute_grads(model.fe_model, dataTrain)]
            
        else:
            lsGrads += [compute_grads(model, dataTrain)]
        
        if model_class == MixedEffectsMLPNonlinearSlope:
            lsRandomSlopeSD += [compute_random_slope_sd(model)]
            lsRandomInt += [get_random_intercepts(model)]
    
        figDB, axDB = plot_percluster_decision_boundary(model, arrXTest, arrYTest, arrZTest, cluster_input=use_z,
                                                    vmax=arrXTest.max(), degrees=dictSpiralParams['degrees'],
                                                    radii=arrRadii)
        plt.show()
    dfResults = pd.DataFrame(lsResults)
    dfGrads = pd.concat(lsGrads, axis=0)
        
    if model_class == MixedEffectsMLPNonlinearSlope:
        dfRandomSlopeSD = pd.concat(lsRandomSlopeSD, axis=0)
        dfRandomIntercept = pd.concat(lsRandomInt, axis=0)
        return dfResults, dfGrads, dfRandomSlopeSD, dfRandomIntercept, figDB
    elif model_class==RandomInterceptNetwork:
        return dfResults, dfGrads, figDB, model
        
    else:
        return dfResults, dfGrads, figDB
    
def compute_95ci(dfResults):
    print('Mean')
    print(dfResults.mean())
    
    print('95CI low') 
    print(dfResults.mean() - 1.96 * (dfResults.std() / (10**0.5)))

    print('95CI high') 
    print(dfResults.mean() + 1.96 * (dfResults.std() / (10**0.5)))

# %% [markdown]
# ## Conventional MLP

# %%
from armed.models.mlp_classifiers import BaseMLP

# %%
dictCompile = {'loss':tf.keras.losses.BinaryCrossentropy(),
                'metrics': tf.keras.metrics.BinaryAccuracy('acc'),
                'optimizer': tf.keras.optimizers.Adam(lr=0.001)}
dfResultsBase, dfGradsBase, figDBBase = cross_validate(BaseMLP, compile_args=dictCompile)
figDBBase.savefig(os.path.join(strOutputDir, 'conventional_decision_boundaries.png'))
figDBBase.savefig(os.path.join(strOutputDir, 'conventional_decision_boundaries.svg'))
figDBBase.show()

figGradsBase, axGradsBase = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsBase, x='Feature', y='Gradient', ax=axGradsBase, color='C0')
axGradsBase.set_ylabel('Gradient magnitude')
figGradsBase.savefig(os.path.join(strOutputDir, 'conventional_feature_gradients.png'))
figGradsBase.savefig(os.path.join(strOutputDir, 'conventional_feature_gradients.svg'))
figGradsBase.show()

compute_95ci(dfResultsBase)
# Out:
# Training fold 0
# Epoch 1/10
# C:\Users\AndrejTschalzev\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 282/282 [==============================] - 5s 6ms/step - loss: 0.6902 - acc: 0.5647 - val_loss: 0.6791 - val_acc: 0.5790
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.6468 - acc: 0.6002 - val_loss: 0.6117 - val_acc: 0.5900
# Epoch 3/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5618 - acc: 0.6718 - val_loss: 0.5394 - val_acc: 0.7000
# Epoch 4/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5146 - acc: 0.7239 - val_loss: 0.5133 - val_acc: 0.7250
# Epoch 5/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4954 - acc: 0.7422 - val_loss: 0.4993 - val_acc: 0.7320
# Epoch 6/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4825 - acc: 0.7550 - val_loss: 0.4898 - val_acc: 0.7550
# Epoch 7/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4743 - acc: 0.7623 - val_loss: 0.4863 - val_acc: 0.7520
# Epoch 8/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4698 - acc: 0.7636 - val_loss: 0.4862 - val_acc: 0.7470
# Epoch 9/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4676 - acc: 0.7614 - val_loss: 0.4824 - val_acc: 0.7530
# Epoch 10/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4661 - acc: 0.7664 - val_loss: 0.4822 - val_acc: 0.7610
# Training fold 1
# Epoch 1/10
# 282/282 [==============================] - 2s 5ms/step - loss: 0.6320 - acc: 0.6305 - val_loss: 0.5440 - val_acc: 0.6820
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5187 - acc: 0.7234 - val_loss: 0.5047 - val_acc: 0.7360
# Epoch 3/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4915 - acc: 0.7480 - val_loss: 0.4924 - val_acc: 0.7420
# Epoch 4/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4804 - acc: 0.7533 - val_loss: 0.4811 - val_acc: 0.7570
# Epoch 5/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4739 - acc: 0.7630 - val_loss: 0.4731 - val_acc: 0.7530
# Epoch 6/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4707 - acc: 0.7633 - val_loss: 0.4708 - val_acc: 0.7590
# Epoch 7/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4688 - acc: 0.7667 - val_loss: 0.4679 - val_acc: 0.7600
# Epoch 8/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4666 - acc: 0.7677 - val_loss: 0.4680 - val_acc: 0.7620
# Epoch 9/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4657 - acc: 0.7684 - val_loss: 0.4663 - val_acc: 0.7660
# Epoch 10/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4643 - acc: 0.7708 - val_loss: 0.4654 - val_acc: 0.7670
# Training fold 2
# Epoch 1/10
# 282/282 [==============================] - 2s 5ms/step - loss: 0.6186 - acc: 0.6422 - val_loss: 0.5256 - val_acc: 0.6950
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5071 - acc: 0.7392 - val_loss: 0.4831 - val_acc: 0.7500
# Epoch 3/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4830 - acc: 0.7548 - val_loss: 0.4801 - val_acc: 0.7560
# Epoch 4/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4756 - acc: 0.7569 - val_loss: 0.4744 - val_acc: 0.7610
# Epoch 5/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4717 - acc: 0.7629 - val_loss: 0.4714 - val_acc: 0.7460
# Epoch 6/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4696 - acc: 0.7604 - val_loss: 0.4724 - val_acc: 0.7680
# Epoch 7/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4683 - acc: 0.7607 - val_loss: 0.4673 - val_acc: 0.7630
# Epoch 8/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4671 - acc: 0.7633 - val_loss: 0.4688 - val_acc: 0.7590
# Epoch 9/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4665 - acc: 0.7637 - val_loss: 0.4668 - val_acc: 0.7550
# Epoch 10/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4656 - acc: 0.7649 - val_loss: 0.4663 - val_acc: 0.7650
# Training fold 3
# Epoch 1/10
# 282/282 [==============================] - 2s 5ms/step - loss: 0.6227 - acc: 0.6325 - val_loss: 0.5365 - val_acc: 0.6880
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5125 - acc: 0.7302 - val_loss: 0.4749 - val_acc: 0.7580
# Epoch 3/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4855 - acc: 0.7517 - val_loss: 0.4603 - val_acc: 0.7680
# Epoch 4/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4774 - acc: 0.7553 - val_loss: 0.4566 - val_acc: 0.7650
# Epoch 5/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4739 - acc: 0.7600 - val_loss: 0.4522 - val_acc: 0.7650
# Epoch 6/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4717 - acc: 0.7591 - val_loss: 0.4502 - val_acc: 0.7660
# Epoch 7/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4707 - acc: 0.7613 - val_loss: 0.4477 - val_acc: 0.7710
# Epoch 8/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4694 - acc: 0.7632 - val_loss: 0.4465 - val_acc: 0.7700
# Epoch 9/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4687 - acc: 0.7621 - val_loss: 0.4459 - val_acc: 0.7750
# Epoch 10/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4679 - acc: 0.7617 - val_loss: 0.4472 - val_acc: 0.7710
# Training fold 4
# Epoch 1/10
# 282/282 [==============================] - 2s 5ms/step - loss: 0.6383 - acc: 0.6100 - val_loss: 0.5960 - val_acc: 0.6230
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5619 - acc: 0.6542 - val_loss: 0.5514 - val_acc: 0.6690
# Epoch 3/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5268 - acc: 0.6889 - val_loss: 0.5219 - val_acc: 0.6880
# Epoch 4/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5046 - acc: 0.7042 - val_loss: 0.5063 - val_acc: 0.7030
# Epoch 5/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4925 - acc: 0.7228 - val_loss: 0.4994 - val_acc: 0.7070
# Epoch 6/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4858 - acc: 0.7323 - val_loss: 0.4950 - val_acc: 0.7280
# Epoch 7/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4814 - acc: 0.7377 - val_loss: 0.4945 - val_acc: 0.7280
# Epoch 8/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4793 - acc: 0.7424 - val_loss: 0.4906 - val_acc: 0.7320
# Epoch 9/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4776 - acc: 0.7452 - val_loss: 0.4893 - val_acc: 0.7300
# Epoch 10/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4763 - acc: 0.7483 - val_loss: 0.4896 - val_acc: 0.7480
# Training fold 5
# Epoch 1/10
# 282/282 [==============================] - 2s 5ms/step - loss: 0.6356 - acc: 0.6065 - val_loss: 0.5676 - val_acc: 0.6600
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5057 - acc: 0.7299 - val_loss: 0.4788 - val_acc: 0.7510
# Epoch 3/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4639 - acc: 0.7627 - val_loss: 0.4662 - val_acc: 0.7570
# Epoch 4/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4561 - acc: 0.7676 - val_loss: 0.4618 - val_acc: 0.7630
# Epoch 5/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4530 - acc: 0.7694 - val_loss: 0.4602 - val_acc: 0.7700
# Epoch 6/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4514 - acc: 0.7702 - val_loss: 0.4580 - val_acc: 0.7650
# Epoch 7/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4507 - acc: 0.7699 - val_loss: 0.4584 - val_acc: 0.7570
# Epoch 8/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4490 - acc: 0.7709 - val_loss: 0.4588 - val_acc: 0.7660
# Epoch 9/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4488 - acc: 0.7701 - val_loss: 0.4571 - val_acc: 0.7670
# Epoch 10/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4480 - acc: 0.7728 - val_loss: 0.4582 - val_acc: 0.7610
# Training fold 6
# Epoch 1/10
# 282/282 [==============================] - 2s 4ms/step - loss: 0.6149 - acc: 0.6434 - val_loss: 0.5460 - val_acc: 0.6950
# Epoch 2/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5093 - acc: 0.7371 - val_loss: 0.4927 - val_acc: 0.7570
# Epoch 3/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4853 - acc: 0.7499 - val_loss: 0.4761 - val_acc: 0.7750
# Epoch 4/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4773 - acc: 0.7564 - val_loss: 0.4678 - val_acc: 0.7700
# Epoch 5/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4732 - acc: 0.7588 - val_loss: 0.4657 - val_acc: 0.7620
# Epoch 6/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4705 - acc: 0.7588 - val_loss: 0.4614 - val_acc: 0.7730
# Epoch 7/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4694 - acc: 0.7621 - val_loss: 0.4582 - val_acc: 0.7750
# Epoch 8/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4674 - acc: 0.7620 - val_loss: 0.4574 - val_acc: 0.7710
# Epoch 9/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4673 - acc: 0.7624 - val_loss: 0.4569 - val_acc: 0.7700
# Epoch 10/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4658 - acc: 0.7652 - val_loss: 0.4560 - val_acc: 0.7760
# Training fold 7
# Epoch 1/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.6290 - acc: 0.6247 - val_loss: 0.5710 - val_acc: 0.6330
# Epoch 2/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5201 - acc: 0.7214 - val_loss: 0.5088 - val_acc: 0.7270
# Epoch 3/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4876 - acc: 0.7433 - val_loss: 0.4965 - val_acc: 0.7520
# Epoch 4/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4751 - acc: 0.7622 - val_loss: 0.4819 - val_acc: 0.7640
# Epoch 5/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4672 - acc: 0.7686 - val_loss: 0.4760 - val_acc: 0.7660
# Epoch 6/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4616 - acc: 0.7764 - val_loss: 0.4681 - val_acc: 0.7710
# Epoch 7/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4579 - acc: 0.7778 - val_loss: 0.4650 - val_acc: 0.7740
# Epoch 8/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4532 - acc: 0.7813 - val_loss: 0.4602 - val_acc: 0.7760
# Epoch 9/10
# 282/282 [==============================] - 2s 6ms/step - loss: 0.4506 - acc: 0.7809 - val_loss: 0.4558 - val_acc: 0.7820
# Epoch 10/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.4459 - acc: 0.7824 - val_loss: 0.4571 - val_acc: 0.7800
# Training fold 8
# Epoch 1/10
# 282/282 [==============================] - 2s 5ms/step - loss: 0.6361 - acc: 0.6302 - val_loss: 0.5672 - val_acc: 0.6610
# Epoch 2/10
# 282/282 [==============================] - 1s 5ms/step - loss: 0.5469 - acc: 0.6881 - val_loss: 0.5036 - val_acc: 0.7380
# Epoch 3/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4885 - acc: 0.7488 - val_loss: 0.4721 - val_acc: 0.7590
# Epoch 4/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4693 - acc: 0.7541 - val_loss: 0.4652 - val_acc: 0.7660
# Epoch 5/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4642 - acc: 0.7606 - val_loss: 0.4652 - val_acc: 0.7460
# Epoch 6/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4614 - acc: 0.7606 - val_loss: 0.4637 - val_acc: 0.7520
# Epoch 7/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4607 - acc: 0.7612 - val_loss: 0.4603 - val_acc: 0.7510
# Epoch 8/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4589 - acc: 0.7632 - val_loss: 0.4613 - val_acc: 0.7500
# Epoch 9/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4586 - acc: 0.7630 - val_loss: 0.4599 - val_acc: 0.7520
# Epoch 10/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4575 - acc: 0.7633 - val_loss: 0.4583 - val_acc: 0.7590
# Training fold 9
# Epoch 1/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.6395 - acc: 0.6153 - val_loss: 0.5662 - val_acc: 0.6610
# Epoch 2/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5569 - acc: 0.6556 - val_loss: 0.5212 - val_acc: 0.6890
# Epoch 3/10
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5161 - acc: 0.6878 - val_loss: 0.4931 - val_acc: 0.7170
# Epoch 4/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4937 - acc: 0.7009 - val_loss: 0.4782 - val_acc: 0.7300
# Epoch 5/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4817 - acc: 0.7182 - val_loss: 0.4738 - val_acc: 0.7400
# Epoch 6/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4749 - acc: 0.7267 - val_loss: 0.4699 - val_acc: 0.7480
# Epoch 7/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4708 - acc: 0.7350 - val_loss: 0.4640 - val_acc: 0.7500
# Epoch 8/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4676 - acc: 0.7370 - val_loss: 0.4604 - val_acc: 0.7530
# Epoch 9/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4661 - acc: 0.7426 - val_loss: 0.4635 - val_acc: 0.7590
# Epoch 10/10
# 282/282 [==============================] - 1s 4ms/step - loss: 0.4638 - acc: 0.7477 - val_loss: 0.4584 - val_acc: 0.7560
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_85788\707923906.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figDBBase.show()
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_85788\707923906.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figGradsBase.show()
# Mean
# Accuracy         0.765744
# Test Accuracy    0.764400
# dtype: float64
# 95CI low
# Accuracy         0.759364
# Test Accuracy    0.758482
# dtype: float64
# 95CI high
# Accuracy         0.772125
# Test Accuracy    0.770318
# dtype: float64

# %% [markdown]
# ## Meta-learning domain generalization

# %%
dictCompile = {'loss':tf.keras.losses.BinaryCrossentropy(),
                'metrics': tf.keras.metrics.BinaryAccuracy('acc'),
                'optimizer': tf.keras.optimizers.Adam(lr=0.001)}
dfResultsMLDG, dfGradsMLDG, figDBMLDG = cross_validate(BaseMLP, compile_args=dictCompile, use_mldg=True)
figDBMLDG.savefig(os.path.join(strOutputDir, 'metalearning_decision_boundaries.png'))
figDBMLDG.savefig(os.path.join(strOutputDir, 'metalearning_decision_boundaries.svg'))
figDBMLDG.show()

figGradsMLDG, axGradsMLDG = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsMLDG, x='Feature', y='Gradient', ax=axGradsMLDG, color='C0')
axGradsMLDG.set_ylabel('Gradient magnitude')
figGradsMLDG.savefig(os.path.join(strOutputDir, 'metalearning_feature_gradients.png'))
figGradsMLDG.savefig(os.path.join(strOutputDir, 'metalearning_feature_gradients.svg'))
figGradsMLDG.show()

compute_95ci(dfResultsMLDG)
# Out:
# WARNING:tensorflow:5 out of the last 33424 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02c097790> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 33425 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02cc2fe50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:7 out of the last 33426 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02cf86670> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:8 out of the last 33427 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02c0e1d30> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:9 out of the last 33428 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02c0ac820> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:10 out of the last 33429 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab027946c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 33430 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02c13b310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x2ab02c13b310> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Mean
# Accuracy         0.629929
# Test Accuracy    0.632800
# dtype: float64
# 95CI low
# Accuracy         0.613166
# Test Accuracy    0.614172
# dtype: float64
# 95CI high
# Accuracy         0.646692
# Test Accuracy    0.651428
# dtype: float64

# %% [markdown]
# ## Conventional MLP with additional cluster membership input
#
# The data X and cluster membership matrix Z are simply concatenated together.

# %%
dictCompile = {'loss':tf.keras.losses.BinaryCrossentropy(),
                'metrics': tf.keras.metrics.BinaryAccuracy('acc'),
                'optimizer': tf.keras.optimizers.Adam(lr=0.001)}
dfResultsConcat, dfGradsConcat, figDBConcat = cross_validate(ClusterCovariateMLP, use_z=True, compile_args=dictCompile,epochs=50)
figDBConcat.savefig(os.path.join(strOutputDir, 'concatcluster_decision_boundaries.png'))
figDBConcat.savefig(os.path.join(strOutputDir, 'concatcluster_decision_boundaries.svg'))
figDBConcat.show()

figGradsConcat, axGradsConcat = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsConcat, x='Feature', y='Gradient', ax=axGradsConcat, color='C0')
axGradsConcat.set_ylabel('Gradient magnitude')
figGradsConcat.savefig(os.path.join(strOutputDir, 'concatcluster_feature_gradients.png'))
figGradsConcat.savefig(os.path.join(strOutputDir, 'concatcluster_feature_gradients.svg'))
figGradsConcat.show()

compute_95ci(dfResultsConcat)
# Out:
# Epoch 1/50
# C:\Users\AndrejTschalzev\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 282/282 [==============================] - 1s 4ms/step - loss: 0.6900 - acc: 0.5547 - val_loss: 0.6837 - val_acc: 0.5790
# Epoch 2/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.6609 - acc: 0.6039 - val_loss: 0.6474 - val_acc: 0.5850
# Epoch 3/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.6217 - acc: 0.6180 - val_loss: 0.6273 - val_acc: 0.6010
# Epoch 4/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5985 - acc: 0.6310 - val_loss: 0.6148 - val_acc: 0.6030
# Epoch 5/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5875 - acc: 0.6397 - val_loss: 0.6062 - val_acc: 0.6130
# Epoch 6/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5817 - acc: 0.6450 - val_loss: 0.6033 - val_acc: 0.6230
# Epoch 7/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5771 - acc: 0.6492 - val_loss: 0.6007 - val_acc: 0.6240
# Epoch 8/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5732 - acc: 0.6550 - val_loss: 0.5978 - val_acc: 0.6240
# Epoch 9/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5694 - acc: 0.6617 - val_loss: 0.5940 - val_acc: 0.6410
# Epoch 10/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5654 - acc: 0.6709 - val_loss: 0.5909 - val_acc: 0.6390
# Epoch 11/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5625 - acc: 0.6764 - val_loss: 0.5894 - val_acc: 0.6430
# Epoch 12/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5588 - acc: 0.6801 - val_loss: 0.5843 - val_acc: 0.6440
# Epoch 13/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5559 - acc: 0.6810 - val_loss: 0.5832 - val_acc: 0.6450
# Epoch 14/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5535 - acc: 0.6807 - val_loss: 0.5785 - val_acc: 0.6570
# Epoch 15/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5508 - acc: 0.6836 - val_loss: 0.5749 - val_acc: 0.6540
# Epoch 16/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5482 - acc: 0.6838 - val_loss: 0.5714 - val_acc: 0.6560
# Epoch 17/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5455 - acc: 0.6871 - val_loss: 0.5678 - val_acc: 0.6660
# Epoch 18/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5430 - acc: 0.6884 - val_loss: 0.5679 - val_acc: 0.6610
# Epoch 19/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5403 - acc: 0.6907 - val_loss: 0.5649 - val_acc: 0.6610
# Epoch 20/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5372 - acc: 0.6933 - val_loss: 0.5645 - val_acc: 0.6630
# Epoch 21/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5347 - acc: 0.6961 - val_loss: 0.5613 - val_acc: 0.6640
# Epoch 22/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5318 - acc: 0.6973 - val_loss: 0.5603 - val_acc: 0.6640
# Epoch 23/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5297 - acc: 0.6987 - val_loss: 0.5609 - val_acc: 0.6670
# Epoch 24/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5281 - acc: 0.6988 - val_loss: 0.5575 - val_acc: 0.6710
# Epoch 25/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5264 - acc: 0.6989 - val_loss: 0.5574 - val_acc: 0.6690
# Epoch 26/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5250 - acc: 0.7010 - val_loss: 0.5567 - val_acc: 0.6670
# Epoch 27/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5232 - acc: 0.7016 - val_loss: 0.5559 - val_acc: 0.6630
# Epoch 28/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5213 - acc: 0.7034 - val_loss: 0.5545 - val_acc: 0.6680
# Epoch 29/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5205 - acc: 0.7019 - val_loss: 0.5546 - val_acc: 0.6610
# Epoch 30/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5182 - acc: 0.7019 - val_loss: 0.5521 - val_acc: 0.6650
# Epoch 31/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5164 - acc: 0.7026 - val_loss: 0.5502 - val_acc: 0.6700
# Epoch 32/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5146 - acc: 0.7023 - val_loss: 0.5489 - val_acc: 0.6720
# Epoch 33/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5132 - acc: 0.7056 - val_loss: 0.5479 - val_acc: 0.6670
# Epoch 34/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5125 - acc: 0.7059 - val_loss: 0.5491 - val_acc: 0.6650
# Epoch 35/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5114 - acc: 0.7067 - val_loss: 0.5472 - val_acc: 0.6660
# Epoch 36/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5106 - acc: 0.7038 - val_loss: 0.5451 - val_acc: 0.6750
# Epoch 37/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5098 - acc: 0.7053 - val_loss: 0.5440 - val_acc: 0.6720
# Epoch 38/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5097 - acc: 0.7066 - val_loss: 0.5440 - val_acc: 0.6650
# Epoch 39/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5093 - acc: 0.7059 - val_loss: 0.5449 - val_acc: 0.6650
# Epoch 40/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5083 - acc: 0.7066 - val_loss: 0.5470 - val_acc: 0.6690
# Epoch 41/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5080 - acc: 0.7064 - val_loss: 0.5440 - val_acc: 0.6680
# Epoch 42/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5083 - acc: 0.7077 - val_loss: 0.5446 - val_acc: 0.6680
# Epoch 43/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5072 - acc: 0.7059 - val_loss: 0.5418 - val_acc: 0.6710
# Epoch 44/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5071 - acc: 0.7054 - val_loss: 0.5432 - val_acc: 0.6690
# Epoch 45/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5066 - acc: 0.7054 - val_loss: 0.5418 - val_acc: 0.6670
# Epoch 46/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5062 - acc: 0.7050 - val_loss: 0.5432 - val_acc: 0.6700
# Epoch 47/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5060 - acc: 0.7023 - val_loss: 0.5424 - val_acc: 0.6720
# Epoch 48/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5055 - acc: 0.7049 - val_loss: 0.5411 - val_acc: 0.6760
# Epoch 49/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5042 - acc: 0.7063 - val_loss: 0.5418 - val_acc: 0.6740
# Epoch 50/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.5036 - acc: 0.7061 - val_loss: 0.5395 - val_acc: 0.6690
# Epoch 1/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.6636 - acc: 0.5933 - val_loss: 0.6293 - val_acc: 0.6260
# Epoch 2/50
# 282/282 [==============================] - 1s 4ms/step - loss: 0.6160 - acc: 0.6092 - val_loss: 0.5898 - val_acc: 0.6080
# Epoch 3/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5938 - acc: 0.6173 - val_loss: 0.5779 - val_acc: 0.6200
# Epoch 4/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5838 - acc: 0.6237 - val_loss: 0.5681 - val_acc: 0.6350
# Epoch 5/50
# 282/282 [==============================] - 1s 2ms/step - loss: 0.5763 - acc: 0.6404 - val_loss: 0.5612 - val_acc: 0.6480
# Epoch 6/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5697 - acc: 0.6560 - val_loss: 0.5517 - val_acc: 0.6610
# Epoch 7/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5623 - acc: 0.6639 - val_loss: 0.5433 - val_acc: 0.6850
# Epoch 8/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5557 - acc: 0.6782 - val_loss: 0.5362 - val_acc: 0.6910
# Epoch 9/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5496 - acc: 0.6854 - val_loss: 0.5289 - val_acc: 0.6950
# Epoch 10/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5429 - acc: 0.6920 - val_loss: 0.5247 - val_acc: 0.6950
# Epoch 11/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5374 - acc: 0.6966 - val_loss: 0.5209 - val_acc: 0.6970
# Epoch 12/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5322 - acc: 0.6966 - val_loss: 0.5174 - val_acc: 0.7000
# Epoch 13/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5290 - acc: 0.6991 - val_loss: 0.5182 - val_acc: 0.7020
# Epoch 14/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5260 - acc: 0.7021 - val_loss: 0.5121 - val_acc: 0.7030
# Epoch 15/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5231 - acc: 0.7027 - val_loss: 0.5096 - val_acc: 0.7030
# Epoch 16/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5207 - acc: 0.7047 - val_loss: 0.5096 - val_acc: 0.7060
# Epoch 17/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5181 - acc: 0.7040 - val_loss: 0.5056 - val_acc: 0.7090
# Epoch 18/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5155 - acc: 0.7073 - val_loss: 0.5026 - val_acc: 0.7100
# Epoch 19/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5126 - acc: 0.7080 - val_loss: 0.4994 - val_acc: 0.7110
# Epoch 20/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5088 - acc: 0.7081 - val_loss: 0.4960 - val_acc: 0.7110
# Epoch 21/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5046 - acc: 0.7093 - val_loss: 0.4916 - val_acc: 0.7170
# Epoch 22/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.5002 - acc: 0.7107 - val_loss: 0.4850 - val_acc: 0.7150
# Epoch 23/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4940 - acc: 0.7118 - val_loss: 0.4784 - val_acc: 0.7280
# Epoch 24/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4880 - acc: 0.7197 - val_loss: 0.4755 - val_acc: 0.7340
# Epoch 25/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4807 - acc: 0.7357 - val_loss: 0.4616 - val_acc: 0.7410
# Epoch 26/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4733 - acc: 0.7407 - val_loss: 0.4516 - val_acc: 0.7560
# Epoch 27/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4650 - acc: 0.7449 - val_loss: 0.4451 - val_acc: 0.7640
# Epoch 28/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4578 - acc: 0.7529 - val_loss: 0.4435 - val_acc: 0.7600
# Epoch 29/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4538 - acc: 0.7541 - val_loss: 0.4350 - val_acc: 0.7660
# Epoch 30/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4500 - acc: 0.7550 - val_loss: 0.4346 - val_acc: 0.7650
# Epoch 31/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4469 - acc: 0.7590 - val_loss: 0.4296 - val_acc: 0.7650
# Epoch 32/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4449 - acc: 0.7597 - val_loss: 0.4288 - val_acc: 0.7660
# Epoch 33/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4432 - acc: 0.7609 - val_loss: 0.4266 - val_acc: 0.7730
# Epoch 34/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4406 - acc: 0.7633 - val_loss: 0.4253 - val_acc: 0.7740
# Epoch 35/50
# 282/282 [==============================] - 1s 3ms/step - loss: 0.4378 - acc: 0.7653 - val_loss: 0.4213 - val_acc: 0.7760
# Epoch 36/50
# 254/282 [==========================>...] - ETA: 0s - loss: 0.4340 - acc: 0.7688
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [34], in <cell line: 4>()
#       1 dictCompile = {'loss':tf.keras.losses.BinaryCrossentropy(),
#       2                 'metrics': tf.keras.metrics.BinaryAccuracy('acc'),
#       3                 'optimizer': tf.keras.optimizers.Adam(lr=0.001)}
# ----> 4 dfResultsConcat, dfGradsConcat, figDBConcat = cross_validate(ClusterCovariateMLP, use_z=True, compile_args=dictCompile,epochs=50)
#       5 figDBConcat.savefig(os.path.join(strOutputDir, 'concatcluster_decision_boundaries.png'))
#       6 figDBConcat.savefig(os.path.join(strOutputDir, 'concatcluster_decision_boundaries.svg'))
#
# Input In [31], in cross_validate(model_class, use_z, build_args, compile_args, use_mldg, randomize_z, epochs)
#     212     model = mldg(arrXTrain, arrYTrain, arrZTrain, model, epochs=10, loss_fn=tf.keras.losses.binary_crossentropy)
#     213 else:
# --> 214     log = model.fit(dataTrain, arrYTrain,
#     215                     validation_data=(dataTest, arrYTest),
#     216                     epochs=epochs,
#     217                     verbose=1)
#     219 dictMetrics = {'Accuracy': model.evaluate(dataTrain, arrYTrain, verbose=0, return_dict=True)['acc'],
#     220                'Test Accuracy': model.evaluate(dataTest, arrYTest, verbose=0, return_dict=True)['acc']}
#     222 lsResults += [dictMetrics]
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ## Domain adversarial MLP

# %%
dictBuild = {'n_clusters': dictSpiralParams['clusters'], 'adversary_layer_units': [4, 4]}
dictCompile = {'loss_gen_weight': 0.5,
               'metric_class': tf.keras.metrics.BinaryAccuracy('acc'),
               'metric_adv': tf.keras.metrics.CategoricalAccuracy('adv_acc')}
dfResultsDA, dfGradsDA, figDBDA = cross_validate(DomainAdversarialMLP, use_z=True, 
                                                 build_args=dictBuild, compile_args=dictCompile)
figDBDA.savefig(os.path.join(strOutputDir, 'adversarial_decision_boundaries.png'))
figDBDA.savefig(os.path.join(strOutputDir, 'adversarial_decision_boundaries.svg'))
figDBDA.show()

figGradsDA, axGradsDA = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsDA, x='Feature', y='Gradient', ax=axGradsDA, color='C0')
axGradsDA.set_ylabel('Gradient magnitude')
figGradsDA.savefig(os.path.join(strOutputDir, 'adversarial_feature_gradients.png'))
figGradsDA.savefig(os.path.join(strOutputDir, 'adversarial_feature_gradients.svg'))
figGradsDA.show()

compute_95ci(dfResultsDA)
# Out:
# Training fold 0
# Epoch 1/10
# 282/282 [==============================] - 3s 8ms/step - class_loss: 0.6921 - adv_loss: 2.3031 - total_loss: -0.4593 - acc: 0.5473 - adv_acc: 0.0926 - val_class_loss: 0.6850 - val_adv_loss: 2.3016 - val_total_loss: -0.4658 - val_acc: 0.6190 - val_adv_acc: 0.0850
# Epoch 2/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.6645 - adv_loss: 2.2961 - total_loss: -0.4834 - acc: 0.6188 - adv_acc: 0.1034 - val_class_loss: 0.6419 - val_adv_loss: 2.2930 - val_total_loss: -0.5046 - val_acc: 0.6120 - val_adv_acc: 0.1230
# Epoch 3/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.6269 - adv_loss: 2.2807 - total_loss: -0.5133 - acc: 0.6237 - adv_acc: 0.1236 - val_class_loss: 0.6141 - val_adv_loss: 2.2750 - val_total_loss: -0.5234 - val_acc: 0.6220 - val_adv_acc: 0.1230
# Epoch 4/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.6075 - adv_loss: 2.2633 - total_loss: -0.5240 - acc: 0.6354 - adv_acc: 0.1417 - val_class_loss: 0.5982 - val_adv_loss: 2.2584 - val_total_loss: -0.5310 - val_acc: 0.6380 - val_adv_acc: 0.1340
# Epoch 5/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5941 - adv_loss: 2.2480 - total_loss: -0.5297 - acc: 0.6454 - adv_acc: 0.1446 - val_class_loss: 0.5860 - val_adv_loss: 2.2440 - val_total_loss: -0.5360 - val_acc: 0.6460 - val_adv_acc: 0.1460
# Epoch 6/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5817 - adv_loss: 2.2346 - total_loss: -0.5354 - acc: 0.6537 - adv_acc: 0.1479 - val_class_loss: 0.5733 - val_adv_loss: 2.2297 - val_total_loss: -0.5416 - val_acc: 0.6580 - val_adv_acc: 0.1510
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5675 - adv_loss: 2.2238 - total_loss: -0.5442 - acc: 0.6618 - adv_acc: 0.1482 - val_class_loss: 0.5568 - val_adv_loss: 2.2195 - val_total_loss: -0.5530 - val_acc: 0.6650 - val_adv_acc: 0.1640
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5465 - adv_loss: 2.2158 - total_loss: -0.5611 - acc: 0.6791 - adv_acc: 0.1548 - val_class_loss: 0.5335 - val_adv_loss: 2.2128 - val_total_loss: -0.5729 - val_acc: 0.6800 - val_adv_acc: 0.1510
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5197 - adv_loss: 2.2101 - total_loss: -0.5851 - acc: 0.7148 - adv_acc: 0.1547 - val_class_loss: 0.5040 - val_adv_loss: 2.2077 - val_total_loss: -0.5999 - val_acc: 0.7310 - val_adv_acc: 0.1570
# Epoch 10/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4928 - adv_loss: 2.2053 - total_loss: -0.6096 - acc: 0.7458 - adv_acc: 0.1580 - val_class_loss: 0.4845 - val_adv_loss: 2.2017 - val_total_loss: -0.6163 - val_acc: 0.7450 - val_adv_acc: 0.1530
# Training fold 1
# Epoch 1/10
# 282/282 [==============================] - 3s 8ms/step - class_loss: 0.6541 - adv_loss: 2.2953 - total_loss: -0.4932 - acc: 0.6140 - adv_acc: 0.1060 - val_class_loss: 0.6248 - val_adv_loss: 2.2750 - val_total_loss: -0.5127 - val_acc: 0.6080 - val_adv_acc: 0.1430
# Epoch 2/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.6099 - adv_loss: 2.2592 - total_loss: -0.5194 - acc: 0.6312 - adv_acc: 0.1472 - val_class_loss: 0.6074 - val_adv_loss: 2.2459 - val_total_loss: -0.5155 - val_acc: 0.6170 - val_adv_acc: 0.1510
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5955 - adv_loss: 2.2343 - total_loss: -0.5213 - acc: 0.6357 - adv_acc: 0.1543 - val_class_loss: 0.5945 - val_adv_loss: 2.2198 - val_total_loss: -0.5154 - val_acc: 0.6170 - val_adv_acc: 0.1630
# Epoch 4/10
# 282/282 [==============================] - 2s 8ms/step - class_loss: 0.5788 - adv_loss: 2.2130 - total_loss: -0.5274 - acc: 0.6389 - adv_acc: 0.1571 - val_class_loss: 0.5797 - val_adv_loss: 2.2110 - val_total_loss: -0.5258 - val_acc: 0.6230 - val_adv_acc: 0.1610
# Epoch 5/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5605 - adv_loss: 2.2007 - total_loss: -0.5396 - acc: 0.6673 - adv_acc: 0.1589 - val_class_loss: 0.5625 - val_adv_loss: 2.1983 - val_total_loss: -0.5366 - val_acc: 0.6710 - val_adv_acc: 0.1590
# Epoch 6/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5434 - adv_loss: 2.1918 - total_loss: -0.5522 - acc: 0.7017 - adv_acc: 0.1574 - val_class_loss: 0.5471 - val_adv_loss: 2.1915 - val_total_loss: -0.5486 - val_acc: 0.6820 - val_adv_acc: 0.1710
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5257 - adv_loss: 2.1873 - total_loss: -0.5676 - acc: 0.7214 - adv_acc: 0.1613 - val_class_loss: 0.5246 - val_adv_loss: 2.1895 - val_total_loss: -0.5702 - val_acc: 0.7220 - val_adv_acc: 0.1550
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5047 - adv_loss: 2.1799 - total_loss: -0.5850 - acc: 0.7529 - adv_acc: 0.1631 - val_class_loss: 0.5043 - val_adv_loss: 2.1869 - val_total_loss: -0.5892 - val_acc: 0.7340 - val_adv_acc: 0.1650
# Epoch 9/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4937 - adv_loss: 2.1785 - total_loss: -0.5952 - acc: 0.7549 - adv_acc: 0.1654 - val_class_loss: 0.4963 - val_adv_loss: 2.1838 - val_total_loss: -0.5956 - val_acc: 0.7530 - val_adv_acc: 0.1670
# Epoch 10/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4844 - adv_loss: 2.1744 - total_loss: -0.6025 - acc: 0.7599 - adv_acc: 0.1681 - val_class_loss: 0.4859 - val_adv_loss: 2.1847 - val_total_loss: -0.6064 - val_acc: 0.7490 - val_adv_acc: 0.1610
# Training fold 2
# Epoch 1/10
# 282/282 [==============================] - 3s 8ms/step - class_loss: 0.6648 - adv_loss: 2.2949 - total_loss: -0.4823 - acc: 0.5770 - adv_acc: 0.1079 - val_class_loss: 0.6225 - val_adv_loss: 2.2855 - val_total_loss: -0.5202 - val_acc: 0.6340 - val_adv_acc: 0.1310
# Epoch 2/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.6159 - adv_loss: 2.2684 - total_loss: -0.5180 - acc: 0.5998 - adv_acc: 0.1386 - val_class_loss: 0.5929 - val_adv_loss: 2.2605 - val_total_loss: -0.5373 - val_acc: 0.6070 - val_adv_acc: 0.1410
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5991 - adv_loss: 2.2429 - total_loss: -0.5222 - acc: 0.5972 - adv_acc: 0.1519 - val_class_loss: 0.5816 - val_adv_loss: 2.2384 - val_total_loss: -0.5376 - val_acc: 0.5990 - val_adv_acc: 0.1470
# Epoch 4/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5886 - adv_loss: 2.2232 - total_loss: -0.5227 - acc: 0.6049 - adv_acc: 0.1539 - val_class_loss: 0.5763 - val_adv_loss: 2.2273 - val_total_loss: -0.5373 - val_acc: 0.5910 - val_adv_acc: 0.1600
# Epoch 5/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5810 - adv_loss: 2.2123 - total_loss: -0.5249 - acc: 0.6128 - adv_acc: 0.1566 - val_class_loss: 0.5685 - val_adv_loss: 2.2169 - val_total_loss: -0.5399 - val_acc: 0.6370 - val_adv_acc: 0.1650
# Epoch 6/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5742 - adv_loss: 2.2063 - total_loss: -0.5288 - acc: 0.6292 - adv_acc: 0.1558 - val_class_loss: 0.5624 - val_adv_loss: 2.2120 - val_total_loss: -0.5436 - val_acc: 0.6290 - val_adv_acc: 0.1690
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5677 - adv_loss: 2.2010 - total_loss: -0.5326 - acc: 0.6401 - adv_acc: 0.1594 - val_class_loss: 0.5540 - val_adv_loss: 2.2079 - val_total_loss: -0.5499 - val_acc: 0.6650 - val_adv_acc: 0.1660
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5601 - adv_loss: 2.1979 - total_loss: -0.5386 - acc: 0.6587 - adv_acc: 0.1570 - val_class_loss: 0.5441 - val_adv_loss: 2.2045 - val_total_loss: -0.5582 - val_acc: 0.6820 - val_adv_acc: 0.1730
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5530 - adv_loss: 2.1951 - total_loss: -0.5444 - acc: 0.6734 - adv_acc: 0.1589 - val_class_loss: 0.5371 - val_adv_loss: 2.2012 - val_total_loss: -0.5636 - val_acc: 0.7080 - val_adv_acc: 0.1600
# Epoch 10/10
# 282/282 [==============================] - 2s 8ms/step - class_loss: 0.5462 - adv_loss: 2.1936 - total_loss: -0.5504 - acc: 0.6902 - adv_acc: 0.1591 - val_class_loss: 0.5281 - val_adv_loss: 2.2030 - val_total_loss: -0.5734 - val_acc: 0.7050 - val_adv_acc: 0.1630
# Training fold 3
# Epoch 1/10
# 282/282 [==============================] - 3s 8ms/step - class_loss: 0.6544 - adv_loss: 2.2943 - total_loss: -0.4924 - acc: 0.6061 - adv_acc: 0.1052 - val_class_loss: 0.6069 - val_adv_loss: 2.2789 - val_total_loss: -0.5326 - val_acc: 0.6280 - val_adv_acc: 0.1270
# Epoch 2/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.6050 - adv_loss: 2.2621 - total_loss: -0.5258 - acc: 0.6349 - adv_acc: 0.1381 - val_class_loss: 0.5793 - val_adv_loss: 2.2547 - val_total_loss: -0.5481 - val_acc: 0.6630 - val_adv_acc: 0.1470
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5831 - adv_loss: 2.2418 - total_loss: -0.5376 - acc: 0.6479 - adv_acc: 0.1466 - val_class_loss: 0.5558 - val_adv_loss: 2.2358 - val_total_loss: -0.5620 - val_acc: 0.6720 - val_adv_acc: 0.1440
# Epoch 4/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5573 - adv_loss: 2.2252 - total_loss: -0.5550 - acc: 0.6700 - adv_acc: 0.1513 - val_class_loss: 0.5269 - val_adv_loss: 2.2263 - val_total_loss: -0.5863 - val_acc: 0.6920 - val_adv_acc: 0.1480
# Epoch 5/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5312 - adv_loss: 2.2148 - total_loss: -0.5759 - acc: 0.6950 - adv_acc: 0.1489 - val_class_loss: 0.5012 - val_adv_loss: 2.2181 - val_total_loss: -0.6078 - val_acc: 0.7340 - val_adv_acc: 0.1490
# Epoch 6/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5115 - adv_loss: 2.2080 - total_loss: -0.5923 - acc: 0.7297 - adv_acc: 0.1502 - val_class_loss: 0.4831 - val_adv_loss: 2.2116 - val_total_loss: -0.6227 - val_acc: 0.7450 - val_adv_acc: 0.1440
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4986 - adv_loss: 2.2018 - total_loss: -0.6021 - acc: 0.7463 - adv_acc: 0.1532 - val_class_loss: 0.4703 - val_adv_loss: 2.2110 - val_total_loss: -0.6352 - val_acc: 0.7650 - val_adv_acc: 0.1440
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4878 - adv_loss: 2.1986 - total_loss: -0.6112 - acc: 0.7549 - adv_acc: 0.1574 - val_class_loss: 0.4598 - val_adv_loss: 2.2063 - val_total_loss: -0.6433 - val_acc: 0.7650 - val_adv_acc: 0.1500
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4778 - adv_loss: 2.1963 - total_loss: -0.6201 - acc: 0.7611 - adv_acc: 0.1566 - val_class_loss: 0.4490 - val_adv_loss: 2.2007 - val_total_loss: -0.6513 - val_acc: 0.7760 - val_adv_acc: 0.1450
# Epoch 10/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4669 - adv_loss: 2.1934 - total_loss: -0.6296 - acc: 0.7674 - adv_acc: 0.1609 - val_class_loss: 0.4412 - val_adv_loss: 2.1963 - val_total_loss: -0.6569 - val_acc: 0.7780 - val_adv_acc: 0.1530
# Training fold 4
# Epoch 1/10
# 282/282 [==============================] - 3s 8ms/step - class_loss: 0.6507 - adv_loss: 2.2946 - total_loss: -0.4962 - acc: 0.6132 - adv_acc: 0.1030 - val_class_loss: 0.6206 - val_adv_loss: 2.2726 - val_total_loss: -0.5156 - val_acc: 0.6270 - val_adv_acc: 0.1300
# Epoch 2/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.6055 - adv_loss: 2.2550 - total_loss: -0.5218 - acc: 0.6404 - adv_acc: 0.1472 - val_class_loss: 0.6018 - val_adv_loss: 2.2409 - val_total_loss: -0.5186 - val_acc: 0.6470 - val_adv_acc: 0.1510
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5932 - adv_loss: 2.2320 - total_loss: -0.5226 - acc: 0.6481 - adv_acc: 0.1503 - val_class_loss: 0.5930 - val_adv_loss: 2.2208 - val_total_loss: -0.5175 - val_acc: 0.6460 - val_adv_acc: 0.1490
# Epoch 4/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5844 - adv_loss: 2.2169 - total_loss: -0.5238 - acc: 0.6524 - adv_acc: 0.1602 - val_class_loss: 0.5856 - val_adv_loss: 2.2109 - val_total_loss: -0.5199 - val_acc: 0.6450 - val_adv_acc: 0.1550
# Epoch 5/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5766 - adv_loss: 2.2074 - total_loss: -0.5269 - acc: 0.6542 - adv_acc: 0.1571 - val_class_loss: 0.5791 - val_adv_loss: 2.2047 - val_total_loss: -0.5232 - val_acc: 0.6430 - val_adv_acc: 0.1520
# Epoch 6/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5712 - adv_loss: 2.2033 - total_loss: -0.5302 - acc: 0.6536 - adv_acc: 0.1540 - val_class_loss: 0.5720 - val_adv_loss: 2.2012 - val_total_loss: -0.5286 - val_acc: 0.6460 - val_adv_acc: 0.1500
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5646 - adv_loss: 2.1969 - total_loss: -0.5336 - acc: 0.6531 - adv_acc: 0.1556 - val_class_loss: 0.5690 - val_adv_loss: 2.1962 - val_total_loss: -0.5291 - val_acc: 0.6440 - val_adv_acc: 0.1450
# Epoch 8/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5594 - adv_loss: 2.1918 - total_loss: -0.5364 - acc: 0.6507 - adv_acc: 0.1564 - val_class_loss: 0.5630 - val_adv_loss: 2.1933 - val_total_loss: -0.5336 - val_acc: 0.6460 - val_adv_acc: 0.1660
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5554 - adv_loss: 2.1880 - total_loss: -0.5384 - acc: 0.6507 - adv_acc: 0.1551 - val_class_loss: 0.5589 - val_adv_loss: 2.1885 - val_total_loss: -0.5353 - val_acc: 0.6440 - val_adv_acc: 0.1570
# Epoch 10/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5519 - adv_loss: 2.1833 - total_loss: -0.5395 - acc: 0.6263 - adv_acc: 0.1567 - val_class_loss: 0.5565 - val_adv_loss: 2.1803 - val_total_loss: -0.5336 - val_acc: 0.6400 - val_adv_acc: 0.1670
# Training fold 5
# Epoch 1/10
# 282/282 [==============================] - 3s 7ms/step - class_loss: 0.6483 - adv_loss: 2.2939 - total_loss: -0.4983 - acc: 0.6208 - adv_acc: 0.1169 - val_class_loss: 0.6136 - val_adv_loss: 2.2707 - val_total_loss: -0.5217 - val_acc: 0.6110 - val_adv_acc: 0.1540
# Epoch 2/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5755 - adv_loss: 2.2501 - total_loss: -0.5493 - acc: 0.6542 - adv_acc: 0.1444 - val_class_loss: 0.5593 - val_adv_loss: 2.2381 - val_total_loss: -0.5598 - val_acc: 0.6600 - val_adv_acc: 0.1440
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5370 - adv_loss: 2.2214 - total_loss: -0.5734 - acc: 0.6991 - adv_acc: 0.1549 - val_class_loss: 0.5329 - val_adv_loss: 2.2121 - val_total_loss: -0.5732 - val_acc: 0.7010 - val_adv_acc: 0.1570
# Epoch 4/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5143 - adv_loss: 2.2045 - total_loss: -0.5877 - acc: 0.7333 - adv_acc: 0.1603 - val_class_loss: 0.5171 - val_adv_loss: 2.2044 - val_total_loss: -0.5852 - val_acc: 0.7230 - val_adv_acc: 0.1610
# Epoch 5/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5003 - adv_loss: 2.1978 - total_loss: -0.5984 - acc: 0.7444 - adv_acc: 0.1593 - val_class_loss: 0.5057 - val_adv_loss: 2.1994 - val_total_loss: -0.5940 - val_acc: 0.7500 - val_adv_acc: 0.1480
# Epoch 6/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4912 - adv_loss: 2.1964 - total_loss: -0.6068 - acc: 0.7486 - adv_acc: 0.1560 - val_class_loss: 0.4988 - val_adv_loss: 2.1966 - val_total_loss: -0.5995 - val_acc: 0.7470 - val_adv_acc: 0.1560
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4853 - adv_loss: 2.1928 - total_loss: -0.6108 - acc: 0.7523 - adv_acc: 0.1601 - val_class_loss: 0.4939 - val_adv_loss: 2.1960 - val_total_loss: -0.6041 - val_acc: 0.7460 - val_adv_acc: 0.1550
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4799 - adv_loss: 2.1912 - total_loss: -0.6154 - acc: 0.7561 - adv_acc: 0.1576 - val_class_loss: 0.4899 - val_adv_loss: 2.1920 - val_total_loss: -0.6061 - val_acc: 0.7540 - val_adv_acc: 0.1580
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4769 - adv_loss: 2.1898 - total_loss: -0.6177 - acc: 0.7571 - adv_acc: 0.1587 - val_class_loss: 0.4863 - val_adv_loss: 2.1898 - val_total_loss: -0.6086 - val_acc: 0.7540 - val_adv_acc: 0.1590
# Epoch 10/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4744 - adv_loss: 2.1881 - total_loss: -0.6194 - acc: 0.7581 - adv_acc: 0.1621 - val_class_loss: 0.4827 - val_adv_loss: 2.1902 - val_total_loss: -0.6125 - val_acc: 0.7560 - val_adv_acc: 0.1580
# Training fold 6
# Epoch 1/10
# 282/282 [==============================] - 3s 7ms/step - class_loss: 0.6315 - adv_loss: 2.2747 - total_loss: -0.5053 - acc: 0.6414 - adv_acc: 0.1333 - val_class_loss: 0.5601 - val_adv_loss: 2.2221 - val_total_loss: -0.5510 - val_acc: 0.6970 - val_adv_acc: 0.1600
# Epoch 2/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5018 - adv_loss: 2.2183 - total_loss: -0.6070 - acc: 0.7439 - adv_acc: 0.1531 - val_class_loss: 0.4733 - val_adv_loss: 2.2013 - val_total_loss: -0.6274 - val_acc: 0.7680 - val_adv_acc: 0.1550
# Epoch 3/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4636 - adv_loss: 2.2088 - total_loss: -0.6406 - acc: 0.7629 - adv_acc: 0.1530 - val_class_loss: 0.4531 - val_adv_loss: 2.1985 - val_total_loss: -0.6461 - val_acc: 0.7770 - val_adv_acc: 0.1600
# Epoch 4/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4560 - adv_loss: 2.2033 - total_loss: -0.6454 - acc: 0.7706 - adv_acc: 0.1514 - val_class_loss: 0.4496 - val_adv_loss: 2.1926 - val_total_loss: -0.6467 - val_acc: 0.7840 - val_adv_acc: 0.1600
# Epoch 5/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4542 - adv_loss: 2.1988 - total_loss: -0.6450 - acc: 0.7702 - adv_acc: 0.1566 - val_class_loss: 0.4487 - val_adv_loss: 2.1890 - val_total_loss: -0.6458 - val_acc: 0.7710 - val_adv_acc: 0.1610
# Epoch 6/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4516 - adv_loss: 2.1964 - total_loss: -0.6464 - acc: 0.7718 - adv_acc: 0.1548 - val_class_loss: 0.4469 - val_adv_loss: 2.1834 - val_total_loss: -0.6448 - val_acc: 0.7870 - val_adv_acc: 0.1540
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4516 - adv_loss: 2.1920 - total_loss: -0.6442 - acc: 0.7726 - adv_acc: 0.1602 - val_class_loss: 0.4453 - val_adv_loss: 2.1823 - val_total_loss: -0.6458 - val_acc: 0.7850 - val_adv_acc: 0.1620
# Epoch 8/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4496 - adv_loss: 2.1904 - total_loss: -0.6454 - acc: 0.7722 - adv_acc: 0.1607 - val_class_loss: 0.4465 - val_adv_loss: 2.1799 - val_total_loss: -0.6435 - val_acc: 0.7780 - val_adv_acc: 0.1580
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4503 - adv_loss: 2.1891 - total_loss: -0.6440 - acc: 0.7718 - adv_acc: 0.1577 - val_class_loss: 0.4450 - val_adv_loss: 2.1777 - val_total_loss: -0.6439 - val_acc: 0.7800 - val_adv_acc: 0.1590
# Epoch 10/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4496 - adv_loss: 2.1867 - total_loss: -0.6435 - acc: 0.7750 - adv_acc: 0.1551 - val_class_loss: 0.4443 - val_adv_loss: 2.1764 - val_total_loss: -0.6439 - val_acc: 0.7880 - val_adv_acc: 0.1710
# Training fold 7
# Epoch 1/10
# 282/282 [==============================] - 3s 7ms/step - class_loss: 0.6478 - adv_loss: 2.2933 - total_loss: -0.4984 - acc: 0.6226 - adv_acc: 0.1194 - val_class_loss: 0.6183 - val_adv_loss: 2.2646 - val_total_loss: -0.5140 - val_acc: 0.6070 - val_adv_acc: 0.1580
# Epoch 2/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5854 - adv_loss: 2.2381 - total_loss: -0.5333 - acc: 0.6446 - adv_acc: 0.1561 - val_class_loss: 0.5690 - val_adv_loss: 2.2224 - val_total_loss: -0.5422 - val_acc: 0.6430 - val_adv_acc: 0.1500
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5551 - adv_loss: 2.2022 - total_loss: -0.5457 - acc: 0.6491 - adv_acc: 0.1559 - val_class_loss: 0.5440 - val_adv_loss: 2.1994 - val_total_loss: -0.5558 - val_acc: 0.6430 - val_adv_acc: 0.1590
# Epoch 4/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5350 - adv_loss: 2.1874 - total_loss: -0.5584 - acc: 0.6277 - adv_acc: 0.1563 - val_class_loss: 0.5296 - val_adv_loss: 2.1911 - val_total_loss: -0.5660 - val_acc: 0.5970 - val_adv_acc: 0.1470
# Epoch 5/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5192 - adv_loss: 2.1828 - total_loss: -0.5720 - acc: 0.6657 - adv_acc: 0.1600 - val_class_loss: 0.5129 - val_adv_loss: 2.1887 - val_total_loss: -0.5815 - val_acc: 0.7050 - val_adv_acc: 0.1560
# Epoch 6/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5052 - adv_loss: 2.1848 - total_loss: -0.5869 - acc: 0.7121 - adv_acc: 0.1623 - val_class_loss: 0.5007 - val_adv_loss: 2.1892 - val_total_loss: -0.5939 - val_acc: 0.7220 - val_adv_acc: 0.1560
# Epoch 7/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4927 - adv_loss: 2.1848 - total_loss: -0.5995 - acc: 0.7381 - adv_acc: 0.1647 - val_class_loss: 0.4938 - val_adv_loss: 2.1898 - val_total_loss: -0.6011 - val_acc: 0.7360 - val_adv_acc: 0.1530
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4826 - adv_loss: 2.1852 - total_loss: -0.6099 - acc: 0.7507 - adv_acc: 0.1597 - val_class_loss: 0.4862 - val_adv_loss: 2.1910 - val_total_loss: -0.6093 - val_acc: 0.7400 - val_adv_acc: 0.1460
# Epoch 9/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4749 - adv_loss: 2.1815 - total_loss: -0.6156 - acc: 0.7560 - adv_acc: 0.1637 - val_class_loss: 0.4798 - val_adv_loss: 2.1843 - val_total_loss: -0.6123 - val_acc: 0.7500 - val_adv_acc: 0.1510
# Epoch 10/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4690 - adv_loss: 2.1793 - total_loss: -0.6205 - acc: 0.7628 - adv_acc: 0.1630 - val_class_loss: 0.4760 - val_adv_loss: 2.1815 - val_total_loss: -0.6147 - val_acc: 0.7640 - val_adv_acc: 0.1530
# Training fold 8
# Epoch 1/10
# 282/282 [==============================] - 3s 7ms/step - class_loss: 0.6482 - adv_loss: 2.2947 - total_loss: -0.4988 - acc: 0.6157 - adv_acc: 0.1014 - val_class_loss: 0.5866 - val_adv_loss: 2.2714 - val_total_loss: -0.5491 - val_acc: 0.6580 - val_adv_acc: 0.1250
# Epoch 2/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5898 - adv_loss: 2.2515 - total_loss: -0.5357 - acc: 0.6438 - adv_acc: 0.1433 - val_class_loss: 0.5468 - val_adv_loss: 2.2291 - val_total_loss: -0.5677 - val_acc: 0.6840 - val_adv_acc: 0.1490
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5548 - adv_loss: 2.2150 - total_loss: -0.5524 - acc: 0.6539 - adv_acc: 0.1546 - val_class_loss: 0.5187 - val_adv_loss: 2.1992 - val_total_loss: -0.5810 - val_acc: 0.6850 - val_adv_acc: 0.1680
# Epoch 4/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5246 - adv_loss: 2.1967 - total_loss: -0.5735 - acc: 0.6947 - adv_acc: 0.1630 - val_class_loss: 0.4966 - val_adv_loss: 2.1826 - val_total_loss: -0.5947 - val_acc: 0.7230 - val_adv_acc: 0.1740
# Epoch 5/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5025 - adv_loss: 2.1897 - total_loss: -0.5922 - acc: 0.7387 - adv_acc: 0.1626 - val_class_loss: 0.4822 - val_adv_loss: 2.1767 - val_total_loss: -0.6061 - val_acc: 0.7450 - val_adv_acc: 0.1700
# Epoch 6/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4857 - adv_loss: 2.1874 - total_loss: -0.6078 - acc: 0.7556 - adv_acc: 0.1608 - val_class_loss: 0.4705 - val_adv_loss: 2.1707 - val_total_loss: -0.6148 - val_acc: 0.7530 - val_adv_acc: 0.1670
# Epoch 7/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4754 - adv_loss: 2.1830 - total_loss: -0.6159 - acc: 0.7631 - adv_acc: 0.1640 - val_class_loss: 0.4628 - val_adv_loss: 2.1680 - val_total_loss: -0.6212 - val_acc: 0.7540 - val_adv_acc: 0.1690
# Epoch 8/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4682 - adv_loss: 2.1809 - total_loss: -0.6221 - acc: 0.7678 - adv_acc: 0.1643 - val_class_loss: 0.4610 - val_adv_loss: 2.1677 - val_total_loss: -0.6228 - val_acc: 0.7580 - val_adv_acc: 0.1750
# Epoch 9/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4623 - adv_loss: 2.1793 - total_loss: -0.6271 - acc: 0.7710 - adv_acc: 0.1611 - val_class_loss: 0.4564 - val_adv_loss: 2.1651 - val_total_loss: -0.6261 - val_acc: 0.7690 - val_adv_acc: 0.1680
# Epoch 10/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4593 - adv_loss: 2.1770 - total_loss: -0.6290 - acc: 0.7741 - adv_acc: 0.1637 - val_class_loss: 0.4523 - val_adv_loss: 2.1640 - val_total_loss: -0.6297 - val_acc: 0.7710 - val_adv_acc: 0.1670
# Training fold 9
# Epoch 1/10
# 282/282 [==============================] - 3s 7ms/step - class_loss: 0.6522 - adv_loss: 2.2920 - total_loss: -0.4934 - acc: 0.6156 - adv_acc: 0.1082 - val_class_loss: 0.6033 - val_adv_loss: 2.2756 - val_total_loss: -0.5345 - val_acc: 0.6410 - val_adv_acc: 0.1260
# Epoch 2/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5927 - adv_loss: 2.2564 - total_loss: -0.5352 - acc: 0.6527 - adv_acc: 0.1397 - val_class_loss: 0.5520 - val_adv_loss: 2.2546 - val_total_loss: -0.5753 - val_acc: 0.6670 - val_adv_acc: 0.1320
# Epoch 3/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.5438 - adv_loss: 2.2384 - total_loss: -0.5752 - acc: 0.6917 - adv_acc: 0.1398 - val_class_loss: 0.5113 - val_adv_loss: 2.2315 - val_total_loss: -0.6045 - val_acc: 0.7030 - val_adv_acc: 0.1450
# Epoch 4/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5172 - adv_loss: 2.2197 - total_loss: -0.5925 - acc: 0.7324 - adv_acc: 0.1540 - val_class_loss: 0.4895 - val_adv_loss: 2.2164 - val_total_loss: -0.6187 - val_acc: 0.7490 - val_adv_acc: 0.1470
# Epoch 5/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.5043 - adv_loss: 2.2035 - total_loss: -0.5973 - acc: 0.7440 - adv_acc: 0.1536 - val_class_loss: 0.4780 - val_adv_loss: 2.2093 - val_total_loss: -0.6266 - val_acc: 0.7600 - val_adv_acc: 0.1500
# Epoch 6/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4949 - adv_loss: 2.1956 - total_loss: -0.6027 - acc: 0.7463 - adv_acc: 0.1571 - val_class_loss: 0.4668 - val_adv_loss: 2.1978 - val_total_loss: -0.6321 - val_acc: 0.7700 - val_adv_acc: 0.1540
# Epoch 7/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4897 - adv_loss: 2.1894 - total_loss: -0.6048 - acc: 0.7506 - adv_acc: 0.1582 - val_class_loss: 0.4620 - val_adv_loss: 2.2005 - val_total_loss: -0.6383 - val_acc: 0.7670 - val_adv_acc: 0.1650
# Epoch 8/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4853 - adv_loss: 2.1867 - total_loss: -0.6079 - acc: 0.7516 - adv_acc: 0.1564 - val_class_loss: 0.4581 - val_adv_loss: 2.1978 - val_total_loss: -0.6408 - val_acc: 0.7640 - val_adv_acc: 0.1580
# Epoch 9/10
# 282/282 [==============================] - 2s 7ms/step - class_loss: 0.4817 - adv_loss: 2.1842 - total_loss: -0.6102 - acc: 0.7540 - adv_acc: 0.1561 - val_class_loss: 0.4557 - val_adv_loss: 2.1937 - val_total_loss: -0.6411 - val_acc: 0.7750 - val_adv_acc: 0.1530
# Epoch 10/10
# 282/282 [==============================] - 2s 6ms/step - class_loss: 0.4807 - adv_loss: 2.1821 - total_loss: -0.6101 - acc: 0.7568 - adv_acc: 0.1572 - val_class_loss: 0.4505 - val_adv_loss: 2.1930 - val_total_loss: -0.6460 - val_acc: 0.7670 - val_adv_acc: 0.1610
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_17636\3400940742.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figDBDA.show()
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_17636\3400940742.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figGradsDA.show()
# Mean
# Accuracy         0.745278
# Test Accuracy    0.746300
# dtype: float64
# 95CI low
# Accuracy         0.718255
# Test Accuracy    0.719201
# dtype: float64
# 95CI high
# Accuracy         0.772301
# Test Accuracy    0.773399
# dtype: float64

# %% [markdown]
# ## GMENN

# %%
config = {
"general_parameters": {
    "target": "continuous",
    "metrics": ["mse", "r2"],
    "model_name": "tabtransformer"
},  
# MENN Parameters
"menn_parameters": {
    "e_mode": "last",
    "m_mode": "all",
    "type_mcem": "SAEM", # "Vanilla" for MCEM and "SAEM" for saem
    "type_kernel": "NUTS",
    "epsilon": None,
    "set_variance_to_sample_std": True,
    "num_iters": 500,
    "num_pretrain_fe_iters": 0,
    "num_warmup_iters":  0,
    "min_samples": 1,
    "max_samples": 1,
    "print_training": 1,
    "print_warmup": 1,
    "print_pretraining": 1,
    "early_stopping_fe": 15,
    "early_stopping_metric_fe":  "val_accuracy",
    "early_stopping_re": 15,
    "early_stopping_metric_re":  "val_accuracy",
    "track_best_model": True,
    "track_best_model_metric":  "val_accuracy",
    'optimizer': tf.keras.optimizers.Adam(lr=0.001),
},

# NN Parameters
"nn_parameters": {
    "epochs": 500,
    "batch_size":  256,
    "patience": 15
},
    
# Embedding parameters
"embed_parameters": {
    "embed_dims_method": "AutoGluon" # "AutoGluon" for AutoGluon method, "sqrt" for using sqrt of number of categories, deafult=10 for all
}
}
# Out:
# C:\Users\AndrejTschalzev\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
import tensorflow.keras.layers as tkl
class BaseMLPGMENN(tf.keras.Model):
    def __init__(self, name: str='mlp', **kwargs):
        """Basic MLP with 3 hidden layers of 4 neurons each.

        Args:
            name (str, optional): Model name. Defaults to 'mlp'.
        """        
        super(BaseMLPGMENN, self).__init__(name=name, **kwargs)

        self.dense0 = tkl.Dense(4, activation='relu', name=name + '_dense0')
        self.dense1 = tkl.Dense(4, activation='relu', name=name + '_dense1')
        self.dense2 = tkl.Dense(4, activation='relu', name=name + '_dense2')
        self.dense_out = tkl.Dense(1, activation='linear', name=name + '_dense_out')
        
    def call(self, inputs,training=False):
        
        x = self.dense0(inputs)
        x = self.dense1(x)
        x = self.dense2(x)
        x = self.dense_out(x)
        
        return x

# %%
dictBuild = {"qs": [10], 
             "fe_model": BaseMLPGMENN, 
             "initial_stds": [1.], 
             "target": "binary", 
             "num_outputs": 1, 
             "RS": 283}
dictCompile = config
dfResultsGMENN, dfGradsGMENN, figDBGMENN, model = cross_validate(RandomInterceptNetwork,  
                                                                            use_z=False, 
                                                                            build_args=dictBuild, 
                                                                            compile_args=dictCompile,
                                                                                    epochs=50)
figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.png'))
figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.svg'))
figDBGMENN.show()

figGradsGMENN, axGradsGMENN = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsGMENN, x='Feature', y='Gradient', ax=axGradsGMENN, color='C0')
axGradsGMENN.set_ylabel('Gradient magnitude')
figGradsGMENN.savefig(os.path.join(strOutputDir, 'GMENN_feature_gradients.png'))
figGradsGMENN.savefig(os.path.join(strOutputDir, 'GMENN_feature_gradients.svg'))
figGradsGMENN.show()

compute_95ci(dfResultsGMENN)
# Out:
# Training fold 9
# batch 281
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [46], in <cell line: 8>()
#       1 dictBuild = {"qs": [10],
#       2              "fe_model": BaseMLPGMENN,
#       3              "initial_stds": [1.],
#       4              "target": "binary",
#       5              "num_outputs": 1,
#       6              "RS": 283}
#       7 dictCompile = config
# ----> 8 dfResultsGMENN, dfGradsGMENN, figDBGMENN, model = cross_validate(RandomInterceptNetwork,
#       9                                                                             use_z=False,
#      10                                                                             build_args=dictBuild,
#      11                                                                             compile_args=dictCompile,
#      12                                                                                     epochs=50)
#      13 figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.png'))
#      14 figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.svg'))
#
# Input In [45], in cross_validate(model_class, use_z, build_args, compile_args, use_mldg, randomize_z, epochs)
#     272     model = mldg(arrXTrain, arrYTrain, arrZTrain, model, epochs=10, loss_fn=tf.keras.losses.binary_crossentropy)
#     274 elif model_class==RandomInterceptNetwork:
# --> 275     log = model.fit(arrXTrain, arrYTrain, arrZTrain_menn.astype(int),
#     276                    val_data=[arrXTest, arrYTest, arrZTest_menn.astype(int)],
#     277                    e_mode=e_mode,
#     278                    m_mode = m_mode,
#     279                    set_variance_to_sample_std=set_variance_to_sample_std,
#     280                    mcmc_kernel_init_func = mcmc_kernel_init_func, num_mcmc_samples=1,
#     281                    optimizer_fe=optimizer,
#     282                    batch_size=batch_size,
#     283                    num_pretrain_fe_iters = num_pretrain_fe_iters,
#     284                    num_warmup_iters=num_warmup_iters,
#     285                    num_iters=num_iters,
#     286                    print_warmup=print_warmup, print_pretraining=print_pretraining, print_training=print_training,
#     287                    early_stopping_fe=early_stopping_fe, early_stopping_metric_fe=early_stopping_metric_fe,
#     288                    early_stopping_re=early_stopping_re, early_stopping_metric_re=early_stopping_metric_re,
#     289                    metrics = metrics,
#     290                    track_best_model=track_best_model, track_best_model_metric = track_best_model_metric
#     291                    )
#     294 else:
#     295     log = model.fit(dataTrain, arrYTrain,
#     296                     validation_data=(dataTest, arrYTest),
#     297                     epochs=epochs,
#     298                     verbose=1)
#
# Input In [42], in RandomInterceptNetwork.fit(self, X, y, Z, val_data, mcmc_kernel_init_func, num_mcmc_samples, e_mode, m_mode, optimizer_fe, set_variance_to_sample_std, batch_size, num_iters, num_pretrain_fe_iters, num_warmup_iters, perc_burnin, print_warmup, print_pretraining, print_training, early_stopping_fe, early_stopping_metric_fe, early_stopping_re, early_stopping_metric_re, metrics, num_samples_use_for_pred, track_best_model, track_best_model_metric)
#     600 for t in range(num_iters):
#     601     iteration_step = tf.convert_to_tensor(t+1, dtype=tf.int32)
# --> 602     loss, grads, current_state, e_time, m_time, acceptance_rate, previous_kernel_results = self.one_iteration(X, Z, y, current_state, previous_kernel_results, num_mcmc_samples_training[t], previous_loss, iteration_step)
#     603     previous_loss = loss
#     605     start_postprocessing = time.time()
#
# Input In [42], in RandomInterceptNetwork.one_iteration(self, X, Z, y, current_state, previous_kernel_results, num_mcmc_samples, previous_loss, iteration_step, set_variance_to_sample_std)
#     296                 self.trainable_variables[q_num].assign(tf.math.reduce_std(tf.math.reduce_mean(next_state[num],axis=0),axis=1))
#     297             else:
# --> 298                 self.trainable_variables[q_num].assign(tf.math.reduce_std(tf.math.reduce_mean(next_state[num],axis=0),axis=-1))
#     299 m_end = time.time()
#     301 return loss, grads, next_state, e_end-e_start, m_end-m_start, acceptance_rate.numpy(), previous_kernel_results
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:902, in BaseResourceVariable.assign(self, value, use_locking, name, read_value)
#     900   else:
#     901     tensor_name = " " + str(self.name)
# --> 902   raise ValueError(
#     903       (f"Cannot assign value to variable '{tensor_name}': Shape mismatch."
#     904        f"The variable shape {self._shape}, and the "
#     905        f"assigned value shape {value_tensor.shape} are incompatible."))
#     906 kwargs = {}
#     907 if forward_compat.forward_compatible(2022, 3, 23):
#     908   # If the shape is fully defined, we do a runtime check with the shape of
#     909   # value.
#
# ValueError: Cannot assign value to variable ' stddev_z0:0': Shape mismatch.The variable shape (), and the assigned value shape (7,) are incompatible.

# %% [markdown]
# ### Slope GMENN

# %%
# dfRandomSlopeSD, dfRandomIntercept
# Out:
# (  Feature      S.D.
#  0       1  0.205302
#  1       2  0.521397,
#     Cluster  Random intercept
#  0        0         -0.104693
#  1        1         -0.156140
#  2        2         -0.342027
#  3        3         -0.224211
#  4        4         -0.077063
#  5        5         -0.357774
#  6        6         -0.242751
#  7        7         -0.180173
#  8        8         -0.470675
#  9        9         -0.284167)

# %%
dictBuild = {"qs": [10], 
             "fe_model": BaseMLPGMENN, 
             "initial_stds": [[1.]*(1+arrX.shape[1]+4)], 
             "target": "binary", 
             "num_outputs": 1, 
             "RS": 283}
dictCompile = config
dfResultsGMENN, dfGradsGMENN, figDBGMENN, model = cross_validate(RandomInterceptNetwork,  
                                                                            use_z=False, 
                                                                            build_args=dictBuild, 
                                                                            compile_args=dictCompile,
                                                                                    epochs=100)
figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.png'))
figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.svg'))
figDBGMENN.show()

figGradsGMENN, axGradsGMENN = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsGMENN, x='Feature', y='Gradient', ax=axGradsGMENN, color='C0')
axGradsGMENN.set_ylabel('Gradient magnitude')
figGradsGMENN.savefig(os.path.join(strOutputDir, 'GMENN_feature_gradients.png'))
figGradsGMENN.savefig(os.path.join(strOutputDir, 'GMENN_feature_gradients.svg'))
figGradsGMENN.show()

compute_95ci(dfResultsGMENN)
# Out:
# Training fold 9
# --------------------------------------------
# Iteration:    0 Acceptance Rate: 1.000 Loss: 7108.709, FE_Loss: 7013.536, RE_Loss_sum: 95.173, train_accuracy: 0.509, fe_train_accuracy: 0.500
#  Validation Loss: 891.327, , FE_Loss_val: 796.153, val_accuracy: 0.501, fe_val_accuracy: 0.500
# E-step Time in Sec.=:  1.5
# M-step Time in Sec.=:  3.63
# Postprocessing Time in Sec.=:  0.49
# --------------------------------------------
# Iteration:    1 Acceptance Rate: 0.000 Loss: 7000.359, FE_Loss: 6905.186, RE_Loss_sum: 95.173, train_accuracy: 0.515, fe_train_accuracy: 0.535
#  Validation Loss: 875.392, , FE_Loss_val: 780.219, val_accuracy: 0.502, fe_val_accuracy: 0.544
# E-step Time in Sec.=:  1.16
# M-step Time in Sec.=:  1.2
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:    2 Acceptance Rate: 1.000 Loss: 6226.973, FE_Loss: 6140.315, RE_Loss_sum: 86.658, train_accuracy: 0.526, fe_train_accuracy: 0.570
#  Validation Loss: 772.707, , FE_Loss_val: 686.049, val_accuracy: 0.504, fe_val_accuracy: 0.595
# E-step Time in Sec.=:  0.05
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:    3 Acceptance Rate: 1.000 Loss: 5761.396, FE_Loss: 5664.622, RE_Loss_sum: 96.773, train_accuracy: 0.530, fe_train_accuracy: 0.577
#  Validation Loss: 710.816, , FE_Loss_val: 614.042, val_accuracy: 0.524, fe_val_accuracy: 0.593
# E-step Time in Sec.=:  0.05
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:    4 Acceptance Rate: 0.000 Loss: 5732.938, FE_Loss: 5636.165, RE_Loss_sum: 96.773, train_accuracy: 0.565, fe_train_accuracy: 0.580
#  Validation Loss: 707.335, , FE_Loss_val: 610.562, val_accuracy: 0.572, fe_val_accuracy: 0.600
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.04
# --------------------------------------------
# Iteration:    5 Acceptance Rate: 1.000 Loss: 5623.086, FE_Loss: 5512.172, RE_Loss_sum: 110.914, train_accuracy: 0.568, fe_train_accuracy: 0.580
#  Validation Loss: 707.480, , FE_Loss_val: 596.566, val_accuracy: 0.582, fe_val_accuracy: 0.609
# E-step Time in Sec.=:  0.21
# M-step Time in Sec.=:  1.19
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:    6 Acceptance Rate: 0.000 Loss: 5600.587, FE_Loss: 5489.673, RE_Loss_sum: 110.914, train_accuracy: 0.582, fe_train_accuracy: 0.580
#  Validation Loss: 704.552, , FE_Loss_val: 593.638, val_accuracy: 0.607, fe_val_accuracy: 0.610
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.04
# --------------------------------------------
# Iteration:    7 Acceptance Rate: 1.000 Loss: 5507.926, FE_Loss: 5431.175, RE_Loss_sum: 76.751, train_accuracy: 0.581, fe_train_accuracy: 0.580
#  Validation Loss: 669.071, , FE_Loss_val: 592.320, val_accuracy: 0.599, fe_val_accuracy: 0.612
# E-step Time in Sec.=:  1.05
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:    8 Acceptance Rate: 1.000 Loss: 5434.215, FE_Loss: 5349.195, RE_Loss_sum: 85.020, train_accuracy: 0.583, fe_train_accuracy: 0.653
#  Validation Loss: 660.669, , FE_Loss_val: 575.649, val_accuracy: 0.598, fe_val_accuracy: 0.676
# E-step Time in Sec.=:  0.2
# M-step Time in Sec.=:  1.15
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:    9 Acceptance Rate: 0.000 Loss: 5368.542, FE_Loss: 5283.522, RE_Loss_sum: 85.020, train_accuracy: 0.582, fe_train_accuracy: 0.670
#  Validation Loss: 653.593, , FE_Loss_val: 568.573, val_accuracy: 0.596, fe_val_accuracy: 0.691
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   10 Acceptance Rate: 1.000 Loss: 5294.217, FE_Loss: 5235.371, RE_Loss_sum: 58.846, train_accuracy: 0.585, fe_train_accuracy: 0.661
#  Validation Loss: 623.805, , FE_Loss_val: 564.960, val_accuracy: 0.595, fe_val_accuracy: 0.679
# E-step Time in Sec.=:  0.71
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   11 Acceptance Rate: 1.000 Loss: 5230.914, FE_Loss: 5167.786, RE_Loss_sum: 63.128, train_accuracy: 0.589, fe_train_accuracy: 0.666
#  Validation Loss: 619.595, , FE_Loss_val: 556.466, val_accuracy: 0.609, fe_val_accuracy: 0.683
# E-step Time in Sec.=:  0.12
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   12 Acceptance Rate: 0.000 Loss: 5177.384, FE_Loss: 5114.256, RE_Loss_sum: 63.128, train_accuracy: 0.598, fe_train_accuracy: 0.671
#  Validation Loss: 613.696, , FE_Loss_val: 550.568, val_accuracy: 0.621, fe_val_accuracy: 0.690
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.23
# Postprocessing Time in Sec.=:  0.04
# --------------------------------------------
# Iteration:   13 Acceptance Rate: 1.000 Loss: 5102.863, FE_Loss: 5072.121, RE_Loss_sum: 30.742, train_accuracy: 0.606, fe_train_accuracy: 0.673
#  Validation Loss: 577.575, , FE_Loss_val: 546.833, val_accuracy: 0.625, fe_val_accuracy: 0.693
# E-step Time in Sec.=:  0.37
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   14 Acceptance Rate: 0.747 Loss: 5051.666, FE_Loss: 5016.325, RE_Loss_sum: 35.341, train_accuracy: 0.614, fe_train_accuracy: 0.672
#  Validation Loss: 576.154, , FE_Loss_val: 540.813, val_accuracy: 0.628, fe_val_accuracy: 0.693
# E-step Time in Sec.=:  0.38
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   15 Acceptance Rate: 0.333 Loss: 5024.228, FE_Loss: 4980.077, RE_Loss_sum: 44.150, train_accuracy: 0.631, fe_train_accuracy: 0.676
#  Validation Loss: 580.334, , FE_Loss_val: 536.184, val_accuracy: 0.649, fe_val_accuracy: 0.696
# E-step Time in Sec.=:  0.05
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   16 Acceptance Rate: 1.000 Loss: 4976.395, FE_Loss: 4917.338, RE_Loss_sum: 59.057, train_accuracy: 0.629, fe_train_accuracy: 0.681
#  Validation Loss: 591.994, , FE_Loss_val: 532.937, val_accuracy: 0.644, fe_val_accuracy: 0.709
# E-step Time in Sec.=:  0.37
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   17 Acceptance Rate: 0.452 Loss: 4928.285, FE_Loss: 4874.505, RE_Loss_sum: 53.780, train_accuracy: 0.648, fe_train_accuracy: 0.729
#  Validation Loss: 582.329, , FE_Loss_val: 528.549, val_accuracy: 0.664, fe_val_accuracy: 0.735
# E-step Time in Sec.=:  0.12
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   18 Acceptance Rate: 1.000 Loss: 4843.812, FE_Loss: 4799.401, RE_Loss_sum: 44.410, train_accuracy: 0.671, fe_train_accuracy: 0.724
#  Validation Loss: 565.631, , FE_Loss_val: 521.221, val_accuracy: 0.686, fe_val_accuracy: 0.728
# E-step Time in Sec.=:  0.2
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   19 Acceptance Rate: 0.000 Loss: 4763.868, FE_Loss: 4719.458, RE_Loss_sum: 44.410, train_accuracy: 0.716, fe_train_accuracy: 0.730
#  Validation Loss: 558.465, , FE_Loss_val: 514.055, val_accuracy: 0.727, fe_val_accuracy: 0.726
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.2
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   20 Acceptance Rate: 1.000 Loss: 4689.658, FE_Loss: 4644.264, RE_Loss_sum: 45.395, train_accuracy: 0.742, fe_train_accuracy: 0.731
#  Validation Loss: 551.042, , FE_Loss_val: 505.647, val_accuracy: 0.746, fe_val_accuracy: 0.723
# E-step Time in Sec.=:  0.38
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   21 Acceptance Rate: 1.000 Loss: 4620.817, FE_Loss: 4573.074, RE_Loss_sum: 47.743, train_accuracy: 0.754, fe_train_accuracy: 0.728
#  Validation Loss: 543.980, , FE_Loss_val: 496.237, val_accuracy: 0.753, fe_val_accuracy: 0.717
# E-step Time in Sec.=:  0.21
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   22 Acceptance Rate: 0.000 Loss: 4576.404, FE_Loss: 4528.661, RE_Loss_sum: 47.743, train_accuracy: 0.764, fe_train_accuracy: 0.727
#  Validation Loss: 538.792, , FE_Loss_val: 491.050, val_accuracy: 0.766, fe_val_accuracy: 0.720
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.15
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   23 Acceptance Rate: 1.000 Loss: 4541.194, FE_Loss: 4497.329, RE_Loss_sum: 43.865, train_accuracy: 0.770, fe_train_accuracy: 0.727
#  Validation Loss: 531.382, , FE_Loss_val: 487.516, val_accuracy: 0.777, fe_val_accuracy: 0.726
# E-step Time in Sec.=:  0.37
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   24 Acceptance Rate: 0.000 Loss: 4509.042, FE_Loss: 4465.176, RE_Loss_sum: 43.865, train_accuracy: 0.774, fe_train_accuracy: 0.728
#  Validation Loss: 527.832, , FE_Loss_val: 483.966, val_accuracy: 0.779, fe_val_accuracy: 0.727
# E-step Time in Sec.=:  0.05
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   25 Acceptance Rate: 1.000 Loss: 4478.378, FE_Loss: 4436.748, RE_Loss_sum: 41.630, train_accuracy: 0.776, fe_train_accuracy: 0.729
#  Validation Loss: 525.062, , FE_Loss_val: 483.432, val_accuracy: 0.782, fe_val_accuracy: 0.730
# E-step Time in Sec.=:  0.54
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   26 Acceptance Rate: 1.000 Loss: 4419.092, FE_Loss: 4386.209, RE_Loss_sum: 32.883, train_accuracy: 0.780, fe_train_accuracy: 0.730
#  Validation Loss: 509.841, , FE_Loss_val: 476.958, val_accuracy: 0.788, fe_val_accuracy: 0.734
# E-step Time in Sec.=:  0.55
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   27 Acceptance Rate: 0.143 Loss: 4407.109, FE_Loss: 4369.866, RE_Loss_sum: 37.243, train_accuracy: 0.782, fe_train_accuracy: 0.733
#  Validation Loss: 511.780, , FE_Loss_val: 474.537, val_accuracy: 0.794, fe_val_accuracy: 0.736
# E-step Time in Sec.=:  0.07
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   28 Acceptance Rate: 1.000 Loss: 4364.122, FE_Loss: 4316.634, RE_Loss_sum: 47.488, train_accuracy: 0.784, fe_train_accuracy: 0.733
#  Validation Loss: 518.016, , FE_Loss_val: 470.528, val_accuracy: 0.791, fe_val_accuracy: 0.735
# E-step Time in Sec.=:  0.12
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   29 Acceptance Rate: 1.000 Loss: 4299.245, FE_Loss: 4268.414, RE_Loss_sum: 30.831, train_accuracy: 0.785, fe_train_accuracy: 0.734
#  Validation Loss: 493.657, , FE_Loss_val: 462.826, val_accuracy: 0.797, fe_val_accuracy: 0.745
# E-step Time in Sec.=:  0.38
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   30 Acceptance Rate: 0.000 Loss: 4268.664, FE_Loss: 4237.833, RE_Loss_sum: 30.831, train_accuracy: 0.786, fe_train_accuracy: 0.735
#  Validation Loss: 490.198, , FE_Loss_val: 459.367, val_accuracy: 0.798, fe_val_accuracy: 0.745
# E-step Time in Sec.=:  0.04
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   31 Acceptance Rate: 1.000 Loss: 4271.803, FE_Loss: 4225.556, RE_Loss_sum: 46.247, train_accuracy: 0.787, fe_train_accuracy: 0.734
#  Validation Loss: 504.490, , FE_Loss_val: 458.243, val_accuracy: 0.795, fe_val_accuracy: 0.742
# E-step Time in Sec.=:  0.71
# M-step Time in Sec.=:  1.19
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   32 Acceptance Rate: 0.010 Loss: 4248.568, FE_Loss: 4216.387, RE_Loss_sum: 32.181, train_accuracy: 0.788, fe_train_accuracy: 0.739
#  Validation Loss: 491.285, , FE_Loss_val: 459.104, val_accuracy: 0.799, fe_val_accuracy: 0.747
# E-step Time in Sec.=:  0.31
# M-step Time in Sec.=:  1.2
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   33 Acceptance Rate: 1.000 Loss: 4212.427, FE_Loss: 4193.902, RE_Loss_sum: 18.524, train_accuracy: 0.787, fe_train_accuracy: 0.740
#  Validation Loss: 472.876, , FE_Loss_val: 454.352, val_accuracy: 0.799, fe_val_accuracy: 0.749
# E-step Time in Sec.=:  1.03
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   34 Acceptance Rate: 1.000 Loss: 4218.147, FE_Loss: 4202.334, RE_Loss_sum: 15.813, train_accuracy: 0.786, fe_train_accuracy: 0.739
#  Validation Loss: 471.427, , FE_Loss_val: 455.614, val_accuracy: 0.799, fe_val_accuracy: 0.748
# E-step Time in Sec.=:  0.38
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   35 Acceptance Rate: 0.050 Loss: 4196.881, FE_Loss: 4170.738, RE_Loss_sum: 26.143, train_accuracy: 0.785, fe_train_accuracy: 0.742
#  Validation Loss: 475.736, , FE_Loss_val: 449.593, val_accuracy: 0.801, fe_val_accuracy: 0.750
# E-step Time in Sec.=:  0.37
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.04
# --------------------------------------------
# Iteration:   36 Acceptance Rate: 1.000 Loss: 4223.771, FE_Loss: 4153.020, RE_Loss_sum: 70.751, train_accuracy: 0.786, fe_train_accuracy: 0.742
#  Validation Loss: 521.577, , FE_Loss_val: 450.826, val_accuracy: 0.798, fe_val_accuracy: 0.748
# E-step Time in Sec.=:  0.71
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   37 Acceptance Rate: 0.000 Loss: 4210.594, FE_Loss: 4139.842, RE_Loss_sum: 70.751, train_accuracy: 0.787, fe_train_accuracy: 0.743
#  Validation Loss: 520.190, , FE_Loss_val: 449.439, val_accuracy: 0.797, fe_val_accuracy: 0.751
# E-step Time in Sec.=:  0.38
# M-step Time in Sec.=:  1.19
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   38 Acceptance Rate: 0.000 Loss: 4198.303, FE_Loss: 4127.552, RE_Loss_sum: 70.751, train_accuracy: 0.786, fe_train_accuracy: 0.743
#  Validation Loss: 518.915, , FE_Loss_val: 448.163, val_accuracy: 0.795, fe_val_accuracy: 0.752
# E-step Time in Sec.=:  1.38
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   39 Acceptance Rate: 0.001 Loss: 4184.388, FE_Loss: 4113.637, RE_Loss_sum: 70.751, train_accuracy: 0.787, fe_train_accuracy: 0.744
#  Validation Loss: 517.352, , FE_Loss_val: 446.601, val_accuracy: 0.798, fe_val_accuracy: 0.751
# E-step Time in Sec.=:  0.37
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   40 Acceptance Rate: 1.000 Loss: 4165.098, FE_Loss: 4124.571, RE_Loss_sum: 40.527, train_accuracy: 0.786, fe_train_accuracy: 0.745
#  Validation Loss: 487.863, , FE_Loss_val: 447.337, val_accuracy: 0.796, fe_val_accuracy: 0.758
# E-step Time in Sec.=:  2.7
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   41 Acceptance Rate: 1.000 Loss: 4124.733, FE_Loss: 4100.057, RE_Loss_sum: 24.677, train_accuracy: 0.788, fe_train_accuracy: 0.746
#  Validation Loss: 469.470, , FE_Loss_val: 444.794, val_accuracy: 0.796, fe_val_accuracy: 0.759
# E-step Time in Sec.=:  2.73
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   42 Acceptance Rate: 1.000 Loss: 4066.479, FE_Loss: 4065.518, RE_Loss_sum: 0.961, train_accuracy: 0.785, fe_train_accuracy: 0.748
#  Validation Loss: 442.418, , FE_Loss_val: 441.456, val_accuracy: 0.797, fe_val_accuracy: 0.758
# E-step Time in Sec.=:  2.73
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   43 Acceptance Rate: 1.000 Loss: 4048.166, FE_Loss: 4046.708, RE_Loss_sum: 1.458, train_accuracy: 0.786, fe_train_accuracy: 0.749
#  Validation Loss: 439.383, , FE_Loss_val: 437.925, val_accuracy: 0.794, fe_val_accuracy: 0.759
# E-step Time in Sec.=:  0.88
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   44 Acceptance Rate: 1.000 Loss: 4023.577, FE_Loss: 4019.298, RE_Loss_sum: 4.279, train_accuracy: 0.784, fe_train_accuracy: 0.749
#  Validation Loss: 437.587, , FE_Loss_val: 433.308, val_accuracy: 0.792, fe_val_accuracy: 0.758
# E-step Time in Sec.=:  1.39
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   45 Acceptance Rate: 1.000 Loss: 4040.414, FE_Loss: 4033.938, RE_Loss_sum: 6.475, train_accuracy: 0.781, fe_train_accuracy: 0.749
#  Validation Loss: 442.874, , FE_Loss_val: 436.399, val_accuracy: 0.792, fe_val_accuracy: 0.760
# E-step Time in Sec.=:  0.7
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   46 Acceptance Rate: 0.000 Loss: 4032.565, FE_Loss: 4026.090, RE_Loss_sum: 6.475, train_accuracy: 0.779, fe_train_accuracy: 0.749
#  Validation Loss: 442.159, , FE_Loss_val: 435.684, val_accuracy: 0.788, fe_val_accuracy: 0.760
# E-step Time in Sec.=:  0.37
# M-step Time in Sec.=:  1.16
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   47 Acceptance Rate: 0.000 Loss: 4019.003, FE_Loss: 4012.528, RE_Loss_sum: 6.475, train_accuracy: 0.778, fe_train_accuracy: 0.750
#  Validation Loss: 440.654, , FE_Loss_val: 434.178, val_accuracy: 0.788, fe_val_accuracy: 0.761
# E-step Time in Sec.=:  0.72
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   48 Acceptance Rate: 0.030 Loss: 4008.068, FE_Loss: 4004.749, RE_Loss_sum: 3.319, train_accuracy: 0.779, fe_train_accuracy: 0.751
#  Validation Loss: 437.728, , FE_Loss_val: 434.409, val_accuracy: 0.786, fe_val_accuracy: 0.758
# E-step Time in Sec.=:  2.74
# M-step Time in Sec.=:  1.18
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   49 Acceptance Rate: 1.000 Loss: 3983.022, FE_Loss: 3982.256, RE_Loss_sum: 0.766, train_accuracy: 0.778, fe_train_accuracy: 0.751
#  Validation Loss: 432.018, , FE_Loss_val: 431.252, val_accuracy: 0.786, fe_val_accuracy: 0.759
# E-step Time in Sec.=:  2.73
# M-step Time in Sec.=:  1.17
# Postprocessing Time in Sec.=:  0.03
# --------------------------------------------
# Iteration:   50 Acceptance Rate: 1.000 Loss: 3953.924, FE_Loss: 3980.493, RE_Loss_sum: -26.569, train_accuracy: 0.776, fe_train_accuracy: 0.755
#  Validation Loss: 402.011, , FE_Loss_val: 428.579, val_accuracy: 0.785, fe_val_accuracy: 0.756
# Early stopping of FE by val_accuracy at 50 iterations
# Early stopping of RE0 by val_accuracy at 50 iterations
# E-step Time in Sec.=:  2.78
# M-step Time in Sec.=:  1.2
# Postprocessing Time in Sec.=:  0.03
# ListWrapper([<tf.Variable 'stddev_z0:0' shape=(7,) dtype=float32, numpy=
# array([0.07457956, 0.0208085 , 2.1848354 , 0.04195804, 5.510772  ,
#        0.0400784 , 0.05376177], dtype=float32)>])
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Mean
# Accuracy         0.776
# Test Accuracy    0.785
# dtype: float32
# 95CI low
# Accuracy        NaN
# Test Accuracy   NaN
# dtype: float32
# 95CI high
# Accuracy        NaN
# Test Accuracy   NaN
# dtype: float32
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\3480347485.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figDBGMENN.show()
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\3480347485.py:22: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figGradsGMENN.show()

# %%
np.array(model.random_effects)[0][0]
# Out:
# array([-0.10153116, -0.06208413, -0.05700963, -0.01994077, -0.05761676,
#        -0.04363593, -0.11693536, -0.0123521 , -0.02889139, -0.05310429],
#       dtype=float32)

# %%
np.array(model.effect_z_samples).shape
# Out:
# (1, 51, 7, 10)

# %%
dictBuild = {"qs": [10], 
             "fe_model": BaseMLPGMENN, 
             "initial_stds": [[1.]*(1+arrX.shape[1]+4)], 
             "target": "binary", 
             "num_outputs": 1, 
             "RS": 283}
dictCompile = config
dfResultsGMENN, dfGradsGMENN, figDBGMENN = cross_validate(RandomInterceptNetwork,  
                                                                            use_z=False, 
                                                                            build_args=dictBuild, 
                                                                            compile_args=dictCompile,
                                                                                    epochs=100)
figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.png'))
figDBGMENN.savefig(os.path.join(strOutputDir, 'GMENN_decision_boundaries.svg'))
figDBGMENN.show()

figGradsGMENN, axGradsGMENN = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsGMENN, x='Feature', y='Gradient', ax=axGradsGMENN, color='C0')
axGradsGMENN.set_ylabel('Gradient magnitude')
figGradsGMENN.savefig(os.path.join(strOutputDir, 'GMENN_feature_gradients.png'))
figGradsGMENN.savefig(os.path.join(strOutputDir, 'GMENN_feature_gradients.svg'))
figGradsGMENN.show()

compute_95ci(dfResultsGMENN)
# Out:
# Training fold 9
# --------------------------------------------
# Iteration:    0 Acceptance Rate: 1.000 Loss: 7108.708, FE_Loss: 7013.535, RE_Loss_sum: 95.173, train_accuracy: 0.509, fe_train_accuracy: 0.500
#  Validation Loss: 891.327, , FE_Loss_val: 796.153, val_accuracy: 0.501, fe_val_accuracy: 0.500
# E-step Time in Sec.=:  3.31
# M-step Time in Sec.=:  8.21
# Postprocessing Time in Sec.=:  1.45
# --------------------------------------------
# Iteration:    1 Acceptance Rate: 0.000 Loss: 7000.359, FE_Loss: 6905.186, RE_Loss_sum: 95.173, train_accuracy: 0.515, fe_train_accuracy: 0.535
#  Validation Loss: 875.392, , FE_Loss_val: 780.219, val_accuracy: 0.502, fe_val_accuracy: 0.544
# E-step Time in Sec.=:  3.07
# M-step Time in Sec.=:  3.49
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:    2 Acceptance Rate: 1.000 Loss: 6226.973, FE_Loss: 6140.315, RE_Loss_sum: 86.658, train_accuracy: 0.526, fe_train_accuracy: 0.570
#  Validation Loss: 772.707, , FE_Loss_val: 686.049, val_accuracy: 0.504, fe_val_accuracy: 0.595
# E-step Time in Sec.=:  0.15
# M-step Time in Sec.=:  3.5
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:    3 Acceptance Rate: 1.000 Loss: 5761.396, FE_Loss: 5664.622, RE_Loss_sum: 96.773, train_accuracy: 0.530, fe_train_accuracy: 0.577
#  Validation Loss: 710.816, , FE_Loss_val: 614.042, val_accuracy: 0.524, fe_val_accuracy: 0.593
# E-step Time in Sec.=:  0.14
# M-step Time in Sec.=:  3.43
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:    4 Acceptance Rate: 0.000 Loss: 5732.938, FE_Loss: 5636.165, RE_Loss_sum: 96.773, train_accuracy: 0.565, fe_train_accuracy: 0.580
#  Validation Loss: 707.335, , FE_Loss_val: 610.562, val_accuracy: 0.572, fe_val_accuracy: 0.600
# E-step Time in Sec.=:  0.09
# M-step Time in Sec.=:  3.45
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:    5 Acceptance Rate: 1.000 Loss: 5623.086, FE_Loss: 5512.172, RE_Loss_sum: 110.914, train_accuracy: 0.568, fe_train_accuracy: 0.580
#  Validation Loss: 707.480, , FE_Loss_val: 596.566, val_accuracy: 0.582, fe_val_accuracy: 0.609
# E-step Time in Sec.=:  0.56
# M-step Time in Sec.=:  3.3
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:    6 Acceptance Rate: 0.000 Loss: 5600.587, FE_Loss: 5489.673, RE_Loss_sum: 110.914, train_accuracy: 0.582, fe_train_accuracy: 0.580
#  Validation Loss: 704.552, , FE_Loss_val: 593.638, val_accuracy: 0.607, fe_val_accuracy: 0.610
# E-step Time in Sec.=:  0.1
# M-step Time in Sec.=:  3.42
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:    7 Acceptance Rate: 1.000 Loss: 5507.926, FE_Loss: 5431.175, RE_Loss_sum: 76.751, train_accuracy: 0.581, fe_train_accuracy: 0.580
#  Validation Loss: 669.071, , FE_Loss_val: 592.320, val_accuracy: 0.599, fe_val_accuracy: 0.612
# E-step Time in Sec.=:  2.79
# M-step Time in Sec.=:  3.33
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:    8 Acceptance Rate: 1.000 Loss: 5434.220, FE_Loss: 5349.192, RE_Loss_sum: 85.027, train_accuracy: 0.583, fe_train_accuracy: 0.653
#  Validation Loss: 660.676, , FE_Loss_val: 575.649, val_accuracy: 0.598, fe_val_accuracy: 0.676
# E-step Time in Sec.=:  0.56
# M-step Time in Sec.=:  3.34
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:    9 Acceptance Rate: 0.000 Loss: 5368.537, FE_Loss: 5283.510, RE_Loss_sum: 85.027, train_accuracy: 0.582, fe_train_accuracy: 0.670
#  Validation Loss: 653.599, , FE_Loss_val: 568.572, val_accuracy: 0.596, fe_val_accuracy: 0.691
# E-step Time in Sec.=:  0.1
# M-step Time in Sec.=:  3.44
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   10 Acceptance Rate: 1.000 Loss: 5294.164, FE_Loss: 5235.314, RE_Loss_sum: 58.850, train_accuracy: 0.585, fe_train_accuracy: 0.661
#  Validation Loss: 623.813, , FE_Loss_val: 564.964, val_accuracy: 0.595, fe_val_accuracy: 0.680
# E-step Time in Sec.=:  1.9
# M-step Time in Sec.=:  3.33
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   11 Acceptance Rate: 1.000 Loss: 5230.988, FE_Loss: 5167.860, RE_Loss_sum: 63.128, train_accuracy: 0.589, fe_train_accuracy: 0.666
#  Validation Loss: 619.591, , FE_Loss_val: 556.463, val_accuracy: 0.610, fe_val_accuracy: 0.682
# E-step Time in Sec.=:  0.34
# M-step Time in Sec.=:  3.3
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   12 Acceptance Rate: 0.000 Loss: 5177.304, FE_Loss: 5114.176, RE_Loss_sum: 63.128, train_accuracy: 0.598, fe_train_accuracy: 0.671
#  Validation Loss: 613.715, , FE_Loss_val: 550.587, val_accuracy: 0.621, fe_val_accuracy: 0.692
# E-step Time in Sec.=:  0.09
# M-step Time in Sec.=:  3.32
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   13 Acceptance Rate: 1.000 Loss: 5103.066, FE_Loss: 5072.273, RE_Loss_sum: 30.793, train_accuracy: 0.606, fe_train_accuracy: 0.673
#  Validation Loss: 577.617, , FE_Loss_val: 546.824, val_accuracy: 0.625, fe_val_accuracy: 0.694
# E-step Time in Sec.=:  1.02
# M-step Time in Sec.=:  3.37
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   14 Acceptance Rate: 0.694 Loss: 5051.665, FE_Loss: 5016.355, RE_Loss_sum: 35.309, train_accuracy: 0.614, fe_train_accuracy: 0.672
#  Validation Loss: 576.053, , FE_Loss_val: 540.743, val_accuracy: 0.629, fe_val_accuracy: 0.695
# E-step Time in Sec.=:  1.04
# M-step Time in Sec.=:  3.31
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   15 Acceptance Rate: 0.168 Loss: 5019.475, FE_Loss: 4977.429, RE_Loss_sum: 42.046, train_accuracy: 0.630, fe_train_accuracy: 0.676
#  Validation Loss: 578.266, , FE_Loss_val: 536.220, val_accuracy: 0.649, fe_val_accuracy: 0.696
# E-step Time in Sec.=:  0.12
# M-step Time in Sec.=:  3.45
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   16 Acceptance Rate: 1.000 Loss: 4969.723, FE_Loss: 4925.712, RE_Loss_sum: 44.011, train_accuracy: 0.624, fe_train_accuracy: 0.680
#  Validation Loss: 577.293, , FE_Loss_val: 533.281, val_accuracy: 0.639, fe_val_accuracy: 0.713
# E-step Time in Sec.=:  1.02
# M-step Time in Sec.=:  3.51
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   17 Acceptance Rate: 1.000 Loss: 4929.701, FE_Loss: 4885.375, RE_Loss_sum: 44.326, train_accuracy: 0.646, fe_train_accuracy: 0.729
#  Validation Loss: 574.320, , FE_Loss_val: 529.993, val_accuracy: 0.653, fe_val_accuracy: 0.733
# E-step Time in Sec.=:  0.54
# M-step Time in Sec.=:  3.38
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   18 Acceptance Rate: 0.000 Loss: 4880.377, FE_Loss: 4836.051, RE_Loss_sum: 44.326, train_accuracy: 0.670, fe_train_accuracy: 0.731
#  Validation Loss: 569.972, , FE_Loss_val: 525.645, val_accuracy: 0.682, fe_val_accuracy: 0.729
# E-step Time in Sec.=:  0.1
# M-step Time in Sec.=:  3.39
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   19 Acceptance Rate: 1.000 Loss: 4781.858, FE_Loss: 4718.549, RE_Loss_sum: 63.310, train_accuracy: 0.715, fe_train_accuracy: 0.724
#  Validation Loss: 577.269, , FE_Loss_val: 513.959, val_accuracy: 0.724, fe_val_accuracy: 0.725
# E-step Time in Sec.=:  1.01
# M-step Time in Sec.=:  3.38
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   20 Acceptance Rate: 1.000 Loss: 4727.783, FE_Loss: 4662.203, RE_Loss_sum: 65.580, train_accuracy: 0.731, fe_train_accuracy: 0.728
#  Validation Loss: 574.093, , FE_Loss_val: 508.513, val_accuracy: 0.738, fe_val_accuracy: 0.729
# E-step Time in Sec.=:  1.04
# M-step Time in Sec.=:  3.3
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   21 Acceptance Rate: 0.000 Loss: 4690.115, FE_Loss: 4624.535, RE_Loss_sum: 65.580, train_accuracy: 0.747, fe_train_accuracy: 0.730
#  Validation Loss: 570.261, , FE_Loss_val: 504.681, val_accuracy: 0.745, fe_val_accuracy: 0.719
# E-step Time in Sec.=:  0.1
# M-step Time in Sec.=:  3.4
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   22 Acceptance Rate: 1.000 Loss: 4639.934, FE_Loss: 4588.246, RE_Loss_sum: 51.688, train_accuracy: 0.763, fe_train_accuracy: 0.730
#  Validation Loss: 552.899, , FE_Loss_val: 501.211, val_accuracy: 0.766, fe_val_accuracy: 0.720
# E-step Time in Sec.=:  1.83
# M-step Time in Sec.=:  3.39
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   23 Acceptance Rate: 0.250 Loss: 4617.576, FE_Loss: 4561.234, RE_Loss_sum: 56.341, train_accuracy: 0.770, fe_train_accuracy: 0.729
#  Validation Loss: 554.812, , FE_Loss_val: 498.470, val_accuracy: 0.778, fe_val_accuracy: 0.725
# E-step Time in Sec.=:  0.12
# M-step Time in Sec.=:  3.44
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   24 Acceptance Rate: 1.000 Loss: 4547.719, FE_Loss: 4478.180, RE_Loss_sum: 69.539, train_accuracy: 0.774, fe_train_accuracy: 0.729
#  Validation Loss: 556.700, , FE_Loss_val: 487.161, val_accuracy: 0.781, fe_val_accuracy: 0.725
# E-step Time in Sec.=:  1.0
# M-step Time in Sec.=:  3.37
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   25 Acceptance Rate: 1.000 Loss: 4489.909, FE_Loss: 4422.980, RE_Loss_sum: 66.928, train_accuracy: 0.778, fe_train_accuracy: 0.734
#  Validation Loss: 544.960, , FE_Loss_val: 478.031, val_accuracy: 0.786, fe_val_accuracy: 0.735
# E-step Time in Sec.=:  1.01
# M-step Time in Sec.=:  3.32
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   26 Acceptance Rate: 0.000 Loss: 4437.557, FE_Loss: 4370.629, RE_Loss_sum: 66.928, train_accuracy: 0.781, fe_train_accuracy: 0.735
#  Validation Loss: 538.501, , FE_Loss_val: 471.573, val_accuracy: 0.794, fe_val_accuracy: 0.738
# E-step Time in Sec.=:  0.11
# M-step Time in Sec.=:  3.41
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   27 Acceptance Rate: 1.000 Loss: 4397.692, FE_Loss: 4334.076, RE_Loss_sum: 63.616, train_accuracy: 0.784, fe_train_accuracy: 0.735
#  Validation Loss: 534.761, , FE_Loss_val: 471.145, val_accuracy: 0.793, fe_val_accuracy: 0.736
# E-step Time in Sec.=:  1.0
# M-step Time in Sec.=:  3.25
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   28 Acceptance Rate: 1.000 Loss: 4360.407, FE_Loss: 4299.232, RE_Loss_sum: 61.175, train_accuracy: 0.782, fe_train_accuracy: 0.730
#  Validation Loss: 523.066, , FE_Loss_val: 461.891, val_accuracy: 0.791, fe_val_accuracy: 0.737
# E-step Time in Sec.=:  1.85
# M-step Time in Sec.=:  3.33
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   29 Acceptance Rate: 0.000 Loss: 4342.160, FE_Loss: 4280.985, RE_Loss_sum: 61.175, train_accuracy: 0.783, fe_train_accuracy: 0.733
#  Validation Loss: 521.474, , FE_Loss_val: 460.299, val_accuracy: 0.794, fe_val_accuracy: 0.739
# E-step Time in Sec.=:  0.1
# M-step Time in Sec.=:  3.37
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   30 Acceptance Rate: 1.000 Loss: 4312.880, FE_Loss: 4259.875, RE_Loss_sum: 53.005, train_accuracy: 0.785, fe_train_accuracy: 0.733
#  Validation Loss: 511.806, , FE_Loss_val: 458.801, val_accuracy: 0.795, fe_val_accuracy: 0.743
# E-step Time in Sec.=:  1.23
# M-step Time in Sec.=:  3.27
# Postprocessing Time in Sec.=:  0.1
# --------------------------------------------
# Iteration:   31 Acceptance Rate: 1.000 Loss: 4290.426, FE_Loss: 4234.339, RE_Loss_sum: 56.088, train_accuracy: 0.783, fe_train_accuracy: 0.732
#  Validation Loss: 511.651, , FE_Loss_val: 455.564, val_accuracy: 0.790, fe_val_accuracy: 0.743
# E-step Time in Sec.=:  0.55
# M-step Time in Sec.=:  3.34
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   32 Acceptance Rate: 0.000 Loss: 4274.257, FE_Loss: 4218.169, RE_Loss_sum: 56.088, train_accuracy: 0.784, fe_train_accuracy: 0.734
#  Validation Loss: 510.252, , FE_Loss_val: 454.164, val_accuracy: 0.792, fe_val_accuracy: 0.744
# E-step Time in Sec.=:  0.1
# M-step Time in Sec.=:  3.43
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   33 Acceptance Rate: 1.000 Loss: 4262.384, FE_Loss: 4204.540, RE_Loss_sum: 57.844, train_accuracy: 0.786, fe_train_accuracy: 0.740
#  Validation Loss: 514.099, , FE_Loss_val: 456.254, val_accuracy: 0.793, fe_val_accuracy: 0.745
# E-step Time in Sec.=:  0.99
# M-step Time in Sec.=:  3.36
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   34 Acceptance Rate: 0.871 Loss: 4234.822, FE_Loss: 4187.010, RE_Loss_sum: 47.813, train_accuracy: 0.786, fe_train_accuracy: 0.741
#  Validation Loss: 500.078, , FE_Loss_val: 452.265, val_accuracy: 0.801, fe_val_accuracy: 0.748
# E-step Time in Sec.=:  0.53
# M-step Time in Sec.=:  3.38
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   35 Acceptance Rate: 0.000 Loss: 4207.854, FE_Loss: 4160.041, RE_Loss_sum: 47.813, train_accuracy: 0.786, fe_train_accuracy: 0.741
#  Validation Loss: 497.072, , FE_Loss_val: 449.260, val_accuracy: 0.800, fe_val_accuracy: 0.748
# E-step Time in Sec.=:  0.11
# M-step Time in Sec.=:  3.48
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   36 Acceptance Rate: 1.000 Loss: 4178.713, FE_Loss: 4132.557, RE_Loss_sum: 46.156, train_accuracy: 0.788, fe_train_accuracy: 0.742
#  Validation Loss: 495.079, , FE_Loss_val: 448.923, val_accuracy: 0.804, fe_val_accuracy: 0.747
# E-step Time in Sec.=:  2.79
# M-step Time in Sec.=:  3.32
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   37 Acceptance Rate: 0.249 Loss: 4149.146, FE_Loss: 4109.136, RE_Loss_sum: 40.010, train_accuracy: 0.787, fe_train_accuracy: 0.743
#  Validation Loss: 486.302, , FE_Loss_val: 446.293, val_accuracy: 0.804, fe_val_accuracy: 0.751
# E-step Time in Sec.=:  0.58
# M-step Time in Sec.=:  3.37
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   38 Acceptance Rate: 1.000 Loss: 4158.795, FE_Loss: 4117.063, RE_Loss_sum: 41.732, train_accuracy: 0.785, fe_train_accuracy: 0.744
#  Validation Loss: 488.618, , FE_Loss_val: 446.886, val_accuracy: 0.799, fe_val_accuracy: 0.750
# E-step Time in Sec.=:  1.9
# M-step Time in Sec.=:  3.44
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   39 Acceptance Rate: 0.000 Loss: 4143.098, FE_Loss: 4101.366, RE_Loss_sum: 41.732, train_accuracy: 0.784, fe_train_accuracy: 0.744
#  Validation Loss: 486.940, , FE_Loss_val: 445.208, val_accuracy: 0.795, fe_val_accuracy: 0.749
# E-step Time in Sec.=:  0.52
# M-step Time in Sec.=:  3.36
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   40 Acceptance Rate: 1.000 Loss: 4102.415, FE_Loss: 4074.719, RE_Loss_sum: 27.695, train_accuracy: 0.779, fe_train_accuracy: 0.746
#  Validation Loss: 466.802, , FE_Loss_val: 439.107, val_accuracy: 0.793, fe_val_accuracy: 0.759
# E-step Time in Sec.=:  3.86
# M-step Time in Sec.=:  3.47
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   41 Acceptance Rate: 1.000 Loss: 4118.120, FE_Loss: 4076.707, RE_Loss_sum: 41.413, train_accuracy: 0.779, fe_train_accuracy: 0.745
#  Validation Loss: 485.568, , FE_Loss_val: 444.155, val_accuracy: 0.790, fe_val_accuracy: 0.750
# E-step Time in Sec.=:  1.9
# M-step Time in Sec.=:  3.54
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   42 Acceptance Rate: 0.000 Loss: 4100.171, FE_Loss: 4058.758, RE_Loss_sum: 41.413, train_accuracy: 0.778, fe_train_accuracy: 0.745
#  Validation Loss: 483.605, , FE_Loss_val: 442.192, val_accuracy: 0.789, fe_val_accuracy: 0.750
# E-step Time in Sec.=:  0.57
# M-step Time in Sec.=:  3.4
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   43 Acceptance Rate: 1.000 Loss: 4068.202, FE_Loss: 4030.749, RE_Loss_sum: 37.453, train_accuracy: 0.777, fe_train_accuracy: 0.745
#  Validation Loss: 476.915, , FE_Loss_val: 439.462, val_accuracy: 0.790, fe_val_accuracy: 0.754
# E-step Time in Sec.=:  3.65
# M-step Time in Sec.=:  3.41
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   44 Acceptance Rate: 1.000 Loss: 4058.826, FE_Loss: 4021.947, RE_Loss_sum: 36.879, train_accuracy: 0.777, fe_train_accuracy: 0.747
#  Validation Loss: 473.939, , FE_Loss_val: 437.061, val_accuracy: 0.785, fe_val_accuracy: 0.754
# E-step Time in Sec.=:  1.12
# M-step Time in Sec.=:  3.53
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   45 Acceptance Rate: 1.000 Loss: 4040.790, FE_Loss: 4003.800, RE_Loss_sum: 36.990, train_accuracy: 0.776, fe_train_accuracy: 0.747
#  Validation Loss: 469.523, , FE_Loss_val: 432.533, val_accuracy: 0.784, fe_val_accuracy: 0.754
# E-step Time in Sec.=:  1.19
# M-step Time in Sec.=:  3.46
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   46 Acceptance Rate: 0.000 Loss: 4025.583, FE_Loss: 3988.593, RE_Loss_sum: 36.990, train_accuracy: 0.775, fe_train_accuracy: 0.748
#  Validation Loss: 467.723, , FE_Loss_val: 430.733, val_accuracy: 0.780, fe_val_accuracy: 0.754
# E-step Time in Sec.=:  0.09
# M-step Time in Sec.=:  3.63
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   47 Acceptance Rate: 1.000 Loss: 4008.639, FE_Loss: 3973.889, RE_Loss_sum: 34.750, train_accuracy: 0.776, fe_train_accuracy: 0.748
#  Validation Loss: 465.737, , FE_Loss_val: 430.987, val_accuracy: 0.782, fe_val_accuracy: 0.762
# E-step Time in Sec.=:  0.42
# M-step Time in Sec.=:  3.47
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   48 Acceptance Rate: 1.000 Loss: 3985.846, FE_Loss: 3952.205, RE_Loss_sum: 33.641, train_accuracy: 0.773, fe_train_accuracy: 0.753
#  Validation Loss: 460.751, , FE_Loss_val: 427.110, val_accuracy: 0.784, fe_val_accuracy: 0.764
# E-step Time in Sec.=:  0.55
# M-step Time in Sec.=:  3.39
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   49 Acceptance Rate: 0.000 Loss: 3978.231, FE_Loss: 3944.590, RE_Loss_sum: 33.641, train_accuracy: 0.772, fe_train_accuracy: 0.755
#  Validation Loss: 459.838, , FE_Loss_val: 426.197, val_accuracy: 0.784, fe_val_accuracy: 0.762
# E-step Time in Sec.=:  0.09
# M-step Time in Sec.=:  3.61
# Postprocessing Time in Sec.=:  0.08
# --------------------------------------------
# Iteration:   50 Acceptance Rate: 1.000 Loss: 3938.491, FE_Loss: 3917.797, RE_Loss_sum: 20.695, train_accuracy: 0.773, fe_train_accuracy: 0.758
#  Validation Loss: 444.660, , FE_Loss_val: 423.965, val_accuracy: 0.784, fe_val_accuracy: 0.761
# E-step Time in Sec.=:  1.03
# M-step Time in Sec.=:  3.33
# Postprocessing Time in Sec.=:  0.09
# --------------------------------------------
# Iteration:   51 Acceptance Rate: 0.277 Loss: 3929.577, FE_Loss: 3906.752, RE_Loss_sum: 22.825, train_accuracy: 0.773, fe_train_accuracy: 0.758
#  Validation Loss: 446.519, , FE_Loss_val: 423.694, val_accuracy: 0.785, fe_val_accuracy: 0.758
# Early stopping of FE by val_accuracy at 51 iterations
# Early stopping of RE0 by val_accuracy at 51 iterations
# E-step Time in Sec.=:  0.12
# M-step Time in Sec.=:  3.67
# Postprocessing Time in Sec.=:  0.08
# ListWrapper([<tf.Variable 'stddev_z0:0' shape=(7,) dtype=float32, numpy=
# array([0.19611645, 0.08001124, 2.2101052 , 0.07511427, 5.956919  ,
#        0.09294966, 0.13292934], dtype=float32)>])
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# Manually added exception for GMENN occured
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\2586190208.py:15: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figDBGMENN.show()
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\2586190208.py:22: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figGradsGMENN.show()
# Mean
# Accuracy         0.773111
# Test Accuracy    0.785000
# dtype: float32
# 95CI low
# Accuracy        NaN
# Test Accuracy   NaN
# dtype: float32
# 95CI high
# Accuracy        NaN
# Test Accuracy   NaN
# dtype: float32

# %%
import numpy as np
# import pandas as pd

import tensorflow.compat.v2 as tf
tf.enable_v2_behavior()

# from tensorflow.keras.layers import Dense, Dropout, Input
# from tensorflow.keras import Model
from tensorflow.keras.layers import ReLU
from tensorflow.keras.activations import sigmoid, softmax, linear
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import f1_score as f1
from tensorflow.keras.metrics import Accuracy,  MeanSquaredError, AUC
from tensorflow_addons.metrics import F1Score, RSquare
from sklearn.metrics import roc_auc_score
from tensorflow.keras.metrics import CategoricalAccuracy as cat_acc
import time

import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors

####
class RandomInterceptNetwork(tf.Module):
    '''
    Single-Category, Random-Intercept Neural Networks.

    To choose the target distribution, specify target="continuous" for regression, target="binary" for binary
    classification and target="categorical" for multi-class classification.

    To fix the stochasticity for the experiments, fix the global random seed with tf.random_seed() as well as the random
    seeds for all non-deterministic functions. The main stochasticity is from the NN initialization and the e-step

    Parameters:
        qs: List with numbers of categories per RE
        fe_model: Any keras model producing an output that fits the target distribution
        target: Target distribution, one of ["continuous", "binary", "categorical"]
        num_outputs: Output size of the fe_model. Should be 1 for continuous and binary targets and the number of
            classes for categorical.
        initial_stds: List of value(s) to initialise the std parameter(s)
        positive_constraint_method: Method used to ensure that std/variance stays positive. One of ["exp", "clip"]. Default: "clip"
        RS: Random seed

    '''
    def __init__(self, qs, fe_model, target="continuous", num_outputs=1, initial_stds=[1.], initial_error_std=1., positive_constraint_method="clip", RS=42):
        self.qs = qs
        self.RS = RS
        self.target = target
        self.num_outputs = num_outputs
        self.fe_model = fe_model
        self.initial_std = initial_stds

        if target == "continuous":
            self.link_function = linear
            self.distribution = tfd.Normal
            if positive_constraint_method == "exp":
                self._stddev_e = tfp.util.TransformedVariable(initial_error_std, bijector=tfb.Exp(), name="stddev_e")
            elif positive_constraint_method == "clip":
                self._stddev_e = tf.Variable(initial_error_std, name='stddev_e', constraint=lambda x: tf.clip_by_value(x, 1e-18, np.infty))

        elif target == "binary":
            self.link_function = sigmoid
            self.distribution = tfd.Bernoulli
        elif target == "categorical":
            self.link_function = softmax
            self.distribution = tfd.OneHotCategorical
        else:
            raise AttributeError("Invalid target type specified. Please specify the target parameter as one of \
                                 ['continuous', 'binary', 'categorical']")

        # Initialize sig2b
        if positive_constraint_method=="exp":
            self._stddev_z = [tfp.util.TransformedVariable(std, bijector=tfb.Exp(), name=f"stddev_z{num}") for num, std in enumerate(self.initial_std)]
        elif positive_constraint_method=="clip":
            self._stddev_z = [tf.Variable(std, name=f'stddev_z{num}', constraint=lambda x: tf.clip_by_value(x, 1e-18, np.infty)) for num, std in enumerate(self.initial_std)]


    def __call__(self, X, Z, training=False):
#         X_random = tf.concat([tf.ones([X.shape[0],1]),X],axis=1)
        
        curr = X
        for i in self.fe_model.layers[:-1]:
            if "dense" in str(i.name):
                curr = i(curr)        
        
        X_random = tf.concat([tf.ones([X.shape[0],1]),X,curr],axis=1)
        
        
        # Let W, b be the parameters of the NN f, b the random effects and sigma the variance of the random effect.
        # Let Rho be the set of all parameters {W, b, sigma}

        # For regression, we assume y ~ Normal(f(X) + b, 1) where b ~ Normal(0, sigma)
        # Hence the probability density function is pdf(y; f(X)+b, 1) = exp(-0.5 (y-(f(x)+b))**2) / (2 pi)**0.5
        # Alternatively, we could formulate the problem like Simchoni as y ~ Normal(f(X), V(sigma))
        if self.target == "continuous":
            priors = [
                # Set up prior distribution Normal(b; 0, sigma)
                tfd.MultivariateNormalDiag(
                    loc=tf.zeros([1+X.shape[1],self.qs[num]]),
                    scale_identity_multiplier=self._stddev_z[num])
                for num in range(len(self._stddev_z))]


            likelihood = lambda *effect_z: tfd.Independent(
                self.distribution(
                    loc = tf.experimental.numpy.ravel(self.fe_model(X, training)) +
                          tf.reduce_sum([tf.gather(effect_z[len(self.qs)-1-num], Z[:, num]) for num in range(len(self.qs))], axis=0),
                    scale=self._stddev_e
                ),
                reinterpreted_batch_ndims=1)

        # For binary classification, we assume y ~ Bernoulli(eta) where eta = f(X) + b and b ~ Normal(0, sigma)
        elif self.target == "binary":
            priors = [
                # Set up prior distribution Normal(b; 0, sigma)
                tfd.MultivariateNormalDiag(
                    loc=tf.zeros([1+X.shape[1]+curr.shape[1],self.qs[num]]),
                    scale_identity_multiplier=self._stddev_z[num])
                for num in range(len(self._stddev_z))]

            likelihood = lambda *effect_z: tfd.Independent(
                self.distribution(
                    logits = tf.experimental.numpy.ravel(self.fe_model(X, training)) +
                          tf.reduce_sum([tf.reduce_sum(tf.multiply(X_random,tf.transpose(tf.gather(effect_z[len(self.qs)-1-num],Z[:,num],axis=1))),axis=1) for num in range(len(self.qs))], axis=0)
                ),
                reinterpreted_batch_ndims=1)

        # For multi-class classification, we assume y ~ Categorical(eta) where eta = f(X) + b and b ~ Normal(0, sigma) and b is a matrix q*c
        elif self.target == "categorical":
            priors = [
                # Set up prior distribution Normal(b; 0, sigma)
                tfd.MultivariateNormalDiag(
                    loc=tf.zeros([1+X.shape[0],self.num_outputs,self.qs[num]]),
                    scale_identity_multiplier=self._stddev_z[num])
                for num in range(len(self._stddev_z))]

            likelihood = lambda *effect_z: tfd.Independent(
                self.distribution(
                    logits = self.fe_model(X, training) +
                             tf.reduce_sum([tf.transpose(tf.gather(effect_z[len(self.qs)-1-num], Z[:, num],axis=1)) for num in range(len(self.qs))], axis=0),
                ),
                reinterpreted_batch_ndims=1)

        # Set the joint distribution as the prior and likelihood for the observed.
        joint = priors + [likelihood]

        # The MLE is solved as min_{W,b,sigma} -log p(y | X, Z; W, b, sigma) = min_{W,b,sigma} -log integral[ p(b; sigma) p(y | X, Z, b; W, b) db
        model = tfd.JointDistributionSequentialAutoBatched(joint)

        model._to_track = self

        return model

    def trace_mcmc(self, states, previous_kernel_results):
        try:
            return previous_kernel_results.log_accept_ratio
        except:
            return previous_kernel_results.inner_results.log_accept_ratio

    # # Set up E-step (MCMC).
    # @tf.function()#autograph=False, jit_compile=True, reduce_retracing=True)
    # def get_mcmc_samples(self, current_state, num_mcmc_samples=tf.constant(1)):

    #     samples, log_accept_ratio = tfp.mcmc.sample_chain(
    #             kernel=self.mcmc_kernel, num_results=num_mcmc_samples, current_state=current_state,
    #             trace_fn= self.trace_mcmc)

    #     acceptance_rate = tf.math.exp(tf.minimum(log_accept_ratio, 0.))

    #     return samples, acceptance_rate

    @tf.function()#autograph=False, jit_compile=True, reduce_retracing=True)
    def get_mcmc_samples(self, current_state, previous_kernel_results, num_mcmc_samples=1):

        samples, _, previous_kernel_results = tfp.mcmc.sample_chain(
                kernel=self.mcmc_kernel, num_results=num_mcmc_samples, current_state=current_state,
                trace_fn= None, previous_kernel_results = previous_kernel_results,
                return_final_kernel_results=True,seed=self.RS)
        try:
            log_accept_ratio = previous_kernel_results.log_accept_ratio
        except:
            log_accept_ratio = previous_kernel_results.inner_results.log_accept_ratio
        acceptance_rate = tf.math.exp(tf.minimum(log_accept_ratio, 0.))

        return samples, acceptance_rate, previous_kernel_results

    # Set up M-step (gradient descent).
    @tf.function()#autograph=False, jit_compile=True, reduce_retracing=True)
    def FE_update_mean_vanilla(self, X, Z, y, current_state):
        zero_state = [tf.zeros(state[0].shape, dtype=tf.float32) for state in current_state]
        with tf.GradientTape() as tape:
            loss = -self(X, Z, training=True).log_prob(current_state + [y]) - tf.reduce_mean(self(X, Z, training=True).log_prob(zero_state + [y]))
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer_fe.apply_gradients(zip(grads,self.trainable_variables))

        return loss, grads

    @tf.function()#autograph=False, jit_compile=True, reduce_retracing=True)
    def FE_update_mean_saem(self, X, Z, y, current_state, previous_loss, iteration_step):
        zero_state = [tf.zeros(state[0].shape, dtype=tf.float32) for state in current_state]
        with tf.GradientTape() as tape:
            vanilla_loss = -self(X, Z, training=True).log_prob(current_state + [y])  - tf.reduce_mean(self(X, Z, training=True).log_prob(zero_state + [y]))
            update_loss = tf.cast(tf.math.subtract(vanilla_loss, previous_loss), tf.float32)
            update_iteration = tf.cast(tf.math.divide(1, iteration_step), tf.float32)
            loss = tf.math.add(previous_loss, tf.math.multiply(update_iteration, update_loss))
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer_fe.apply_gradients(zip(grads,self.trainable_variables))

        return loss, grads

    @tf.function()#autograph=False, jit_compile=True, reduce_retracing=True)
    def FE_update_all_vanilla(self, X, Z, y, current_state):
        zero_state = [tf.zeros(state[0].shape, dtype=tf.float32) for state in current_state]
        with tf.GradientTape() as tape:
            loss = -tf.reduce_mean(self(X, Z, training=True).log_prob(current_state + [y])) - tf.reduce_mean(self(X, Z, training=True).log_prob(zero_state + [y]))
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer_fe.apply_gradients(zip(grads,self.trainable_variables))

        return loss, grads

    @tf.function()#autograph=False, jit_compile=True, reduce_retracing=True)
    def FE_update_all_saem(self, X, Z, y, current_state, previous_loss, iteration_step):
        zero_state = [tf.zeros(state[0].shape, dtype=tf.float32) for state in current_state]
        with tf.GradientTape() as tape:
            vanilla_loss = -tf.reduce_mean(self(X, Z, training=True).log_prob(current_state + [y])) - tf.reduce_mean(self(X, Z, training=True).log_prob(zero_state + [y]))
            update_loss = tf.cast(tf.math.subtract(vanilla_loss, previous_loss), tf.float32)
            update_iteration = tf.cast(tf.math.divide(1, iteration_step), tf.float32)
            loss = tf.math.add(previous_loss, tf.math.multiply(update_iteration, update_loss))
        grads = tape.gradient(loss, self.trainable_variables)
        self.optimizer_fe.apply_gradients(zip(grads,self.trainable_variables))

        return loss, grads


    def one_iteration(self, X, Z, y, current_state, previous_kernel_results, num_mcmc_samples, previous_loss, iteration_step, set_variance_to_sample_std=True):
        # In the e-step the expectation of the complete log-likelihood is determined w.r.t. the conditional distribution p(b | f(X), y)
        e_start = time.time()
        if self.e_mode == "mean":
            input_sample = [tf.reduce_mean(q_state, axis=0) for q_state in current_state]
        elif self.e_mode =="last":
            input_sample = [q_state[-1] for q_state in current_state]
        next_state, acceptance_rate, previous_kernel_results = self.get_mcmc_samples(input_sample, previous_kernel_results, tf.constant(num_mcmc_samples))
        e_end = time.time()

        # The m-step updates p(y | Rho) w.r.t. W, b & sigma
        # The posterior MCMC sample is used to calculate an unbiased estimate of the matginal likelihood up to a constant
        m_start = time.time()
        # Update FE part
        if self.m_mode == "all":
            if not self.fe_converged:
                for index, offset in enumerate(range(0, self.train_size, self.batch_size)):
                    print(f"batch {index}", end="\r")
                    X_batch = X[offset: offset + self.batch_size]
                    Z_batch = Z[offset: offset + self.batch_size]
                    y_batch = y[offset: offset + self.batch_size]

                    if self.type_mcem == "Vanilla":
                        loss, grads = self.FE_update_all_vanilla(X_batch, Z_batch, y_batch, next_state)
                    else:
                        loss, grads = self.FE_update_all_saem(X_batch, Z_batch, y_batch, next_state, previous_loss, iteration_step)
            else:
                loss = -tf.reduce_mean(self.target_log_prob_fn(*zip(next_state)))

                if self.type_mcem == 'SAEM':
                    update_loss = tf.cast(tf.math.subtract(loss, previous_loss), tf.float32)
                    update_iteration = tf.cast(tf.math.divide(1, iteration_step), tf.float32)
                    loss = tf.math.add(previous_loss, tf.math.multiply(update_iteration, update_loss))

                grads = [tf.zeros(i.shape) for i in self.trainable_variables]
        elif self.m_mode == "mean":
            if not self.fe_converged:
                next_state_mean = [tf.reduce_mean(q_state, axis=0) for q_state in next_state]
                for index, offset in enumerate(range(0, self.train_size, self.batch_size)):
                    print(f"batch {index}", end="\r")
                    X_batch = X[offset: offset + self.batch_size]
                    Z_batch = Z[offset: offset + self.batch_size]
                    y_batch = y[offset: offset + self.batch_size]
                    if self.type_mcem == "Vanilla":
                        loss, grads = self.FE_update_mean_vanilla(X_batch, Z_batch, y_batch, next_state_mean)
                    else:
                        loss, grads = self.FE_update_all_saem(X_batch, Z_batch, y_batch, next_state_mean, previous_loss, iteration_step)
            else:
                loss = -tf.reduce_mean(self.target_log_prob_fn(*zip(next_state)))
                if self.type_mcem == 'SAEM':
                    update_loss = tf.cast(tf.math.subtract(loss, previous_loss), tf.float32)
                    update_iteration = tf.cast(tf.math.divide(1, iteration_step), tf.float32)
                    loss = tf.math.add(previous_loss, tf.math.multiply(update_iteration, update_loss)) 
                grads = [tf.zeros(i.shape) for i in self.trainable_variables]

        # Update RE part
        if set_variance_to_sample_std:
            for num, q_num in enumerate(np.where(self.z_indicator)[0]):
                if not self.re_converged[num]:
                    if self.target == "categorical":
                        self.trainable_variables[q_num].assign(tf.math.reduce_std(tf.math.reduce_mean(next_state[num],axis=0),axis=1))
                    else:
                        self.trainable_variables[q_num].assign(tf.math.reduce_std(tf.math.reduce_mean(next_state[num],axis=0),axis=-1))
        m_end = time.time()

        return loss, grads, next_state, e_end-e_start, m_end-m_start, acceptance_rate.numpy(), previous_kernel_results




    def get_mcmc_kernel_init_func(self, type_mcem: str = 'Vanilla', type_kernel: str = 'NUTS', epsilon: float = None, num_of_steps: int = None, min_samples:int = 1, max_samples: int = 1):

        '''
        Implements three different types of Markov Chain Monte Carlo transition kernels:

        -the No U-Turn Sampler, NUTS
        -Hamiltonian Monte Carlo, HMC
        -Metropolis Adjusted Langevin Algorithm, MALA

        Args:
        -type_mcem: the type of Monte Carlo Expectation Maximization (MCEM) Method. Allowed values: ['SAEM', 'Vanilla']
        -type_kernel: required, specifies the type of MCMC. Allowed values: ['NUTS', 'HMC', 'MALA']
        -epsilon: optional, a positive float, defines the step width, if no value is given Dual Averaging is used
        with the optimal acceptance rate for the respective MCMC type. Find out more in Hoffman's canonical paper:
        http://jmlr.org/papers/volume15/hoffman14a/hoffman14a.pdf
        -num_of_steps: required for HMC, a positive integer, the number of steps used by HMC. If you are unsure about
        num_of_steps consider switching to NUTS as that's HMC with an automatic number of steps selection.
        '''

        if type_mcem not in ['SAEM', 'Vanilla']:
            raise AttributeError(f"Unallowed Monte Carlo Expectation Maximization. Current value: {type_mcem}. Allowed values: ['SAEM', 'Vanilla']")
        #MC Initialization
        num_adaption_steps = 500 #similar to burnin for dual averaging
        self.min_samples = min_samples
        self.max_samples = max_samples
        self.type_mcem = type_mcem

        if epsilon is None:
            step_size = 0.01
        else:
            step_size = epsilon

        if max_samples < min_samples:
            print(f"From a Monte Carlo perspective it makes more sense to have min_samples <= max_samples.\
            Current values are min_samples: {min_samples}, max_samples: {max_samples}.")

        if type_kernel == "NUTS":

            target_accept_prob = 0.651

            kernel_out = lambda target_log_prob_fn: tfp.mcmc.NoUTurnSampler(
                target_log_prob_fn=target_log_prob_fn,
                step_size=step_size)

            if epsilon is None:

                kernel_out = lambda target_log_prob_fn:  tfp.mcmc.DualAveragingStepSizeAdaptation(
                                inner_kernel=tfp.mcmc.NoUTurnSampler(
                                target_log_prob_fn=target_log_prob_fn,
                                step_size=step_size),
                                num_adaptation_steps=num_adaption_steps,
                                target_accept_prob = target_accept_prob)

                # kernel_out_adap = lambda kernel_out:  tfp.mcmc.DualAveragingStepSizeAdaptation(
                #                 inner_kernel=kernel_out, num_adaptation_steps=num_adaption_steps,
                #                 target_accept_prob = target_accept_prob)

        elif type_kernel == "HMC":

            target_accept_prob = 0.651

            if isinstance(num_of_steps, int):

                kernel_out = lambda target_log_prob_fn: tfp.mcmc.HamiltonianMonteCarlo(
                                target_log_prob_fn=target_log_prob_fn,
                                step_size=step_size, num_leapfrog_steps = num_of_steps)

                if epsilon is None:

                    kernel_out = lambda target_log_prob_fn: tfp.mcmc.DualAveragingStepSizeAdaptation(
                                    inner_kernel=tfp.mcmc.HamiltonianMonteCarlo(
                                    target_log_prob_fn=target_log_prob_fn,
                                    step_size=step_size, num_leapfrog_steps = num_of_steps),
                                    num_adaptation_steps=num_adaption_steps,
                                    target_accept_prob = target_accept_prob)

            else:

                raise AttributeError("Invalid value for num_of_steps. Please specify an integer or consider switching \
                                        to NUTS by specifying type = 'NUTS' for adaptive number of steps (e.g. no user input required).")


        elif type_kernel == "MALA":

            target_accept_prob = 0.574

            kernel_out = lambda target_log_prob_fn: tfp.mcmc.MetropolisAdjustedLangevinAlgorithm(
                            target_log_prob_fn=target_log_prob_fn,
                            step_size=step_size)

            if epsilon is None:

                raise AttributeError("Please specify epsilon for MALA as Dual Averaging is not supported for MALA.")

        else:

            raise AttributeError("Invalid MCMC type specified. Please select type_kernel from \
                                ['NUTS', 'HMC', MALA']. Currently selected type is: " + type_kernel + ".")
        return(kernel_out)

    def fit(self, X, y, Z,
            val_data=None,
            mcmc_kernel_init_func = lambda x: x, num_mcmc_samples=1,
            e_mode="last", m_mode = "all",
            optimizer_fe=Adam(), set_variance_to_sample_std=True,
            batch_size=100,
            num_iters=1500,
            num_pretrain_fe_iters = 0, num_warmup_iters=0, perc_burnin=0.1,
            print_warmup=500, print_pretraining=5, print_training=500,
            early_stopping_fe=None, early_stopping_metric_fe="train_loss",
            early_stopping_re=None, early_stopping_metric_re="train_loss",
            metrics=[], num_samples_use_for_pred="posterior_mean",
            track_best_model=False, track_best_model_metric = "train_loss"):

        fit_start = time.time()
        self.num_mcmc_samples = num_mcmc_samples
        self.e_mode = e_mode
        self.m_mode = m_mode
        self.optimizer_fe = optimizer_fe
        self.batch_size = batch_size
        self.num_warmup_iters = num_warmup_iters
        self.num_pretrain_fe_iters = num_pretrain_fe_iters
        self.num_iters = num_iters
        self.num_iters_actual = num_iters
        self.effect_z_samples = [[] for _ in range(len(self.qs))]
        self.early_stopping_fe = early_stopping_fe
        self.early_stopping_metric_fe = early_stopping_metric_fe
        self.early_stopping_re = early_stopping_re
        self.early_stopping_metric_re = early_stopping_metric_re
        self.track_best_model = track_best_model
        self.track_best_model_metric = track_best_model_metric
        self.loss_history = {"train_loss": [],
                             "z": [],
                             "z_grads": [],
                             "z_change": [],
                             "fe_grads_absmean": [],
                             "acceptance_rate": [],
                             "fe_loss": [],
                             "re_loss": [],
                             "e_step_time": [],
                             "m_step_time": [],
                             "postprocessing_time": []
                             }
        if self.target == "continuous":
            self.loss_history["e"] = []

        self.fe_converged=False
        self.re_converged=[False]*len(self.qs)

        for metric in metrics:
            self.loss_history["train_" + metric] = []
            self.loss_history["fe_"+ "train_" + metric] = []

        if self.target == "categorical":
            y = tf.one_hot(y, self.num_outputs)

        if not tf.is_tensor(X):
            X = tf.convert_to_tensor(X, dtype=tf.float32)
        if not tf.is_tensor(y):
            y = tf.convert_to_tensor(y,dtype=tf.float32)
        if not tf.is_tensor(Z):
            Z = tf.convert_to_tensor(Z,dtype=tf.int32)


        # The joint distribution is defined with the fixed variables
        data_model = self(X, Z)
        # To obtain the loss function, we pass the sampled vector b and y to compute the log probability of the posterior
        self.target_log_prob_fn = tf.function(lambda *x: data_model.log_prob(x + (y,)))
        self.target_log_prob_parts_fn = tf.function(lambda *x: data_model.log_prob_parts(x + (y,)))

        if val_data is not None:
            X_val, y_val, Z_val = val_data

            if not tf.is_tensor(X_val):
                X_val = tf.convert_to_tensor(X_val,dtype=tf.float32)
            if not tf.is_tensor(y_val):
                if self.target == "continuous":
                    y_val = tf.convert_to_tensor(y_val,dtype=tf.float32)
                else:
                    y_val = tf.convert_to_tensor(y_val,dtype=tf.int32)
            if not tf.is_tensor(Z_val):
                Z_val = tf.convert_to_tensor(Z_val,dtype=tf.int32)

            if self.target == "categorical":
                y_val = tf.one_hot(y_val, self.num_outputs)

            data_model_val = self(X_val, Z_val)
            self.target_log_prob_fn_val = tf.function(lambda *x: data_model_val.log_prob(x + (y_val,)))  # /len(labels_train)
            self.target_log_prob_parts_fn_val = tf.function(lambda *x: data_model_val.log_prob_parts(x + (y_val,)))  # /len(labels_train)
            self.loss_history["val_loss"] = []
            self.loss_history["fe_loss_val"] = []
            for metric in metrics:
                self.loss_history["val_" + metric] = []
                self.loss_history["fe_" + "val_" + metric] = []

        self.mcmc_kernel = mcmc_kernel_init_func(self.target_log_prob_fn)

        # The initial state for HMC is randomly sampled from the prior distribution
        current_state = data_model.sample(1, seed=self.RS)[:-1]
        # kernel_results = mcmc_kernel.bootstrap_results(current_state)
        previous_kernel_results = None

        self.z_indicator = [i.name in [f'stddev_z{num}:0' for num in range(len(self.qs))] for i in self.trainable_variables]
        self.train_size = X.shape[0]



        if early_stopping_fe is not None:
            if early_stopping_metric_fe in ["train_accuracy", "val_accuracy", "train_f1", "val_f1", "train_auc",
                                         "val_auc"]:
                current_best_fe = -np.inf
            else:
                current_best_fe = np.inf

        if early_stopping_re is not None:
            if early_stopping_metric_re in ["train_accuracy", "val_accuracy", "train_f1", "val_f1", "train_auc",
                                         "val_auc"]:
                current_best_re = [-np.inf]*len(self.qs)
            else:
                current_best_re = [np.inf]*len(self.qs)
            early_stop_re = [0] * len(self.qs)

        # Run FE model pretraining with 0-RE variance assumption
        if self.num_pretrain_fe_iters>0:
            zero_state = [tf.zeros(state[0].shape, dtype=tf.float32) for state in current_state]
            last_loss = np.inf
            if val_data is not None:
                last_val_loss = np.inf

            for t in range(num_pretrain_fe_iters):
                with tf.GradientTape() as tape:
                    loss = -self.target_log_prob_fn(*zero_state)
                grads = tape.gradient(loss, self.trainable_variables)
                self.optimizer_fe.apply_gradients(zip(grads, self.trainable_variables))

                if val_data is not None:
                    val_loss = -self.target_log_prob_fn_val(*zero_state).numpy()

                if t % print_pretraining == 0 or t == num_pretrain_fe_iters - 1:
                    fe_str = "FE Pretraining Iteration: {:>3} Loss: {:.3f}".format(
                        t, loss)
                    if val_data is not None:
                        fe_str += ", Validation Loss: {:.3f}".format(val_loss)
                    print(fe_str)

                if val_data is not None:
                    if last_val_loss<val_loss:
                        break
                    else:
                        last_val_loss = val_loss
                else:
                    if last_loss<loss:
                        break
                    else:
                        last_loss = loss

        # Run warm-up stage.
        if num_warmup_iters>0:
            num_mcmc_samples_warmup = np.concatenate([[0+i]*round(self.num_warmup_iters/self.max_samples) for i in range(self.min_samples,self.max_samples+1)])[:self.num_warmup_iters].astype(np.int32)
            for t in range(num_warmup_iters):
                # last_state = current_state
                start = time.time()
                if self.e_mode == "mean":
                    input_sample = [tf.reduce_mean(q_state, axis=0) for q_state in current_state]
                elif self.e_mode == "last":
                    input_sample = [q_state[-1] for q_state in current_state]
                current_state, acceptance_rate, previous_kernel_results = self.get_mcmc_samples(input_sample, previous_kernel_results, num_mcmc_samples_warmup[t])
                end = time.time()
                print("E-step Time in Sec.=: ", round(end - start, 2))

                if t % print_warmup == 0 or t == num_warmup_iters - 1:
                    print("Warm-Up Iteration: {:>3} Acceptance Rate: {:.3f}".format(
                        t, tf.reduce_mean(acceptance_rate).numpy()))

            if set_variance_to_sample_std:
                for num,q_num in enumerate(np.where(self.z_indicator)[0]):
                    if not self.re_converged[num]:
                        if self.target == "categorical":
                            self.trainable_variables[q_num].assign(
                                tf.math.reduce_std(tf.math.reduce_mean(current_state[num], axis=0), axis=1))
                        else:
                            self.trainable_variables[q_num].assign(
                                tf.math.reduce_std(tf.math.reduce_mean(current_state[num], axis=0)))

        if self.track_best_model:
            if self.track_best_model_metric in ["train_accuracy", "val_accuracy", "train_f1", "val_f1", "train_auc", "val_auc"]:
                self.best_score = -np.inf
            else:
                self.best_score = np.inf


        # Run training.
        num_mcmc_samples_training = np.concatenate([[0+i]*round(self.num_iters/self.max_samples) for i in range(self.min_samples,self.max_samples+1)])[:self.num_iters].astype(np.int32)
        previous_loss = -tf.reduce_mean(self.target_log_prob_fn(*zip(current_state)))
        for t in range(num_iters):
            iteration_step = tf.convert_to_tensor(t+1, dtype=tf.int32)
            loss, grads, current_state, e_time, m_time, acceptance_rate, previous_kernel_results = self.one_iteration(X, Z, y, current_state, previous_kernel_results, num_mcmc_samples_training[t], previous_loss, iteration_step)
            previous_loss = loss

            start_postprocessing = time.time()

            if self.m_mode =="all":
                loss = -tf.reduce_mean(self.target_log_prob_fn(*zip(current_state)))
                log_prob_parts = [-tf.reduce_mean(i).numpy() for i in self.target_log_prob_parts_fn(*current_state)]
            elif self.m_mode == "mean":
                current_state_mean = [tf.reduce_mean(q_state, axis=0) for q_state in current_state]
                loss = -self.target_log_prob_fn(*current_state_mean)
                log_prob_parts = [-i.numpy() for i in self.target_log_prob_parts_fn(*current_state_mean)]

            for q in range(len(self.qs)):
                self.effect_z_samples[q] += [i.numpy() for i in current_state[q]]

            self.random_effects = [np.mean(effect[round(t*(perc_burnin)):], axis=0) for effect in self.effect_z_samples]

            self.loss_history["e_step_time"].append(e_time)
            self.loss_history["m_step_time"].append(m_time)
            self.loss_history["train_loss"].append(loss.numpy())
            if self.target=="continuous":
                self.loss_history["e"].append(self._stddev_e.numpy())
            self.loss_history["z"].append([i.numpy() for i in self._stddev_z])
            self.loss_history["z_grads"].append(grads[:len(self.qs)])
#             self.loss_history["fe_grads_absmean"].append([np.mean(np.abs(i)) for i in grads[len(self.qs):]])
            self.loss_history["acceptance_rate"] += [acceptance_rate]
            self.loss_history["re_loss"].append(list([i for i in log_prob_parts[:-1]]))
            self.loss_history["fe_loss"].append(log_prob_parts[-1])
            if t==0:
                self.loss_history["z_change"].append([0.011]*len(self.qs))
            else:
                self.loss_history["z_change"].append(
                    [np.abs(np.array(self.loss_history["z"])[-1, q_num] - np.array(self.loss_history["z"])[-2, q_num])
                     for q_num in range(len(self.qs))])

            if len(metrics)>0:
                eval_results_train = self.evaluate(metrics, X, y, Z, num_samples_use_for_pred)
                eval_results_train_fe = self.evaluate(metrics, X, y)
                for metric in metrics:
                    self.loss_history["train_" + metric].append(eval_results_train[metric])
                    self.loss_history["fe_" + "train_" + metric].append(eval_results_train_fe[metric])

            if val_data is not None:
                if self.m_mode == "all":
                    val_loss = -tf.reduce_mean(self.target_log_prob_fn_val(*current_state)).numpy()
                    log_prob_parts_val = [-tf.reduce_mean(i).numpy() for i in self.target_log_prob_parts_fn_val(*current_state)]
                elif self.m_mode == "mean":
                    current_state_mean = [tf.reduce_mean(q_state, axis=0) for q_state in current_state]
                    val_loss = -self.target_log_prob_fn_val(*current_state_mean).numpy()
                    log_prob_parts_val = [-i.numpy() for i in self.target_log_prob_parts_fn_val(*current_state_mean)]

                self.loss_history["val_loss"].append(val_loss)
                self.loss_history["fe_loss_val"].append(log_prob_parts_val[-1])

                if len(metrics)>0:
                    eval_results_val = self.evaluate(metrics, X_val, y_val, Z_val, num_samples_use_for_pred)
                    eval_results_val_fe = self.evaluate(metrics, X_val, y_val)
                    for metric in metrics:
                        self.loss_history["val_" + metric].append(eval_results_val[metric])
                        self.loss_history["fe_"+ "val_" + metric].append(eval_results_val_fe[metric])

            ### Verbose Todo: Implement as Callback function
            if t % print_training == 0 or t == num_iters - 1:
                print("--------------------------------------------")
                print_str = "Iteration: {:>4} Acceptance Rate: {:.3f} Loss: {:.3f}, FE_Loss: {:.3f}, RE_Loss_sum: {:.3f}".format(
                    t, tf.reduce_mean(acceptance_rate).numpy(), self.loss_history["train_loss"][t],
                    self.loss_history["fe_loss"][t], np.sum(self.loss_history["re_loss"][t]))
                if len(metrics)>0:
                    for metric in metrics:
                        print_str += ", train_{}: {:.3f}".format(metric, self.loss_history["train_" + metric][t])
                        print_str += ", fe_train_{}: {:.3f}".format(metric, self.loss_history["fe_" + "train_" + metric][t])

                if val_data is not None:
                    print_str += "\n" + " Validation Loss: {:.3f}, , FE_Loss_val: {:.3f}".format(
                        self.loss_history['val_loss'][-1],
                        self.loss_history["fe_loss_val"][t])
                    if len(metrics) > 0:
                        for metric in metrics:
                            print_str += ", val_{}: {:.3f}".format(metric, self.loss_history["val_" +metric][t])
                            print_str += ", fe_val_{}: {:.3f}".format(metric,self.loss_history["fe_" + "val_" + metric][t])
                print(print_str)

            ### Track best model parameters Todo: Implement as Callback function
            if self.track_best_model:
                if self.track_best_model_metric in ["train_accuracy", "val_accuracy", "train_f1", "val_f1", "train_auc", "val_auc"]:
                    track_best_condition = self.best_score<self.loss_history[self.track_best_model_metric][t]
                else:
                    track_best_condition = self.best_score>self.loss_history[self.track_best_model_metric][t]
                if track_best_condition:
                    self.best_score = self.loss_history[self.track_best_model_metric][t]
                    self.best_parameters = [i.numpy() for i in self.trainable_variables]
                    self.best_iteration = t

            ### Early stopping FE Todo: Implement as Callback function
            if early_stopping_fe is not None:
                if not self.fe_converged:
                    if early_stopping_metric_fe in ["train_accuracy", "val_accuracy", "train_f1", "val_f1", "train_auc", "val_auc"]:
                        early_stop_condition_fe = self.loss_history[early_stopping_metric_fe][-1] <= current_best_fe
                    else:
                        early_stop_condition_fe = self.loss_history[early_stopping_metric_fe][-1] >= current_best_fe

                    if early_stop_condition_fe:
                        early_stop_fe += 1
                    else:
                        early_stop_fe = 0
                        current_best_fe = self.loss_history[early_stopping_metric_fe][-1]
                    if early_stop_fe==early_stopping_fe:
                        print(f"Early stopping of FE by {early_stopping_metric_fe} at {t} iterations")
                        self.fe_converged = True

            ### Early stopping RE Todo: Implement as Callback function
            if early_stopping_re is not None:
                for q_num in range(len(self.qs)):
                    if not self.re_converged[q_num]:
                        # Test whether metric is RE-specific or same for all
                        if len(np.array(self.loss_history[early_stopping_metric_re]).shape) == 1:
                            current_metric = self.loss_history[early_stopping_metric_re][-1]
                        else:
                            current_metric = self.loss_history[early_stopping_metric_re][-1][q_num]

                        if early_stopping_metric_re in ["train_accuracy", "val_accuracy", "train_f1", "val_f1",
                                                        "train_auc", "val_auc"]:
                            early_stop_condition_re = current_metric <= current_best_re[q_num]
                        elif early_stopping_metric_re == "z_change":
                            early_stop_condition_re = current_metric <= 0.01
                        else:
                            early_stop_condition_re = current_metric >= current_best_re[q_num]

                        if early_stop_condition_re:
                            early_stop_re[q_num] += 1
                        else:
                            early_stop_re[q_num] = 0
                            current_best_re[q_num] = current_metric
                        if early_stop_re[q_num] == early_stopping_re:
                            print(f"Early stopping of RE{q_num} by {early_stopping_metric_re} at {t} iterations")
                            self.re_converged[q_num] = True

            end_postprocessing = time.time()
            if t % print_training == 0 or t == num_iters - 1:
                print("E-step Time in Sec.=: ", round(e_time, 2))
                print("M-step Time in Sec.=: ", round(m_time, 2))
                print("Postprocessing Time in Sec.=: ", round(end_postprocessing - start_postprocessing, 2))

                self.loss_history["postprocessing_time"].append(end_postprocessing - start_postprocessing)

            if all(self.re_converged+[self.fe_converged]):
                self.num_iters_actual = t + 1
                break

        # The random effects are obtained as the inferred posterior mean of sampled values over the iterations
        self.random_effects = [np.mean(effect[round(self.num_iters_actual*(perc_burnin)):],axis=0) for effect in self.effect_z_samples]

        fit_end = time.time()
        self.total_fit_time = fit_end-fit_start


    def evaluate(self, metrics, X, y, Z=None, num_samples_use="posterior_mean"):
        '''
        Currently supported metrics:
            Regression: MSE, R2
            Classification: Accuracy, F1 (macro), ROC-AUC
        '''
        if num_samples_use!="posterior_mean" and num_samples_use>len(self.loss_history["effect_z_samples"]):
            num_samples_use = "posterior_mean"

        if Z is not None:
            y_pred = self.predict(X, Z, num_samples_use)
        else:
            y_pred = self.predict(X)

        res_metrics = {}
        if self.target=="continuous":
            y_pred = tf.reshape(y_pred,-1)
            if "mse" in metrics:
                res_metrics["mse"] = MeanSquaredError()(y,y_pred).numpy()
            if "r2" in metrics:
                res_metrics["r2"] = RSquare()(y,y_pred).numpy()

        if self.target == "binary":
            if "accuracy" in metrics:
                res_metrics["accuracy"] = Accuracy()(y,np.round(y_pred)).numpy()
            if "f1" in metrics:
                res_metrics["f1"] = f1(y,np.round(y_pred))
            if "auc" in metrics:
                res_metrics["auc"] = roc_auc_score(y,y_pred)

        if self.target == "categorical":
            # If y is a vector
            if len(y.shape)==1:
                if "accuracy" in metrics:
                    res_metrics["accuracy"] = cat_acc()(tf.one_hot(y,self.num_outputs), y_pred).numpy().numpy()
                if "f1" in metrics:
                    res_metrics["f1"] = F1Score(num_classes=self.num_outputs, average="macro")(tf.one_hot(y,self.num_outputs),y_pred).numpy()
                if "auc" in metrics:
                    res_metrics["auc"] = roc_auc_score(y,y_pred, multi_class="ovo", average="macro")
            # If y is sparse - one hot encoded
            else:
                if "accuracy" in metrics:
                    res_metrics["accuracy"] = cat_acc()(y, y_pred).numpy()
                if "f1" in metrics:
                    res_metrics["f1"] = F1Score(num_classes=self.num_outputs, average="macro")(y,y_pred).numpy()
                if "auc" in metrics:
                    res_metrics["auc"] = roc_auc_score(y,y_pred, multi_class="ovo", average="macro")

        if len(res_metrics)==0:
            raise Warning("The provided metrics are inappropriate for the target or not supported")

        return res_metrics

    def predict(self, X, Z=None, num_samples_use="posterior_mean"):
        if not tf.is_tensor(X):
            X = tf.convert_to_tensor(X)
#         X_random = tf.concat([tf.ones([X.shape[0],1]),X],axis=1)
        curr = X
        for i in self.fe_model.layers[:-1]:
            if "dense" in str(i.name):
                curr = i(curr)        

        res = self.fe_model(X,training=False)

        if Z is not None:
            X_random = tf.concat([tf.ones([X.shape[0],1]),X,curr],axis=1)
            
            if num_samples_use=="posterior_mean":
                if self.target in ["continuous", "binary"]:
                    res = tf.experimental.numpy.ravel(res) + tf.reduce_sum([tf.reduce_sum(tf.multiply(X_random,tf.transpose(tf.gather(self.random_effects[num],Z[:,num],axis=1))),axis=1) for num in range(len(self.qs))], axis=0)
                elif self.target == "categorical":
                    res = res + tf.reduce_sum([tf.transpose(tf.gather(self.random_effects[num], Z[:, num],axis=1)) for num in range(len(self.qs))], axis=0)
            else:

                if self.target in ["continuous", "binary"]:
                    samples = [[self.effect_z_samples[q][i] for q in range(len(self.qs))] for i in
                               range(-num_samples_use, 0)]
                    res = tf.reduce_mean([tf.experimental.numpy.ravel(res) + tf.reduce_sum(
                        [tf.reduce_sum(tf.multiply(X_random,tf.transpose(tf.gather(sample,Z,axis=1))),axis=1) for num in range(len(self.qs))], axis=0) for sample in
                                          samples], axis=0)
                elif self.target == "categorical":
                    samples = [[self.effect_z_samples[q][i] for q in range(len(self.qs))] for i in
                               range(-num_samples_use, 0)]
                    res = tf.reduce_mean([res + tf.reduce_sum([tf.transpose(tf.gather(sample[num], Z[:, num],axis=1))
                                                               for num in range(len(self.qs))], axis=0) for sample in samples], axis=0)
        return self.link_function(res)

# %% [markdown]
# ## Mixed effects MLP
# With nonlinear slope layer

# %%
dictBuild = {'n_features': arrX.shape[1],
             'n_clusters': dictSpiralParams['clusters'],
             'adversary_layer_units': [4, 4],
             'slope_posterior_init_scale': 0.3, 
             'intercept_posterior_init_scale': 0.1, 
             'slope_prior_scale': 0.3, 
             'intercept_prior_scale': 0.1,
             'kl_weight': 0.00001}
dictCompile = {'loss_class_fe_weight': 1.0, 
               'loss_gen_weight': 0.5, 
               'loss_class_me_weight': 1.0,
               'metric_class_me': tf.keras.metrics.BinaryAccuracy('acc'),
               'metric_class_fe': tf.keras.metrics.BinaryAccuracy('acc_fe'),
               'metric_adv': tf.keras.metrics.CategoricalAccuracy('adv_acc')}
dfResultsME, dfGradsME, dfRandomSlopeSD, dfRandomIntercept, figDBME = cross_validate(MixedEffectsMLPNonlinearSlope,  
                                                                            use_z=True, 
                                                                            build_args=dictBuild, 
                                                                            compile_args=dictCompile)
figDBME.savefig(os.path.join(strOutputDir, 'mixedeffects_decision_boundaries.png'))
figDBME.savefig(os.path.join(strOutputDir, 'mixedeffects_decision_boundaries.svg'))
figDBME.show()

figGradsME, axGradsME = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsME, x='Feature', y='Gradient', ax=axGradsME, color='C0')
axGradsME.set_ylabel('Gradient magnitude')
figGradsME.savefig(os.path.join(strOutputDir, 'mixedeffects_feature_gradients.png'))
figGradsME.savefig(os.path.join(strOutputDir, 'mixedeffects_feature_gradients.svg'))
figGradsME.show()

compute_95ci(dfResultsME)
# Out:
# Training fold 9
# Epoch 1/10
# 282/282 [==============================] - 5s 11ms/step - class_me_loss: 0.7130 - class_fe_loss: 0.6916 - adv_loss: 2.3028 - total_loss: 0.2540 - acc: 0.5000 - acc_fe: 0.4969 - adv_acc: 0.0918 - val_class_me_loss: 0.6971 - val_class_fe_loss: 0.6821 - val_adv_loss: 2.3012 - val_total_loss: 0.0000e+00 - val_acc: 0.5000 - val_acc_fe: 0.5510 - val_adv_acc: 0.0970
# Epoch 2/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.6679 - class_fe_loss: 0.6427 - adv_loss: 2.2921 - total_loss: 0.1655 - acc: 0.5670 - acc_fe: 0.6204 - adv_acc: 0.0994 - val_class_me_loss: 0.6164 - val_class_fe_loss: 0.5751 - val_adv_loss: 2.2876 - val_total_loss: 0.0000e+00 - val_acc: 0.6520 - val_acc_fe: 0.6810 - val_adv_acc: 0.1060
# Epoch 3/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.5856 - class_fe_loss: 0.5475 - adv_loss: 2.2702 - total_loss: -0.0010 - acc: 0.6920 - acc_fe: 0.6986 - adv_acc: 0.1080 - val_class_me_loss: 0.5430 - val_class_fe_loss: 0.5028 - val_adv_loss: 2.2664 - val_total_loss: 0.0000e+00 - val_acc: 0.7150 - val_acc_fe: 0.7340 - val_adv_acc: 0.1440
# Epoch 4/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.5295 - class_fe_loss: 0.5032 - adv_loss: 2.2506 - total_loss: -0.0915 - acc: 0.7321 - acc_fe: 0.7360 - adv_acc: 0.1322 - val_class_me_loss: 0.5011 - val_class_fe_loss: 0.4758 - val_adv_loss: 2.2496 - val_total_loss: 0.0000e+00 - val_acc: 0.7510 - val_acc_fe: 0.7460 - val_adv_acc: 0.1370
# Epoch 5/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.4989 - class_fe_loss: 0.4879 - adv_loss: 2.2357 - total_loss: -0.1298 - acc: 0.7493 - acc_fe: 0.7481 - adv_acc: 0.1446 - val_class_me_loss: 0.4792 - val_class_fe_loss: 0.4663 - val_adv_loss: 2.2362 - val_total_loss: 0.0000e+00 - val_acc: 0.7620 - val_acc_fe: 0.7610 - val_adv_acc: 0.1380
# Epoch 6/10
# 282/282 [==============================] - 3s 9ms/step - class_me_loss: 0.4811 - class_fe_loss: 0.4786 - adv_loss: 2.2232 - total_loss: -0.1506 - acc: 0.7563 - acc_fe: 0.7546 - adv_acc: 0.1553 - val_class_me_loss: 0.4660 - val_class_fe_loss: 0.4596 - val_adv_loss: 2.2249 - val_total_loss: 0.0000e+00 - val_acc: 0.7680 - val_acc_fe: 0.7690 - val_adv_acc: 0.1390
# Epoch 7/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.4722 - class_fe_loss: 0.4769 - adv_loss: 2.2136 - total_loss: -0.1564 - acc: 0.7573 - acc_fe: 0.7561 - adv_acc: 0.1553 - val_class_me_loss: 0.4571 - val_class_fe_loss: 0.4550 - val_adv_loss: 2.2206 - val_total_loss: 0.0000e+00 - val_acc: 0.7790 - val_acc_fe: 0.7630 - val_adv_acc: 0.1380
# Epoch 8/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.4645 - class_fe_loss: 0.4742 - adv_loss: 2.2076 - total_loss: -0.1637 - acc: 0.7582 - acc_fe: 0.7578 - adv_acc: 0.1562 - val_class_me_loss: 0.4508 - val_class_fe_loss: 0.4525 - val_adv_loss: 2.2153 - val_total_loss: 0.0000e+00 - val_acc: 0.7710 - val_acc_fe: 0.7740 - val_adv_acc: 0.1590
# Epoch 9/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.4598 - class_fe_loss: 0.4728 - adv_loss: 2.2035 - total_loss: -0.1678 - acc: 0.7596 - acc_fe: 0.7600 - adv_acc: 0.1572 - val_class_me_loss: 0.4504 - val_class_fe_loss: 0.4565 - val_adv_loss: 2.2127 - val_total_loss: 0.0000e+00 - val_acc: 0.7670 - val_acc_fe: 0.7700 - val_adv_acc: 0.1460
# Epoch 10/10
# 282/282 [==============================] - 3s 10ms/step - class_me_loss: 0.4556 - class_fe_loss: 0.4721 - adv_loss: 2.2006 - total_loss: -0.1712 - acc: 0.7610 - acc_fe: 0.7602 - adv_acc: 0.1600 - val_class_me_loss: 0.4443 - val_class_fe_loss: 0.4521 - val_adv_loss: 2.2114 - val_total_loss: 0.0000e+00 - val_acc: 0.7770 - val_acc_fe: 0.7680 - val_adv_acc: 0.1550
# Mean
# Accuracy         0.762444
# Test Accuracy    0.777000
# dtype: float64
# 95CI low
# Accuracy        NaN
# Test Accuracy   NaN
# dtype: float64
# 95CI high
# Accuracy        NaN
# Test Accuracy   NaN
# dtype: float64
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\553910355.py:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figDBME.show()
# C:\Users\AndrejTschalzev\AppData\Local\Temp\ipykernel_524\553910355.py:28: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   figGradsME.show()

# %% [markdown]
# ## Mixed effects MLP
#
# With domain adversarial loss disabled.

# %%
dictBuild = {'n_features': arrX.shape[1],
             'n_clusters': dictSpiralParams['clusters'],
             'adversary_layer_units': [4, 4],
             'slope_posterior_init_scale': 0.3, 
             'intercept_posterior_init_scale': 0.1, 
             'slope_prior_scale': 0.3, 
             'intercept_prior_scale': 0.1,
             'kl_weight': 0.00001}
dictCompile = {'loss_class_fe_weight': 0., 
               'loss_gen_weight': 0., 
               'loss_class_me_weight': 1.0,
               'metric_class_me': tf.keras.metrics.BinaryAccuracy('acc'),
               'metric_class_fe': tf.keras.metrics.BinaryAccuracy('acc_fe'),
               'metric_adv': tf.keras.metrics.CategoricalAccuracy('adv_acc')}
dfResultsME2, dfGradsME2, dfRandomSlopeSD2, dfRandomIntercept2, figDBME2 = cross_validate(MixedEffectsMLPNonlinearSlope,  
                                                                            use_z=True, 
                                                                            build_args=dictBuild, 
                                                                            compile_args=dictCompile)
figDBME2.savefig(os.path.join(strOutputDir, 'mixedeffects_noadv_decision_boundaries.png'))
figDBME2.savefig(os.path.join(strOutputDir, 'mixedeffects_noadv_decision_boundaries.svg'))
figDBME2.show()

figGradsME2, axGradsME2 = plt.subplots(figsize=(arrX.shape[1], 3))
sns.boxplot(data=dfGradsME2, x='Feature', y='Gradient', ax=axGradsME2, color='C0')
axGradsME2.set_ylabel('Gradient magnitude')
figGradsME2.savefig(os.path.join(strOutputDir, 'mixedeffects_noadv_feature_gradients.png'))
figGradsME2.savefig(os.path.join(strOutputDir, 'mixedeffects_noadv_feature_gradients.svg'))
figGradsME2.show()

compute_95ci(dfResultsME2)
# Out:
# Mean
# Accuracy         0.793528
# Test Accuracy    0.793262
# dtype: float64
# 95CI low
# Accuracy         0.771184
# Test Accuracy    0.768500
# dtype: float64
# 95CI high
# Accuracy         0.815872
# Test Accuracy    0.818023
# dtype: float64

# %% [markdown]
# ## Mixed effects MLP
#
# With Z input randomized to ablate learned RE information.

# %%
dictBuild = {'n_features': arrX.shape[1],
             'n_clusters': dictSpiralParams['clusters'],
             'adversary_layer_units': [4, 4],
             'slope_posterior_init_scale': 0.3, 
             'intercept_posterior_init_scale': 0.1, 
             'slope_prior_scale': 0.3, 
             'intercept_prior_scale': 0.1,
             'kl_weight': 0.00001}
dictCompile = {'loss_class_fe_weight': 1.0, 
               'loss_gen_weight': 0.5, 
               'loss_class_me_weight': 1.0,
               'metric_class_me': tf.keras.metrics.BinaryAccuracy('acc'),
               'metric_class_fe': tf.keras.metrics.BinaryAccuracy('acc_fe'),
               'metric_adv': tf.keras.metrics.CategoricalAccuracy('adv_acc')}
dfResultsMERandomizedZ, dfGradsMERandomizedZ, dfRandomSlopeSD, dfRandomIntercept, figDBMERandomizedZ = cross_validate(MixedEffectsMLPNonlinearSlope,  
                                                                            use_z=True, 
                                                                            build_args=dictBuild, 
                                                                            compile_args=dictCompile,
                                                                            randomize_z=True)
figDBMERandomizedZ.show()

compute_95ci(dfResultsMERandomizedZ)
# Out:
# 2022-02-04 12:43:57.401426: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2022-02-04 12:44:00.006965: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# Mean
# Accuracy         0.785816
# Test Accuracy    0.766992
# dtype: float64
# 95CI low
# Accuracy         0.779762
# Test Accuracy    0.756388
# dtype: float64
# 95CI high
# Accuracy         0.791869
# Test Accuracy    0.777596
# dtype: float64

# %% [markdown]
# Create barplot comparing performance

# %%
lsPerformance = []
for strModel, df in {'Conventional': dfResultsBase,
                     'Cluster input': dfResultsConcat,
                     'Meta-learning': dfResultsMLDG,
                     'Domain adversarial': dfResultsDA,
                     'Mixed effects': dfResultsME,
                     'Mixed effects w/o DA': dfResultsME2}.items():
    dfLong = df['Test Accuracy'].to_frame('Accuracy')
    dfLong['Model'] = strModel
    lsPerformance += [dfLong]
    
dfPerformance = pd.concat(lsPerformance, axis=0)
figPerf, axPerf = plt.subplots(figsize=(10, 3))
sns.barplot(data=dfPerformance, x='Model',  y='Accuracy', ax=axPerf)
axPerf.set_ylim(dfPerformance['Accuracy'].min() - 0.05, dfPerformance['Accuracy'].max())

figPerf.savefig(os.path.join(strOutputDir, 'performance_comparison.png'))
figPerf.savefig(os.path.join(strOutputDir, 'performance_comparison.svg'))
figPerf.show()

dfPerformance.to_csv(os.path.join(strOutputDir, 'test_performance.csv'))

# %% [markdown]
# For the ME-MLP, compare each cluster's learned random intercept with its class balance. When simulating a confounding effect, these two measurements should be highly correlated.

# %%
# Compute conversion % by site
dfRatio = pd.DataFrame({'Cluster': arrZ.argmax(axis=1), 'Class': arrY})
dfClusterRatio = dfRatio.groupby('Cluster').mean()
dfClusterRatio.columns = ['Class balance']

dfClusterInt = dfClusterRatio.join(dfRandomIntercept.groupby('Cluster').median())
fig, ax = plt.subplots()
sns.scatterplot(data=dfClusterInt, x='Random intercept', y='Class balance', ax=ax)
r, p = stats.pearsonr(dfClusterInt['Random intercept'], dfClusterInt['Class balance'])
ax.text(0.05, 0.9, f'r = {r:.03f}, p = {p:.2e}', 
        transform=ax.transAxes, bbox={'boxstyle': 'round', 'facecolor': 'white', 'edgecolor': 'k'})

fig.savefig(os.path.join(strOutputDir, 'mixedeffects_random_intercepts.png'))
fig.savefig(os.path.join(strOutputDir, 'mixedeffects_random_intercepts.svg'))
# Out:
# /project/bioinformatics/DLLab/shared/CondaEnvironments/Kevin385Ray/lib/python3.8/site-packages/scipy/stats/stats.py:3845: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())

# %% [markdown]
# Compare feature importance.

# %%
dfGradsBaseNorm = dfGradsBase.copy()
dfGradsBaseNorm['Gradient'] /= dfGradsBaseNorm['Gradient'].max()
dfGradsBaseNorm['Gradient'] -= dfGradsBaseNorm['Gradient'].min()
dfGradsBaseNorm['Model'] = 'Conventional'

dfGradsConcatNorm = dfGradsConcat.copy()
dfGradsConcatNorm['Gradient'] /= dfGradsConcatNorm['Gradient'].max()
dfGradsConcatNorm['Gradient'] -= dfGradsConcatNorm['Gradient'].min()
dfGradsConcatNorm['Model'] = 'Cluster input'

dfGradsMLDGNorm = dfGradsMLDG.copy()
dfGradsMLDGNorm['Gradient'] /= dfGradsMLDGNorm['Gradient'].max()
dfGradsMLDGNorm['Gradient'] -= dfGradsMLDGNorm['Gradient'].min()
dfGradsMLDGNorm['Model'] = 'Meta-learning'

dfGradsDANorm = dfGradsDA.copy()
dfGradsDANorm['Gradient'] /= dfGradsDANorm['Gradient'].max()
dfGradsDANorm['Gradient'] -= dfGradsDANorm['Gradient'].min()
dfGradsDANorm['Model'] = 'Domain adversarial'

dfGradsMENorm = dfGradsME.copy()
dfGradsMENorm['Gradient'] /= dfGradsMENorm['Gradient'].max()
dfGradsMENorm['Gradient'] -= dfGradsMENorm['Gradient'].min()
dfGradsMENorm['Model'] = 'ME-MLP w/ DA'

dfGradsME2Norm = dfGradsME2.copy()
dfGradsME2Norm['Gradient'] /= dfGradsME2Norm['Gradient'].max()
dfGradsME2Norm['Gradient'] -= dfGradsME2Norm['Gradient'].min()
dfGradsME2Norm['Model'] = 'ME-MLP w/o DA'

dfGradsAll = pd.concat([dfGradsBaseNorm, dfGradsConcatNorm, dfGradsMLDGNorm, dfGradsDANorm, dfGradsME2Norm, dfGradsMENorm], axis=0)
figGradsAll, axGradsAll = plt.subplots(figsize=(4 * arrX.shape[1], 4))
sns.barplot(data=dfGradsAll, x='Model', y='Gradient', hue='Feature', ax=axGradsAll)
axGradsAll.set_ylabel('Gradient magnitude')

figGradsAll.savefig(os.path.join(strOutputDir, 'feature_gradients_compared.png'))
figGradsAll.savefig(os.path.join(strOutputDir, 'feature_gradients_compared.svg'))
figGradsAll.show()

# %% [markdown]
# When simulating confounds: Test for difference in gradient magnitude between the least important "real" feature and each probe feature

# %%
if dictSpiralParams['confounded_vars'] > 0:
    for strModel, df in [('Conventional', dfGradsBase), ('Cluster input', dfGradsConcat), 
                        ('Meta-learning', dfGradsMLDG), ('Domain adversarial', dfGradsDA),
                        ('ME-MLP w/ DA', dfGradsME),
                        ('ME-MLP w/o DA', dfGradsME2)]:
        print(strModel)
        dfRealFeatures = df.loc[df['Feature'].isin(['1', '2'])]
        strRefFeature = dfRealFeatures.groupby('Feature').mean().idxmin().values[0]
        
        for iProbe in range(dictSpiralParams['confounded_vars']):    
            t, p = stats.ttest_rel(df.loc[df['Feature'] == strRefFeature, 'Gradient'],
                                df.loc[df['Feature'] == f'Probe {iProbe + 1}', 'Gradient'])
            print(f'Feature {strRefFeature} vs. Probe {iProbe + 1}: t = {t:.03f}, p = {p:.05f}')
